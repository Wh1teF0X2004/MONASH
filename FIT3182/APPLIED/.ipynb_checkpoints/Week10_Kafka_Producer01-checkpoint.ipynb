# %% [markdown]
# # Producer 1
# This program writes records to Kafka topic `Scenario01`. Each record has `key = "parsed"` and `value = "$LOCALE_TIME, $X"`, where `$LOCALE_TIME` is some locale-sensitive time representation, and `$X` is a random integer in the interval $[0,100)$.

# %%
# import statements
from time import sleep
from json import dumps
from kafka3 import KafkaProducer
import random
import datetime as dt

hostip = "10.192.45.88" # change it to your IP


def publish_message(producer_instance, topic_name, key, value):
    try:
        # CONVERT TO BYTES
        # KAFKA REQURIES MESSAGE TO BE SENT AS BYTES
        key_bytes = bytes(key, encoding='utf-8')
        value_bytes = bytes(value, encoding='utf-8')
        
        # TO SEND THE MESSAGE TO BE SPECIFIC TOPIC
        producer_instance.send(topic_name, key=key_bytes, value=value_bytes)
        
        # .flush() MAKE SURE THAT THE MESSAGE IS ACTUALLY SENT TO KAFKA BEFORE MOVING ON TO THE NEXT LINE
        producer_instance.flush()
        print('Message published successfully. Data: ' + str(data))
    except Exception as ex:
        print('Exception in publishing message.')
        print(str(ex))
        
def connect_kafka_producer():
    _producer = None
    try:
        _producer = KafkaProducer(bootstrap_servers=[f'{hostip}:9092'],
                                  api_version=(0, 10))
    except Exception as ex:
        print('Exception while connecting Kafka.')
        print(str(ex))
    finally:
        return _producer
    
if __name__ == '__main__':
   
    topic = 'Scenario01'
    
    print('Publishing records..')
    producer = connect_kafka_producer()
    
    for e in range(100):
        # .strftime("%X") IS TO FORMAT THE DATETIME OBJECT AS A STRING REPRESENTATION IN HH:MM:SS
        data = str(dt.datetime.now().strftime("%X")) + ', ' + str(random.randrange(0,100))
        publish_message(producer, topic, 'parsed', data)
        sleep(1)
# Out:
# Publishing records..
# Message published successfully. Data: 03:50:27, 86
# Message published successfully. Data: 03:50:28, 84
# Message published successfully. Data: 03:50:29, 87
# Message published successfully. Data: 03:50:30, 41
# Message published successfully. Data: 03:50:31, 15
# Message published successfully. Data: 03:50:32, 8
# Message published successfully. Data: 03:50:33, 63
# Message published successfully. Data: 03:50:34, 34
# Message published successfully. Data: 03:50:35, 71
# Message published successfully. Data: 03:50:37, 76
# Message published successfully. Data: 03:50:38, 34
# Message published successfully. Data: 03:50:39, 63
# Message published successfully. Data: 03:50:40, 5
# Message published successfully. Data: 03:50:41, 97
# Message published successfully. Data: 03:50:42, 9
# Message published successfully. Data: 03:50:43, 8
# Message published successfully. Data: 03:50:44, 61
# Message published successfully. Data: 03:50:45, 97
# ...
