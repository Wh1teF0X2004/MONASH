# %% [markdown]
# # Producer 3
# This program writes records to Kafka topic `Scenario03`. Each record has `key = "parsed"` and `value = "$LOCALE_TIME, $X"`, where `$LOCALE_TIME` is some locale-sensitive time representation, and `$X` is a random integer in the interval $[0,100)$.

# %%
# import statements
from time import sleep
from json import dumps
from kafka3 import KafkaProducer
import random
import datetime as dt

hostip = "10.192.45.88" # change it to your IP

def publish_message(producer_instance, topic_name, key, value):
    try:
        key_bytes = bytes(key, encoding='utf-8')
        value_bytes = bytes(value, encoding='utf-8')
        producer_instance.send(topic_name, key=key_bytes, value=value_bytes)
        producer_instance.flush()
        print('Message published successfully. Data: ' + str(data))
    except Exception as ex:
        print('Exception in publishing message.')
        print(str(ex))
        
def connect_kafka_producer():
    _producer = None
    try:
        _producer = KafkaProducer(bootstrap_servers=[f'{hostip}:9092'],
                                  api_version=(0, 10))
    except Exception as ex:
        print('Exception while connecting Kafka.')
        print(str(ex))
    finally:
        return _producer
    
if __name__ == '__main__':
   
    topic = 'Scenario03'
    
    print('Publishing records..')
    producer = connect_kafka_producer()
    
    for e in range(100):
        # INTRODUCE VARIATIONS IN ARRIVAL TIME BY ADDING RANDOM SLEEP DURATIONS
        sleep_duration = random.uniform(0.5, 2.0)
        sleep(sleep_duration)
        data = str(dt.datetime.now().strftime("%X")) + ', ' + str(random.randrange(0,100))
        publish_message(producer, topic, 'parsed', data)
        # sleep(1)
# Out:
# Publishing records..
# Message published successfully. Data: 04:05:05, 28
# Message published successfully. Data: 04:05:07, 22
# Message published successfully. Data: 04:05:09, 21
# Message published successfully. Data: 04:05:11, 73
# Message published successfully. Data: 04:05:11, 53
# Message published successfully. Data: 04:05:13, 75
# Message published successfully. Data: 04:05:14, 97
# Message published successfully. Data: 04:05:15, 15
# Message published successfully. Data: 04:05:16, 28
# Message published successfully. Data: 04:05:17, 56
# Message published successfully. Data: 04:05:18, 48
# Message published successfully. Data: 04:05:19, 47
# Message published successfully. Data: 04:05:21, 11
# Message published successfully. Data: 04:05:22, 7
# Message published successfully. Data: 04:05:23, 73
# Message published successfully. Data: 04:05:24, 0
# Message published successfully. Data: 04:05:26, 40
# Message published successfully. Data: 04:05:27, 21
# ...
