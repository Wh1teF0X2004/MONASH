# %% [markdown]
# # Using Folium to visualize unoccupied parking spots
# Folium uses the power of [leaflet.js](https://leafletjs.com/) to allow easy visualization of map data.
# - [Folium quickstart](https://python-visualization.github.io/folium/quickstart.html)
# - [API reference](https://python-visualization.github.io/folium/modules.html#module-folium.folium)

# %% [markdown]
# First, let's grab our data from the database and filter out records describing vacant parking spots.

# %%
from pymongo import MongoClient
from pprint import pprint

host_ip = "10.192.45.93"

client = MongoClient(host_ip, 27017)
db = client.fit3182_db
week11 = db.week11
# Preparing the data for plotting
unoccupiedList = []

# Looping through all the data
for row in week11.find():
    pprint(row)
    # Checking if the parking spot is available
    if row['status'] == 'Unoccupied':
        # Adding the latitude and longitude to the list of unoccupied spots
        unoccupiedList.append( (float(row['latitude']), float(row['longitude'])) )
# Out:
# {'_id': 50662,
#  'latitude': -37.80913844013256,
#  'longitude': 144.97189445783573,
#  'status': 'Present'}
# {'_id': 50663,
#  'latitude': -37.80908828360667,
#  'longitude': 144.97187134487461,
#  'status': 'Present'}
# {'_id': 50664,
#  'latitude': -37.809037522981974,
#  'longitude': 144.97184785392136,
#  'status': 'Present'}
# {'_id': 50634,
#  'latitude': -37.80882551342851,
#  'longitude': 144.97187528239476,
#  'status': 'Unoccupied'}
# {'_id': 50635,
#  'latitude': -37.80880200217635,
#  'longitude': 144.97186447735396,
#  'status': 'Present'}
# {'_id': 50640,
#  'latitude': -37.808660179978915,
#  'longitude': 144.97179932080303,
#  'status': 'Unoccupied'}
# {'_id': 50641,
#  'latitude': -37.80863676590235,
#  'longitude': 144.97178858752375,
#  'status': 'Present'}
# {'_id': 50643,
#  'latitude': -37.808589373656346,
#  'longitude': 144.97176686270228,
#  'status': 'Present'}
# {'_id': 50645,
#  'latitude': -37.80854402111967,
#  'longitude': 144.97174607257597,
#  'status': 'Present'}
# {'_id': 65168,
#  'latitude': -37.81065243137996,
#  'longitude': 144.96782988802386,
#  'status': 'Unoccupied'}
# {'_id': 65163,
#  'latitude': -37.810585009767664,
#  'longitude': 144.96805719749062,
#  'status': 'Present'}
# {'_id': 65162,
#  'latitude': -37.81057630472673,
#  'longitude': 144.9680868422238,
#  'status': 'Unoccupied'}
# {'_id': 65161,
#  'latitude': -37.8105679515687,
#  'longitude': 144.96811522171183,
#  'status': 'Unoccupied'}
# {'_id': 65160,
#  'latitude': -37.8105600050226,
#  'longitude': 144.96814288315204,
#  'status': 'Unoccupied'}
# {'_id': 65140,
#  'latitude': -37.810360151885874,
#  'longitude': 144.96882366467938,
#  'status': 'Present'}
# {'_id': 65139,
#  'latitude': -37.8103516363898,
#  'longitude': 144.96885285230542,
#  'status': 'Unoccupied'}
# {'_id': 65138,
#  'latitude': -37.81034291748419,
#  'longitude': 144.9688825826736,
#  'status': 'Present'}
# {'_id': 65137,
#  'latitude': -37.810334301158015,
#  'longitude': 144.96891216705563,
#  'status': 'Unoccupied'}
# {'_id': 65136,
#  'latitude': -37.81032556866694,
#  'longitude': 144.96894199588996,
#  'status': 'Present'}
# {'_id': 65129,
#  'latitude': -37.81025476640585,
#  'longitude': 144.9691838165588,
#  'status': 'Present'}
# {'_id': 65523,
#  'latitude': -37.81335468962813,
#  'longitude': 144.95823713898977,
#  'status': 'Present'}
# {'_id': 65522,
#  'latitude': -37.81333638334371,
#  'longitude': 144.95830036989398,
#  'status': 'Unoccupied'}
# {'_id': 65512,
#  'latitude': -37.8130652946148,
#  'longitude': 144.95923177270038,
#  'status': 'Present'}
# {'_id': 65580,
#  'latitude': -37.81334243786431,
#  'longitude': 144.9589552760267,
#  'status': 'Unoccupied'}
# {'_id': 65579,
#  'latitude': -37.81332436626951,
#  'longitude': 144.95901777615921,
#  'status': 'Unoccupied'}
# {'_id': 65596,
#  'latitude': -37.81367617155814,
#  'longitude': 144.9577989034692,
#  'status': 'Unoccupied'}
# {'_id': 65593,
#  'latitude': -37.81361505092875,
#  'longitude': 144.9580112697744,
#  'status': 'Unoccupied'}
# {'_id': 65590,
#  'latitude': -37.81355238242727,
#  'longitude': 144.9582278777661,
#  'status': 'Unoccupied'}
# {'_id': 65570,
#  'latitude': -37.813517379359894,
#  'longitude': 144.95802880213256,
#  'status': 'Present'}
# {'_id': 65558,
#  'latitude': -37.81341256173804,
#  'longitude': 144.95838767338887,
#  'status': 'Unoccupied'}
# {'_id': 65552,
#  'latitude': -37.813339019172425,
#  'longitude': 144.95864016115172,
#  'status': 'Present'}
# {'_id': 65550,
#  'latitude': -37.813320247143366,
#  'longitude': 144.9587044311516,
#  'status': 'Unoccupied'}
# {'_id': 65549,
#  'latitude': -37.813311556984594,
#  'longitude': 144.95873418423957,
#  'status': 'Present'}
# {'_id': 65548,
#  'latitude': -37.81330288381933,
#  'longitude': 144.95876387835244,
#  'status': 'Unoccupied'}
# {'_id': 65538,
#  'latitude': -37.81319676404733,
#  'longitude': 144.95912719882205,
#  'status': 'Present'}
# {'_id': 65537,
#  'latitude': -37.813188012095566,
#  'longitude': 144.95915716252705,
#  'status': 'Present'}
# {'_id': 65536,
#  'latitude': -37.81317933967216,
#  'longitude': 144.95918685368446,
#  'status': 'Unoccupied'}
# {'_id': 65532,
#  'latitude': -37.813144333027964,
#  'longitude': 144.95930670384632,
#  'status': 'Present'}
# {'_id': 65528,
#  'latitude': -37.81309344432242,
#  'longitude': 144.9594816718423,
#  'status': 'Present'}
# {'_id': 65527,
#  'latitude': -37.81308470590268,
#  'longitude': 144.95951158908997,
#  'status': 'Unoccupied'}
# {'_id': 52149,
#  'latitude': -37.81127806929965,
#  'longitude': 144.9672745517347,
#  'status': 'Present'}
# {'_id': 52110,
#  'latitude': -37.81163155142592,
#  'longitude': 144.96768730663672,
#  'status': 'Unoccupied'}
# {'_id': 57942,
#  'latitude': -37.8201668549864,
#  'longitude': 144.95453587450794,
#  'status': 'Unoccupied'}
# {'_id': 57938,
#  'latitude': -37.82037346768652,
#  'longitude': 144.95463055373497,
#  'status': 'Unoccupied'}
# {'_id': 57937,
#  'latitude': -37.820423666254094,
#  'longitude': 144.95465361283914,
#  'status': 'Unoccupied'}
# {'_id': 7506,
#  'latitude': -37.80876204220064,
#  'longitude': 144.95870647846792,
#  'status': 'Present'}
# {'_id': 7508,
#  'latitude': -37.808800623722234,
#  'longitude': 144.9585733737045,
#  'status': 'Unoccupied'}
# {'_id': 7510,
#  'latitude': -37.808839675702,
#  'longitude': 144.95843901574676,
#  'status': 'Unoccupied'}
# {'_id': 7512,
#  'latitude': -37.808860847980164,
#  'longitude': 144.95836611190578,
#  'status': 'Unoccupied'}
# {'_id': 7521,
#  'latitude': -37.80877954195293,
#  'longitude': 144.95830675513193,
#  'status': 'Unoccupied'}
# {'_id': 7524,
#  'latitude': -37.80861997545845,
#  'longitude': 144.95851053590047,
#  'status': 'Present'}
# {'_id': 7527,
#  'latitude': -37.80869892691619,
#  'longitude': 144.95823845973945,
#  'status': 'Present'}
# {'_id': 7529,
#  'latitude': -37.808745387122045,
#  'longitude': 144.95842532854292,
#  'status': 'Unoccupied'}
# {'_id': 7532,
#  'latitude': -37.80871941352815,
#  'longitude': 144.95851431851983,
#  'status': 'Present'}
# {'_id': 7535,
#  'latitude': -37.808685459576594,
#  'longitude': 144.9586313602008,
#  'status': 'Unoccupied'}
# {'_id': 7536,
#  'latitude': -37.80867678877247,
#  'longitude': 144.95866122055884,
#  'status': 'Unoccupied'}
# {'_id': 7538,
#  'latitude': -37.80865942637155,
#  'longitude': 144.95872094870927,
#  'status': 'Unoccupied'}
# {'_id': 66452,
#  'latitude': -37.81322561474281,
#  'longitude': 144.95524936628024,
#  'status': 'Unoccupied'}
# {'_id': 65213,
#  'latitude': -37.81092948294076,
#  'longitude': 144.96655417860907,
#  'status': 'Present'}
# {'_id': 65245,
#  'latitude': -37.81116977716893,
#  'longitude': 144.9663764898553,
#  'status': 'Unoccupied'}
# {'_id': 65861,
#  'latitude': -37.808937525361586,
#  'longitude': 144.96995988235648,
#  'status': 'Unoccupied'}
# {'_id': 65835,
#  'latitude': -37.80893402031106,
#  'longitude': 144.96980158069755,
#  'status': 'Present'}
# {'_id': 65837,
#  'latitude': -37.80897111670238,
#  'longitude': 144.96967358921987,
#  'status': 'Unoccupied'}
# {'_id': 65838,
#  'latitude': -37.808989664207985,
#  'longitude': 144.9696095894605,
#  'status': 'Unoccupied'}
# {'_id': 65855,
#  'latitude': -37.80882010318139,
#  'longitude': 144.9703644306575,
#  'status': 'Unoccupied'}
# {'_id': 65850,
#  'latitude': -37.8087286939151,
#  'longitude': 144.97067955581468,
#  'status': 'Present'}
# {'_id': 6031,
#  'latitude': -37.80867892330137,
#  'longitude': 144.95830745140307,
#  'status': 'Present'}
# {'_id': 65026,
#  'latitude': -37.809780944277975,
#  'longitude': 144.97046816802302,
#  'status': 'Present'}
# {'_id': 65069,
#  'latitude': -37.80995071804908,
#  'longitude': 144.9702211247601,
#  'status': 'Present'}
# {'_id': 65060,
#  'latitude': -37.80982848782082,
#  'longitude': 144.97063865748817,
#  'status': 'Present'}
# {'_id': 52230,
#  'latitude': -37.81023414700783,
#  'longitude': 144.96692374522712,
#  'status': 'Present'}
# {'_id': 52228,
#  'latitude': -37.81028044883135,
#  'longitude': 144.96694518657677,
#  'status': 'Present'}
# {'_id': 52227,
#  'latitude': -37.81030328247425,
#  'longitude': 144.96695576061347,
#  'status': 'Present'}
# {'_id': 52226,
#  'latitude': -37.810326116566685,
#  'longitude': 144.96696633465655,
#  'status': 'Present'}
# {'_id': 52225,
#  'latitude': -37.81034895065827,
#  'longitude': 144.96697690871835,
#  'status': 'Present'}
# {'_id': 52223,
#  'latitude': -37.8103941257034,
#  'longitude': 144.96699783693825,
#  'status': 'Present'}
# {'_id': 54634,
#  'latitude': -37.811582207875794,
#  'longitude': 144.95914220671528,
#  'status': 'Present'}
# {'_id': 54631,
#  'latitude': -37.811676681158545,
#  'longitude': 144.9591853849827,
#  'status': 'Present'}
# {'_id': 54630,
#  'latitude': -37.81170020795702,
#  'longitude': 144.95919613802207,
#  'status': 'Present'}
# {'_id': 54629,
#  'latitude': -37.811723924153966,
#  'longitude': 144.95920697367882,
#  'status': 'Present'}
# {'_id': 62246,
#  'latitude': -37.817334516747486,
#  'longitude': 144.96048215380262,
#  'status': 'Unoccupied'}
# {'_id': 62245,
#  'latitude': -37.81731709210602,
#  'longitude': 144.96054316903195,
#  'status': 'Unoccupied'}
# {'_id': 62244,
#  'latitude': -37.817298204837954,
#  'longitude': 144.9606094090057,
#  'status': 'Present'}
# {'_id': 62243,
#  'latitude': -37.81727844911076,
#  'longitude': 144.96067754707826,
#  'status': 'Unoccupied'}
# {'_id': 62236,
#  'latitude': -37.817143732618085,
#  'longitude': 144.96114386734132,
#  'status': 'Unoccupied'}
# {'_id': 62235,
#  'latitude': -37.81712214094766,
#  'longitude': 144.96121930871175,
#  'status': 'Unoccupied'}
# {'_id': 61737,
#  'latitude': -37.81382164650383,
#  'longitude': 144.97251252259366,
#  'status': 'Present'}
# {'_id': 61724,
#  'latitude': -37.813874063514234,
#  'longitude': 144.97177959501835,
#  'status': 'Present'}
# {'_id': 61911,
#  'latitude': -37.8148396343282,
#  'longitude': 144.96849391253153,
#  'status': 'Present'}
# {'_id': 61912,
#  'latitude': -37.8148583618696,
#  'longitude': 144.96842999036193,
#  'status': 'Present'}
# {'_id': 61914,
#  'latitude': -37.814895832137886,
#  'longitude': 144.96830203829683,
#  'status': 'Present'}
# {'_id': 61915,
#  'latitude': -37.81491466165707,
#  'longitude': 144.96823782973135,
#  'status': 'Present'}
# {'_id': 61922,
#  'latitude': -37.81504586009345,
#  'longitude': 144.96779000312512,
#  'status': 'Present'}
# {'_id': 61924,
#  'latitude': -37.81508331085854,
#  'longitude': 144.9676622616073,
#  'status': 'Present'}
# {'_id': 61940,
#  'latitude': -37.81492715247235,
#  'longitude': 144.96874994815795,
#  'status': 'Unoccupied'}
# {'_id': 61941,
#  'latitude': -37.81494900164732,
#  'longitude': 144.96867536034765,
#  'status': 'Present'}
# {'_id': 61951,
#  'latitude': -37.815147629452596,
#  'longitude': 144.96799743934574,
#  'status': 'Unoccupied'}
# {'_id': 61950,
#  'latitude': -37.815128610767,
#  'longitude': 144.96806244045393,
#  'status': 'Present'}
# {'_id': 62418,
#  'latitude': -37.81857432698953,
#  'longitude': 144.9556004387088,
#  'status': 'Unoccupied'}
# {'_id': 62417,
#  'latitude': -37.8185561346571,
#  'longitude': 144.95566398621668,
#  'status': 'Present'}
# {'_id': 62415,
#  'latitude': -37.81851813189846,
#  'longitude': 144.95579587661973,
#  'status': 'Present'}
# {'_id': 56911,
#  'latitude': -37.817028328018054,
#  'longitude': 144.95614648347217,
#  'status': 'Present'}
# {'_id': 56928,
#  'latitude': -37.81679658224592,
#  'longitude': 144.9557915530827,
#  'status': 'Unoccupied'}
# {'_id': 56929,
#  'latitude': -37.81674568274913,
#  'longitude': 144.95576852792365,
#  'status': 'Present'}
# {'_id': 56622,
#  'latitude': -37.819877047154925,
#  'longitude': 144.95720891921408,
#  'status': 'Present'}
# {'_id': 56618,
#  'latitude': -37.81954857202497,
#  'longitude': 144.95730605648407,
#  'status': 'Unoccupied'}
# {'_id': 56828,
#  'latitude': -37.81767713241681,
#  'longitude': 144.956195114485,
#  'status': 'Present'}
# {'_id': 57313,
#  'latitude': -37.81303368849585,
#  'longitude': 144.95430777285787,
#  'status': 'Unoccupied'}
# {'_id': 57330,
#  'latitude': -37.81280728602657,
#  'longitude': 144.95395122511678,
#  'status': 'Present'}
# {'_id': 57212,
#  'latitude': -37.81397756150945,
#  'longitude': 144.9547469022172,
#  'status': 'Present'}
# {'_id': 7540,
#  'latitude': -37.80860224835065,
#  'longitude': 144.95891864975522,
#  'status': 'Present'}
# {'_id': 7544,
#  'latitude': -37.80856743824421,
#  'longitude': 144.95903826480014,
#  'status': 'Present'}
# {'_id': 7558,
#  'latitude': -37.80843433398998,
#  'longitude': 144.95949821594064,
#  'status': 'Present'}
# {'_id': 7559,
#  'latitude': -37.80842568164155,
#  'longitude': 144.95952808407958,
#  'status': 'Present'}
# {'_id': 67236,
#  'latitude': -37.81149893338926,
#  'longitude': 144.95755272257927,
#  'status': 'Unoccupied'}
# {'_id': 67325,
#  'latitude': -37.812140156035866,
#  'longitude': 144.95482142738666,
#  'status': 'Present'}
# {'_id': 67331,
#  'latitude': -37.81224916076433,
#  'longitude': 144.9544364035221,
#  'status': 'Unoccupied'}
# {'_id': 67333,
#  'latitude': -37.81228549676049,
#  'longitude': 144.95430806306481,
#  'status': 'Unoccupied'}
# {'_id': 66459,
#  'latitude': -37.81337774058336,
#  'longitude': 144.9547207103931,
#  'status': 'Present'}
# {'_id': 66457,
#  'latitude': -37.81334131863632,
#  'longitude': 144.95484532479395,
#  'status': 'Present'}
# {'_id': 66456,
#  'latitude': -37.813319994155535,
#  'longitude': 144.9549183985641,
#  'status': 'Present'}
# {'_id': 66455,
#  'latitude': -37.813279618467504,
#  'longitude': 144.95505961989613,
#  'status': 'Present'}
# {'_id': 66454,
#  'latitude': -37.81326272176674,
#  'longitude': 144.955118941283,
#  'status': 'Present'}
# {'_id': 66451,
#  'latitude': -37.813207078667304,
#  'longitude': 144.9553145722814,
#  'status': 'Present'}
# {'_id': 67422,
#  'latitude': -37.81283323412847,
#  'longitude': 144.95238038119547,
#  'status': 'Present'}
# {'_id': 67415,
#  'latitude': -37.81269681686551,
#  'longitude': 144.95285983151754,
#  'status': 'Unoccupied'}
# {'_id': 67414,
#  'latitude': -37.81267196765203,
#  'longitude': 144.95294765655223,
#  'status': 'Unoccupied'}
# {'_id': 67412,
#  'latitude': -37.812633480644536,
#  'longitude': 144.95308270383853,
#  'status': 'Present'}
# {'_id': 67453,
#  'latitude': -37.812988759460055,
#  'longitude': 144.95232339104786,
#  'status': 'Present'}
# {'_id': 67452,
#  'latitude': -37.812969695731255,
#  'longitude': 144.9523908473923,
#  'status': 'Present'}
# {'_id': 67451,
#  'latitude': -37.812950802794575,
#  'longitude': 144.95245771177468,
#  'status': 'Present'}
# {'_id': 67445,
#  'latitude': -37.812837262864065,
#  'longitude': 144.95285922753288,
#  'status': 'Present'}
# {'_id': 67441,
#  'latitude': -37.812772145611305,
#  'longitude': 144.95308954233172,
#  'status': 'Present'}
# {'_id': 67440,
#  'latitude': -37.81274806511247,
#  'longitude': 144.95317471577334,
#  'status': 'Present'}
# {'_id': 67435,
#  'latitude': -37.81265649519399,
#  'longitude': 144.95349866861588,
#  'status': 'Unoccupied'}
# {'_id': 54416,
#  'latitude': -37.81354274368513,
#  'longitude': 144.96015603675647,
#  'status': 'Present'}
# {'_id': 60733,
#  'latitude': -37.820641488195506,
#  'longitude': 144.9569432240824,
#  'status': 'Present'}
# {'_id': 51950,
#  'latitude': -37.81313654299781,
#  'longitude': 144.96812582653453,
#  'status': 'Unoccupied'}
# {'_id': 51933,
#  'latitude': -37.81331767384614,
#  'longitude': 144.96833410288292,
#  'status': 'Present'}
# {'_id': 51925,
#  'latitude': -37.81355383064921,
#  'longitude': 144.96844271755066,
#  'status': 'Present'}
# {'_id': 51926,
#  'latitude': -37.81353111706288,
#  'longitude': 144.96843244981244,
#  'status': 'Present'}
# {'_id': 51928,
#  'latitude': -37.81348501062016,
#  'longitude': 144.9684113895476,
#  'status': 'Present'}
# {'_id': 51929,
#  'latitude': -37.81343206116386,
#  'longitude': 144.96838644867847,
#  'status': 'Present'}
# {'_id': 65212,
#  'latitude': -37.81090906486972,
#  'longitude': 144.96662346197735,
#  'status': 'Present'}
# {'_id': 65063,
#  'latitude': -37.80986340442115,
#  'longitude': 144.97051957741644,
#  'status': 'Present'}
# {'_id': 65062,
#  'latitude': -37.80984383399,
#  'longitude': 144.97058642839502,
#  'status': 'Present'}
# {'_id': 65058,
#  'latitude': -37.80980107550256,
#  'longitude': 144.97073220031848,
#  'status': 'Present'}
# {'_id': 65057,
#  'latitude': -37.8097917677008,
#  'longitude': 144.97076399805246,
#  'status': 'Present'}
# {'_id': 65052,
#  'latitude': -37.80972376415039,
#  'longitude': 144.97099638310678,
#  'status': 'Present'}
# {'_id': 65051,
#  'latitude': -37.80968431334239,
#  'longitude': 144.9711311431266,
#  'status': 'Present'}
# {'_id': 65048,
#  'latitude': -37.80965891045284,
#  'longitude': 144.97121818720672,
#  'status': 'Present'}
# {'_id': 65047,
#  'latitude': -37.80964002393621,
#  'longitude': 144.97128242960477,
#  'status': 'Present'}
# {'_id': 65043,
#  'latitude': -37.80959904378582,
#  'longitude': 144.9714224107713,
#  'status': 'Unoccupied'}

# %%
import folium

# %% [markdown]
# Initialize a map at Melbourne.

# %%
fomap = folium.Map(location=[-37.812015244225677, 144.951471202974], zoom_start=15)

# %% [markdown]
# Plot a marker for each vacant parking spot.

# %%
for loc in unoccupiedList:
    folium.Marker(location=loc, popup=f"lat={loc[0]:.2f}, lon={loc[1]:.2f}").add_to(fomap)

# %% [markdown]
# Show the map.

# %%
fomap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_42cce13be8c21b19be2d1bebf8eb30d2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_42cce13be8c21b19be2d1bebf8eb30d2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_42cce13be8c21b19be2d1bebf8eb30d2 = L.map(
#                 &quot;map_42cce13be8c21b19be2d1bebf8eb30d2&quot;,
#                 {
#                     center: [-37.81201524422568, 144.951471202974],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_caee4da8e0e782b6fd851b90cfe5e66b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_caee4da8e0e782b6fd851b90cfe5e66b.addTo(map_42cce13be8c21b19be2d1bebf8eb30d2);
#
#
#             var marker_5e1e1695e263775ae4a10fe37f9b6345 = L.marker(
#                 [-37.80882551342851, 144.97187528239476],
#                 {}
#             ).addTo(map_42cce13be8c21b19be2d1bebf8eb30d2);
#
#
#         var popup_65cb65c352b2638991d8ec119b4cccc8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fade40a166f2f3eae708d7153e846a5b = $(`&lt;div id=&quot;html_fade40a166f2f3eae708d7153e846a5b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lat=-37.81, lon=144.97&lt;/div&gt;`)[0];
#                 popup_65cb65c352b2638991d8ec119b4cccc8.setContent(html_fade40a166f2f3eae708d7153e846a5b);
#
#
#
#         marker_5e1e1695e263775ae4a10fe37f9b6345.bindPopup(popup_65cb65c352b2638991d8ec119b4cccc8)
#         ;
#
#
#
#
#             var marker_6c2d1b9655c0d21d2a9fdae4f6ae991f = L.marker(
#                 [-37.808660179978915, 144.97179932080303],
#                 {}
#             ).addTo(map_42cce13be8c21b19be2d1bebf8eb30d2);
#
#
#         var popup_1b15ac42e6cfa38903c80c087eecc770 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_95016bd3d86ec0afa24396e4f44183e3 = $(`&lt;div id=&quot;html_95016bd3d86ec0afa24396e4f44183e3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lat=-37.81, lon=144.97&lt;/div&gt;`)[0];
#                 popup_1b15ac42e6cfa38903c80c087eecc770.setContent(html_95016bd3d86ec0afa24396e4f44183e3);
#
#
#
#         marker_6c2d1b9655c0d21d2a9fdae4f6ae991f.bindPopup(popup_1b15ac42e6cfa38903c80c087eecc770)
#         ;
#
#
#
#
#             var marker_132ca376b099787cfa8ac183d412341c = L.marker(
#                 [-37.81065243137996, 144.96782988802386],
#                 {}
#             ).addTo(map_42cce13be8c21b19be2d1bebf8eb30d2);
#
#
#         var popup_a4b542c7e83d6248b98e47f2fd5948e0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_63e004fbdaa3f44eb9b18d053aa2f3fc = $(`&lt;div id=&quot;html_63e004fbdaa3f44eb9b18d053aa2f3fc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lat=-37.81, lon=144.97&lt;/div&gt;`)[0];
#                 popup_a4b542c7e83d6248b98e47f2fd5948e0.setContent(html_63e004fbdaa3f44eb9b18d053aa2f3fc);
#
#
#
#         marker_132ca376b099787cfa8ac183d412341c.bindPopup(popup_a4b542c7e83d6248b98e47f2fd5948e0)
#         ;
#
#
#
#
#             var marker_2c4b029f3e3b1a02723a9731cf2b3130 = L.marker(
#                 [-37.81057630472673, 144.9680868422238],
#                 {}
#             ).addTo(map_42cce13be8c21b19be2d1bebf8eb30d2);
#
#
#         var popup_8b4e57ac234f8e102668f7ccd2620dfe = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1fa93c887803ce028033de3493ad9cb1 = $(`&lt;div id=&quot;html_1fa93c887803ce028033de3493ad9cb1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lat=-37.81, lon=144.97&lt;/div&gt;`)[0];
#                 popup_8b4e57ac234f8e102668f7ccd2620dfe.setContent(html_1fa93c887803ce028033de3493ad9cb1);
#
#
#
#         marker_2c4b029f3e3b1a02723a9731cf2b3130.bindPopup(popup_8b4e57ac234f8e102668f7ccd2620dfe)
#         ;
#
#
#
#
#             var marker_e9854eaa5990683ce93e6a0a2dd1b202 = L.marker(
#                 [-37.8105679515687, 144.96811522171183],
#                 {}
#             ).addTo(map_42cce13be8c21b19be2d1bebf8eb30d2);
#
#
#         var popup_999ff1441083c795548aeddbb18ef16e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1634a3c4525d8e1b88c9318830751542 = $(`&lt;div id=&quot;html_1634a3c4525d8e1b88c9318830751542&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lat=-37.81, lon=144.97&lt;/div&gt;`)[0];
#                 popup_999ff1441083c795548aeddbb18ef16e.setContent(html_1634a3c4525d8e1b88c9318830751542);
#
#
#
#         marker_e9854eaa5990683ce93e6a0a2dd1b202.bindPopup(popup_999ff1441083c795548aeddbb18ef16e)
#         ;
#
#
#
#
#             var marker_90512d3c1f824a6ad11

# %% [markdown]
# If you want, you can save the map to a file for later viewing.

# %%
fomap.save('parking-spots.html')
