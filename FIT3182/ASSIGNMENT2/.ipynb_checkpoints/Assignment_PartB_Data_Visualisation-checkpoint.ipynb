# %% [markdown]
# <div style= "text-align: right">
#     <p style= "text-align: right; font-weight: bold; font-size: x-large;">FIT3182 Big Data Management and Processing</p>
#     <p style= "text-align: right; font-weight: bold; font-size: large;">Assignment 2</p>
#     <p style= "text-align: right">Foo Kai Yan</p>
#     <p style= "text-align: right">kfoo0012@student.monash.edu<br><br><i>33085625<br><br><i>22<sup>th</sup> May 2024</i></p>
# <div>
# <hr style="border-color: black;">

# %% [markdown]
# ## Student Statement
# The assignment was completed with the assistance of some code obtained from seminar/tutorial/lab/applied class.

# %% [markdown]
# ### Import required Libraries

# %%
import os
import json
import folium
import pymongo
import datetime as dt
from time import sleep
from pprint import pprint
from kafka3 import KafkaConsumer
import matplotlib.pyplot as plt
from pymongo import MongoClient

# this line is needed for the inline display of graphs in Jupyter Notebook
# %matplotlib notebook

# %% [markdown]
# ### Check working directory

# %%
os.getcwd()
# Out:
# '/home/student/kfoo0012'

# %% [markdown]
# ### Set host ip

# %%
# hostip obtained using `ipconfig` command in command prompt
hostip = "192.168.68.58"

# %% [markdown]
# ### Streaming Data Visualisation

# %%
topic = "Climate"

def connect_kafka_consumer():
    '''
    connect_kafka_consumer function:
    - attempts to connect to a Kafka cluster and create a consumer for a specified predefined topic
    '''
    _consumer = None
    try:
         _consumer = KafkaConsumer(topic,
                                   consumer_timeout_ms=10000, # stop iteration if no message after 10 sec
                                   auto_offset_reset='earliest', # comment this if you don't want to consume earliest available message
                                   bootstrap_servers=[f'{hostip}:9092'],
                                   api_version=(0, 10)) # Sets the Kafka API version that the client will use to communicate with the Kafka cluster
    except Exception as ex:
        print('Exception while connecting Kafka')
        print(str(ex))
    finally:
        return _consumer

def annotate_max(x, y, ax = None):
    '''
    annotate the maximum points on the plot
    '''
    ymax = max(y) # Finds the maximum value in the y dataset
    xpos = y.index(ymax) # Finds the index position of the maximum value in the y dataset
    xmax = x[xpos] # Retrieves the corresponding x-coordinate for the maximum y-value
    text = 'Max: Time={}, Value={}'.format(xmax, ymax)
    if not ax:
        ax=plt.gca() # Get current axes
        
    # To add annotations to a plot.
    # `xy` is to specify the location of the point
    # `xytext` specifies the location of the text
    # `arrowprops` specifies the properties of the arrow
    
    ax.annotate(text, xy=(xmax, ymax), xytext=(xmax, ymax+5), arrowprops=dict(facecolor='red', shrink=0.05),)
    
def annotate_min(x, y, ax = None):
    '''
    annotate the minimum points on the plot
    '''
    ymin = min(y) # Finds the minimum value in the y dataset
    xpos = y.index(ymin) # Finds the index position of the minimum value in the y dataset
    xmin = x[xpos] # Retrieves the corresponding x-coordinate for the minimum y-value
    text = 'Min: Time={}, Value={}'.format(xmin, ymin)
    if not ax:
        ax=plt.gca()
    ax.annotate(text, xy=(xmin, ymin), xytext=(xmin, ymin+5), arrowprops=dict(facecolor='orange', shrink=0.05),)
    
def init_plots():
    try:
        width = 9.5
        height = 6
        fig = plt.figure(figsize=(width,height)) # Create new figure
        ax = fig.add_subplot(111) # Add the subplot axes to the given grid position
        # Sets the title of the figure:
        fig.suptitle('Real-time stream data visualization for Air Temperature against Arrival Time')
        # Set labels for the x-axis and y-axis:
        ax.set_xlabel('Time')
        ax.set_ylabel('Value')
        # Sets the limits of the y-axis to range from 0 to 110:
        ax.set_ylim(0,110) 
        # Specifies the tick marks on the y-axis at intervals of 20 units:
        ax.set_yticks([0, 20, 40, 60, 80, 100])
        fig.show() # Displaying the figure
        fig.canvas.draw() # Drawing on the canvas
        return fig, ax
    except Exception as ex:
        print(str(ex))
        
def consume_messages(consumer, fig, ax):
    try:
        # container for x and y values
        x, y = [], []
        count = 0
        # print('Waiting for messages')
        for message in consumer:
            byte_string = message.value
            #print("MESSAGE: ", message)
            # Decode the byte string to a string
            convert_to_json_str = byte_string.decode('utf-8')
            # Parse the string into a JSON object (dictionary)
            parse_string_data = json.loads(convert_to_json_str)
            # Access the value for producer_id
            producer_id = parse_string_data.get('producer_id')
            
            # search specific producer_id because we only process the climate data
            if producer_id == "producer1_climate": 
                data = message[6].decode("utf-8") # decode because it was encoded in bytes
                data = json.loads(data) # loading into dictionary
                x.append(dt.datetime.now().strftime("%X")) 
                y.append(data.get("air_temperature_celcius"))
                count += 1
                # we start plotting only when we have 10 data points
                if len(y) > 10:
                    ax.clear()
                    ax.plot(x, y)
                    
                    ax.set_xlabel('Arival Time')
                    ax.set_ylabel('Air Temperature (°C)')
                    
                    ax.set_ylim(0,50) 
                    ax.set_yticks([0, 5, 10, 15, 20, 25, 30, 35, 40, 45, 50]) # Manually set the range for Air Temperature
                    
                    annotate_max(x,y)
                    annotate_min(x,y)
                    
                    fig.canvas.draw()
                    
                    x.pop(0) # removing the item in the first position
                    y.pop(0)
        plt.close('all')
    except Exception as ex:
        print(str(ex))
    
if __name__ == '__main__':
    consumer = connect_kafka_consumer()
    fig, ax = init_plots()
    consume_messages(consumer, fig, ax)
# Out:
# <img src="data:image/png;base64,..." width="950">
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=0, timestamp=1716282691688, timestamp_type=0, key=None, value=b'{"latitude": -36.358, "longitude": 143.113, "air_temperature_celcius": 21.0, "relative_humidity": 58.8, "windspeed_knots": 8.8, "max_wind_speed": 22.9, "ghi": 167.0, "precipitation_type": "G", "precipitation": 0.08, "latest_date": "2023-01-01T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=3490249284, serialized_key_size=-1, serialized_value_size=289, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=1, timestamp=1716282701930, timestamp_type=0, key=None, value=b'{"latitude": -37.368, "longitude": 148.05, "air_temperature_celcius": 10.0, "relative_humidity": 41.4, "windspeed_knots": 9.4, "max_wind_speed": 14.0, "ghi": 92.0, "precipitation_type": "I", "precipitation": 0.0, "latest_date": "2023-01-02T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=2879978846, serialized_key_size=-1, serialized_value_size=286, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=2, timestamp=1716282711945, timestamp_type=0, key=None, value=b'{"latitude": -36.939, "longitude": 143.28, "air_temperature_celcius": 20.0, "relative_humidity": 67.4, "windspeed_knots": 8.5, "max_wind_speed": 14.0, "ghi": 147.0, "precipitation_type": "G", "precipitation": 0.63, "latest_date": "2023-01-03T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=2022637805, serialized_key_size=-1, serialized_value_size=288, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=3, timestamp=1716282721965, timestamp_type=0, key=None, value=b'{"latitude": -37.478, "longitude": 148.117, "air_temperature_celcius": 11.0, "relative_humidity": 43.9, "windspeed_knots": 11.2, "max_wind_speed": 16.9, "ghi": 99.0, "precipitation_type": "G", "precipitation": 0.12, "latest_date": "2023-01-04T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=2895602437, serialized_key_size=-1, serialized_value_size=289, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=4, timestamp=1716282731978, timestamp_type=0, key=None, value=b'{"latitude": -37.8088, "longitude": 142.2291, "air_temperature_celcius": 11.0, "relative_humidity": 40.8, "windspeed_knots": 6.4, "max_wind_speed": 8.9, "ghi": 102.0, "precipitation_type": "G", "precipitation": 0.0, "latest_date": "2023-01-05T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=3427621994, serialized_key_size=-1, serialized_value_size=289, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=5, timestamp=1716282741989, timestamp_type=0, key=None, value=b'{"latitude": -37.6008, "longitude": 143.0558, "air_temperature_celcius": 15.0, "relative_humidity": 44.8, "windspeed_knots": 8.3, "max_wind_speed": 19.0, "ghi": 134.0, "precipitation_type": "I", "precipitation": 0.0, "latest_date": "2023-01-06T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=805508915, serialized_key_size=-1, serialized_value_size=290, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=6, timestamp=1716282752006, timestamp_type=0, key=None, value=b'{"latitude": -37.437, "longitude": 148.104, "air_temperature_celcius": 12.0, "relative_humidity": 40.7, "windspeed_knots": 16.7, "max_wind_speed": 21.0, "ghi": 111.0, "precipitation_type": "G", "precipitation": 0.12, "latest_date": "2023-01-07T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=554215838, serialized_key_size=-1, serialized_value_size=290, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=7, timestamp=1716282789182, timestamp_type=0, key=None, value=b'{"latitude": -35.325, "longitude": 143.497, "air_temperature_celcius": 13.0, "relative_humidity": 48.5, "windspeed_knots": 5.3, "max_wind_speed": 11.1, "ghi": 113.0, "precipitation_type": "G", "precipitation": 0.08, "latest_date": "2023-01-01T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=2673324472, serialized_key_size=-1, serialized_value_size=289, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=8, timestamp=1716282799198, timestamp_type=0, key=None, value=b'{"latitude": -36.285, "longitude": 146.151, "air_temperature_celcius": 19.0, "relative_humidity": 56.3, "windspeed_knots": 5.8, "max_wind_speed": 8.9, "ghi": 154.0, "precipitation_type": "I", "precipitation": 0.0, "latest_date": "2023-01-02T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=528330422, serialized_key_size=-1, serialized_value_size=287, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=9, timestamp=1716282809215, timestamp_type=0, key=None, value=b'{"latitude": -36.6516, "longitude": 141.4943, "air_temperature_celcius": 11.0, "relative_humidity": 45.3, "windspeed_knots": 8.5, "max_wind_speed": 15.0, "ghi": 98.0, "precipitation_type": "G", "precipitation": 0.0, "latest_date": "2023-01-03T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=1300395703, serialized_key_size=-1, serialized_value_size=289, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=10, timestamp=1716282819230, timestamp_type=0, key=None, value=b'{"latitude": -37.57, "longitude": 148.034, "air_temperature_celcius": 11.0, "relative_humidity": 40.4, "windspeed_knots": 19.3, "max_wind_speed": 26.0, "ghi": 102.0, "precipitation_type": "G", "precipitation": 0.0, "latest_date": "2023-01-04T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=1810908227, serialized_key_size=-1, serialized_value_size=288, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=11, timestamp=1716282829246, timestamp_type=0, key=None, value=b'{"latitude": -37.463, "longitude": 148.109, "air_temperature_celcius": 11.0, "relative_humidity": 45.1, "windspeed_knots": 5.6, "max_wind_speed": 9.9, "ghi": 98.0, "precipitation_type": "I", "precipitation": 0.0, "latest_date": "2023-01-05T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=788993636, serialized_key_size=-1, serialized_value_size=286, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=12, timestamp=1716297584717, timestamp_type=0, key=None, value=b'{"latitude": -37.856, "longitude": 143.416, "air_temperature_celcius": 14.0, "relative_humidity": 51.0, "windspeed_knots": 9.1, "max_wind_speed": 12.0, "ghi": 119.0, "precipitation_type": "G", "precipitation": 0.0, "latest_date": "2023-01-01T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=3054601348, serialized_key_size=-1, serialized_value_size=288, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=13, timestamp=1716297595236, timestamp_type=0, key=None, value=b'{"latitude": -37.9243, "longitude": 144.1064, "air_temperature_celcius": 17.0, "relative_humidity": 53.0, "windspeed_knots": 14.6, "max_wind_speed": 22.9, "ghi": 142.0, "precipitation_type": "I", "precipitation": 0.0, "latest_date": "2023-01-02T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=2626283029, serialized_key_size=-1, serialized_value_size=291, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=14, timestamp=1716297605254, timestamp_type=0, key=None, value=b'{"latitude": -37.692, "longitude": 143.593, "air_temperature_celcius": 14.0, "relative_humidity": 45.8, "windspeed_knots": 6.5, "max_wind_speed": 9.9, "ghi": 124.0, "precipitation_type": "G", "precipitation": 0.0, "latest_date": "2023-01-03T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=2899692048, serialized_key_size=-1, serialized_value_size=287, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=15, timestamp=1716297615265, timestamp_type=0, key=None, value=b'{"latitude": -37.229, "longitude": 141.182, "air_temperature_celcius": 8.0, "relative_humidity": 44.5, "windspeed_knots": 4.7, "max_wind_speed": 7.0, "ghi": 72.0, "precipitation_type": "G", "precipitation": 0.01, "latest_date": "2023-01-04T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=683122894, serialized_key_size=-1, serialized_value_size=286, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=16, timestamp=1716297625279, timestamp_type=0, key=None, value=b'{"latitude": -34.282, "longitude": 142.121, "air_temperature_celcius": 15.0, "relative_humidity": 49.1, "windspeed_knots": 9.6, "max_wind_speed": 16.9, "ghi": 130.0, "precipitation_type": "G", "precipitation": 0.01, "latest_date": "2023-01-05T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=1623458435, serialized_key_size=-1, serialized_value_size=289, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=17, timestamp=1716297635296, timestamp_type=0, key=None, value=b'{"latitude": -37.559, "longitude": 148.037, "air_temperature_celcius": 9.0, "relative_humidity": 41.1, "windspeed_knots": 12.7, "max_wind_speed": 19.0, "ghi": 83.0, "precipitation_type": "G", "precipitation": 0.24, "latest_date": "2023-01-06T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=1668699742, serialized_key_size=-1, serialized_value_size=288, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=18, timestamp=1716297645312, timestamp_type=0, key=None, value=b'{"latitude": -35.892, "longitude": 145.62, "air_temperature_celcius": 10.0, "relative_humidity": 42.6, "windspeed_knots": 8.9, "max_wind_speed": 15.0, "ghi": 91.0, "precipitation_type": "G", "precipitation": 0.04, "latest_date": "2023-01-07T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=1025770008, serialized_key_size=-1, serialized_value_size=287, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=19, timestamp=1716297655326, timestamp_type=0, key=None, value=b'{"latitude": -36.748, "longitude": 144.168, "air_temperature_celcius": 11.0, "relative_humidity": 48.2, "windspeed_knots": 10.8, "max_wind_speed": 22.9, "ghi": 96.0, "precipitation_type": "G", "precipitation": 0.59, "latest_date": "2023-01-08T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=3277931470, serialized_key_size=-1, serialized_value_size=289, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=20, timestamp=1716297665343, timestamp_type=0, key=None, value=b'{"latitude": -37.434, "longitude": 148.091, "air_temperature_celcius": 9.0, "relative_humidity": 40.0, "windspeed_knots": 8.6, "max_wind_speed": 15.0, "ghi": 84.0, "precipitation_type": "G", "precipitation": 0.0, "latest_date": "2023-01-09T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=482742361, serialized_key_size=-1, serialized_value_size=286, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=21, timestamp=1716297675360, timestamp_type=0, key=None, value=b'{"latitude": -38.231, "longitude": 147.172, "air_temperature_celcius": 24.0, "relative_humidity": 61.6, "windspeed_knots": 7.7, "max_wind_speed": 14.0, "ghi": 186.0, "precipitation_type": "I", "precipitation": 0.0, "latest_date": "2023-01-10T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=2130715718, serialized_key_size=-1, serialized_value_size=288, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=22, timestamp=1716297685366, timestamp_type=0, key=None, value=b'{"latitude": -36.778, "longitude": 145.1635, "air_temperature_celcius": 17.0, "relative_humidity": 46.3, "windspeed_knots": 11.7, "max_wind_speed": 20.0, "ghi": 150.0, "precipitation_type": "G", "precipitation": 0.02, "latest_date": "2023-01-11T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=2603644175, serialized_key_size=-1, serialized_value_size=291, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=23, timestamp=1716297695381, timestamp_type=0, key=None, value=b'{"latitude": -37.375, "longitude": 148.063, "air_temperature_celcius": 10.0, "relative_humidity": 43.5, "windspeed_knots": 12.0, "max_wind_speed": 16.9, "ghi": 90.0, "precipitation_type": "G", "precipitation": 0.04, "latest_date": "2023-01-12T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=600939113, serialized_key_size=-1, serialized_value_size=289, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=24, timestamp=1716297705393, timestamp_type=0, key=None, value=b'{"latitude": -36.418, "longitude": 141.596, "air_temperature_celcius": 14.0, "relative_humidity": 50.1, "windspeed_knots": 8.7, "max_wind_speed": 15.0, "ghi": 120.0, "precipitation_type": "G", "precipitation": 0.0, "latest_date": "2023-01-13T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=2940273006, serialized_key_size=-1, serialized_value_size=288, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=25, timestamp=1716297715404, timestamp_type=0, key=None, value=b'{"latitude": -36.952, "longitude": 144.972, "air_temperature_celcius": 21.0, "relative_humidity": 57.3, "windspeed_knots": 5.4, "max_wind_speed": 9.9, "ghi": 169.0, "precipitation_type": "I", "precipitation": 0.0, "latest_date": "2023-01-14T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=3038194318, serialized_key_size=-1, serialized_value_size=287, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=26, timestamp=1716297725433, timestamp_type=0, key=None, value=b'{"latitude": -37.8088, "longitude": 142.2291, "air_temperature_celcius": 11.0, "relative_humidity": 40.8, "windspeed_knots": 6.4, "max_wind_speed": 8.9, "ghi": 102.0, "precipitation_type": "G", "precipitation": 0.0, "latest_date": "2023-01-15T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=50009397, serialized_key_size=-1, serialized_value_size=289, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=27, timestamp=1716297735443, timestamp_type=0, key=None, value=b'{"latitude": -36.0201, "longitude": 143.7775, "air_temperature_celcius": 18.0, "relative_humidity": 55.6, "windspeed_knots": 8.2, "max_wind_speed": 12.0, "ghi": 147.0, "precipitation_type": "I", "precipitation": 0.0, "latest_date": "2023-01-16T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=1967021000, serialized_key_size=-1, serialized_value_size=290, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=28, timestamp=1716297745457, timestamp_type=0, key=None, value=b'{"latitude": -37.444, "longitude": 148.101, "air_temperature_celcius": 9.0, "relative_humidity": 42.0, "windspeed_knots": 4.6, "max_wind_speed": 12.0, "ghi": 82.0, "precipitation_type": "I", "precipitation": 0.0, "latest_date": "2023-01-17T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=142617252, serialized_key_size=-1, serialized_value_size=286, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=29, timestamp=1716297755477, timestamp_type=0, key=None, value=b'{"latitude": -36.4274, "longitude": 142.1944, "air_temperature_celcius": 22.0, "relative_humidity": 46.9, "windspeed_knots": 12.9, "max_wind_speed": 19.0, "ghi": 193.0, "precipitation_type": "I", "precipitation": 0.0, "latest_date": "2023-01-18T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=3507387424, serialized_key_size=-1, serialized_value_size=291, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=30, timestamp=1716297765493, timestamp_type=0, key=None, value=b'{"latitude": -37.758, "longitude": 144.693, "air_temperature_celcius": 20.0, "relative_humidity": 58.8, "windspeed_knots": 11.5, "max_wind_speed": 15.9, "ghi": 159.0, "precipitation_type": "I", "precipitation": 0.0, "latest_date": "2023-01-19T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=2861127951, serialized_key_size=-1, serialized_value_size=289, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=31, timestamp=1716297775507, timestamp_type=0, key=None, value=b'{"latitude": -36.291, "longitude": 146.159, "air_temperature_celcius": 24.0, "relative_humidity": 55.4, "windspeed_knots": 5.9, "max_wind_speed": 9.9, "ghi": 196.0, "precipitation_type": "I", "precipitation": 0.0, "latest_date": "2023-01-20T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=3235876465, serialized_key_size=-1, serialized_value_size=287, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=32, timestamp=1716297785530, timestamp_type=0, key=None, value=b'{"latitude": -36.275, "longitude": 146.154, "air_temperature_celcius": 18.0, "relative_humidity": 53.3, "windspeed_knots": 7.9, "max_wind_speed": 14.0, "ghi": 150.0, "precipitation_type": "I", "precipitation": 0.0, "latest_date": "2023-01-21T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=3246941954, serialized_key_size=-1, serialized_value_size=288, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=33, timestamp=1716297795543, timestamp_type=0, key=None, value=b'{"latitude": -35.323, "longitude": 143.509, "air_temperature_celcius": 15.0, "relative_humidity": 49.3, "windspeed_knots": 3.6, "max_wind_speed": 7.0, "ghi": 129.0, "precipitation_type": "I", "precipitation": 0.0, "latest_date": "2023-01-22T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=1867372947, serialized_key_size=-1, serialized_value_size=287, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=34, timestamp=1716297805561, timestamp_type=0, key=None, value=b'{"latitude": -36.0005, "longitude": 143.1847, "air_temperature_celcius": 17.0, "relative_humidity": 52.5, "windspeed_knots": 7.7, "max_wind_speed": 16.9, "ghi": 143.0, "precipitation_type": "I", "precipitation": 0.0, "latest_date": "2023-01-23T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=3918949759, serialized_key_size=-1, serialized_value_size=290, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=35, timestamp=1716297815577, timestamp_type=0, key=None, value=b'{"latitude": -37.46, "longitude": 148.113, "air_temperature_celcius": 11.0, "relative_humidity": 44.2, "windspeed_knots": 8.7, "max_wind_speed": 15.9, "ghi": 99.0, "precipitation_type": "G", "precipitation": 0.04, "latest_date": "2023-01-24T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=1993074860, serialized_key_size=-1, serialized_value_size=287, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=36, timestamp=1716297825593, timestamp_type=0, key=None, value=b'{"latitude": -36.1462, "longitude": 145.2096, "air_temperature_celcius": 10.0, "relative_humidity": 43.6, "windspeed_knots": 9.7, "max_wind_speed": 14.0, "ghi": 90.0, "precipitation_type": "G", "precipitation": 0.2, "latest_date": "2023-01-25T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=1381619619, serialized_key_size=-1, serialized_value_size=289, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=37, timestamp=1716297835613, timestamp_type=0, key=None, value=b'{"latitude": -36.0005, "longitude": 143.1847, "air_temperature_celcius": 17.0, "relative_humidity": 52.5, "windspeed_knots": 7.7, "max_wind_speed": 16.9, "ghi": 143.0, "precipitation_type": "I", "precipitation": 0.0, "latest_date": "2023-01-26T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=2169273677, serialized_key_size=-1, serialized_value_size=290, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=38, timestamp=1716297845635, timestamp_type=0, key=None, value=b'{"latitude": -37.327, "longitude": 148.083, "air_temperature_celcius": 10.0, "relative_humidity": 44.8, "windspeed_knots": 8.8, "max_wind_speed": 14.0, "ghi": 89.0, "precipitation_type": "G", "precipitation": 0.39, "latest_date": "2023-01-27T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=612627228, serialized_key_size=-1, serialized_value_size=288, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=39, timestamp=1716297855651, timestamp_type=0, key=None, value=b'{"latitude": -37.444, "longitude": 148.101, "air_temperature_celcius": 9.0, "relative_humidity": 42.0, "windspeed_knots": 4.6, "max_wind_speed": 12.0, "ghi": 82.0, "precipitation_type": "I", "precipitation": 0.0, "latest_date": "2023-01-28T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=3439972929, serialized_key_size=-1, serialized_value_size=286, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=40, timestamp=1716297865668, timestamp_type=0, key=None, value=b'{"latitude": -37.6836, "longitude": 142.6069, "air_temperature_celcius": 13.0, "relative_humidity": 38.4, "windspeed_knots": 11.5, "max_wind_speed": 16.9, "ghi": 122.0, "precipitation_type": "G", "precipitation": 0.0, "latest_date": "2023-01-29T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=2346923259, serialized_key_size=-1, serialized_value_size=291, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=41, timestamp=1716297875683, timestamp_type=0, key=None, value=b'{"latitude": -36.398, "longitude": 145.286, "air_temperature_celcius": 11.0, "relative_humidity": 45.1, "windspeed_knots": 11.5, "max_wind_speed": 18.1, "ghi": 98.0, "precipitation_type": "G", "precipitation": 0.2, "latest_date": "2023-01-30T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=708656443, serialized_key_size=-1, serialized_value_size=288, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=42, timestamp=1716297885695, timestamp_type=0, key=None, value=b'{"latitude": -37.446, "longitude": 148.102, "air_temperature_celcius": 10.0, "relative_humidity": 39.4, "windspeed_knots": 9.6, "max_wind_speed": 14.0, "ghi": 93.0, "precipitation_type": "G", "precipitation": 0.0, "latest_date": "2023-01-31T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=52349961, serialized_key_size=-1, serialized_value_size=287, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=43, timestamp=1716297895703, timestamp_type=0, key=None, value=b'{"latitude": -37.368, "longitude": 148.05, "air_temperature_celcius": 10.0, "relative_humidity": 41.4, "windspeed_knots": 9.4, "max_wind_speed": 14.0, "ghi": 92.0, "precipitation_type": "I", "precipitation": 0.0, "latest_date": "2023-02-01T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=163994650, serialized_key_size=-1, serialized_value_size=286, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=44, timestamp=1716297905714, timestamp_type=0, key=None, value=b'{"latitude": -36.1, "longitude": 143.772, "air_temperature_celcius": 18.0, "relative_humidity": 58.9, "windspeed_knots": 5.5, "max_wind_speed": 14.0, "ghi": 143.0, "precipitation_type": "G", "precipitation": 0.08, "latest_date": "2023-02-02T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=3427169198, serialized_key_size=-1, serialized_value_size=287, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=45, timestamp=1716297915728, timestamp_type=0, key=None, value=b'{"latitude": -37.945, "longitude": 144.354, "air_temperature_celcius": 24.0, "relative_humidity": 55.6, "windspeed_knots": 5.9, "max_wind_speed": 13.0, "ghi": 196.0, "precipitation_type": "I", "precipitation": 0.0, "latest_date": "2023-02-03T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=3091938506, serialized_key_size=-1, serialized_value_size=288, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=46, timestamp=1716297925743, timestamp_type=0, key=None, value=b'{"latitude": -36.1858, "longitude": 143.885, "air_temperature_celcius": 20.0, "relative_humidity": 58.4, "windspeed_knots": 4.7, "max_wind_speed": 11.1, "ghi": 159.0, "precipitation_type": "G", "precipitation": 0.01, "latest_date": "2023-02-04T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=2190194431, serialized_key_size=-1, serialized_value_size=290, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=47, timestamp=1716297935757, timestamp_type=0, key=None, value=b'{"latitude": -37.087, "longitude": 145.363, "air_temperature_celcius": 13.0, "relative_humidity": 49.4, "windspeed_knots": 3.8, "max_wind_speed": 9.9, "ghi": 112.0, "precipitation_type": "G", "precipitation": 0.01, "latest_date": "2023-02-05T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=1171831754, serialized_key_size=-1, serialized_value_size=288, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=48, timestamp=1716297945773, timestamp_type=0, key=None, value=b'{"latitude": -37.434, "longitude": 148.091, "air_temperature_celcius": 9.0, "relative_humidity": 40.0, "windspeed_knots": 8.6, "max_wind_speed": 15.0, "ghi": 84.0, "precipitation_type": "G", "precipitation": 0.0, "latest_date": "2023-02-06T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=107917060, serialized_key_size=-1, serialized_value_size=286, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=49, timestamp=1716297955783, timestamp_type=0, key=None, value=b'{"latitude": -37.63, "longitude": 149.232, "air_temperature_celcius": 18.0, "relative_humidity": 57.0, "windspeed_knots": 7.4, "max_wind_speed": 15.0, "ghi": 145.0, "precipitation_type": "I", "precipitation": 0.0, "latest_date": "2023-02-07T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=1618429816, serialized_key_size=-1, serialized_value_size=287, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=50, timestamp=1716297965792, timestamp_type=0, key=None, value=b'{"latitude": -38.116, "longitude": 143.818, "air_temperature_celcius": 10.0, "relative_humidity": 46.8, "windspeed_knots": 5.3, "max_wind_speed": 9.9, "ghi": 88.0, "precipitation_type": "I", "precipitation": 0.0, "latest_date": "2023-02-08T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=4120202465, serialized_key_size=-1, serialized_value_size=286, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=51, timestamp=1716297975811, timestamp_type=0, key=None, value=b'{"latitude": -37.538, "longitude": 148.895, "air_temperature_celcius": 6.0, "relative_humidity": 37.1, "windspeed_knots": 5.8, "max_wind_speed": 9.9, "ghi": 57.0, "precipitation_type": "I", "precipitation": 0.0, "latest_date": "2023-02-09T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=744200664, serialized_key_size=-1, serialized_value_size=285, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=52, timestamp=1716297985822, timestamp_type=0, key=None, value=b'{"latitude": -37.3847, "longitude": 142.8935, "air_temperature_celcius": 20.0, "relative_humidity": 43.6, "windspeed_knots": 10.3, "max_wind_speed": 15.0, "ghi": 181.0, "precipitation_type": "I", "precipitation": 0.0, "latest_date": "2023-02-10T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=1872158108, serialized_key_size=-1, serialized_value_size=291, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=53, timestamp=1716297995843, timestamp_type=0, key=None, value=b'{"latitude": -37.46, "longitude": 148.113, "air_temperature_celcius": 11.0, "relative_humidity": 44.2, "windspeed_knots": 8.7, "max_wind_speed": 15.9, "ghi": 99.0, "precipitation_type": "G", "precipitation": 0.04, "latest_date": "2023-02-11T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=4001497193, serialized_key_size=-1, serialized_value_size=287, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=54, timestamp=1716298127277, timestamp_type=0, key=None, value=b'{"latitude": -36.758, "longitude": 145.19, "air_temperature_celcius": 20.0, "relative_humidity": 58.4, "windspeed_knots": 6.1, "max_wind_speed": 11.1, "ghi": 159.0, "precipitation_type": "I", "precipitation": 0.0, "latest_date": "2023-01-01T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=2008187219, serialized_key_size=-1, serialized_value_size=287, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=55, timestamp=1716298137289, timestamp_type=0, key=None, value=b'{"latitude": -37.401, "longitude": 148.067, "air_temperature_celcius": 13.0, "relative_humidity": 42.5, "windspeed_knots": 14.0, "max_wind_speed": 19.0, "ghi": 118.0, "precipitation_type": "G", "precipitation": 0.04, "latest_date": "2023-01-02T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=4152263884, serialized_key_size=-1, serialized_value_size=290, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=56, timestamp=1716298147303, timestamp_type=0, key=None, value=b'{"latitude": -37.7836, "longitude": 141.4711, "air_temperature_celcius": 12.0, "relative_humidity": 44.5, "windspeed_knots": 11.1, "max_wind_speed": 15.0, "ghi": 108.0, "precipitation_type": "G", "precipitation": 0.0, "latest_date": "2023-01-03T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=1475892449, serialized_key_size=-1, serialized_value_size=291, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=57, timestamp=1716298157319, timestamp_type=0, key=None, value=b'{"latitude": -36.3823, "longitude": 141.3146, "air_temperature_celcius": 10.0, "relative_humidity": 43.7, "windspeed_knots": 9.5, "max_wind_speed": 13.0, "ghi": 90.0, "precipitation_type": "G", "precipitation": 0.08, "latest_date": "2023-01-04T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=2757855423, serialized_key_size=-1, serialized_value_size=290, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=58, timestamp=1716298167341, timestamp_type=0, key=None, value=b'{"latitude": -36.6732, "longitude": 142.5162, "air_temperature_celcius": 19.0, "relative_humidity": 53.9, "windspeed_knots": 8.3, "max_wind_speed": 14.0, "ghi": 158.0, "precipitation_type": "I", "precipitation": 0.0, "latest_date": "2023-01-05T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=910742784, serialized_key_size=-1, serialized_value_size=290, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=59, timestamp=1716298177349, timestamp_type=0, key=None, value=b'{"latitude": -37.467, "longitude": 143.351, "air_temperature_celcius": 17.0, "relative_humidity": 53.4, "windspeed_knots": 9.4, "max_wind_speed": 25.1, "ghi": 142.0, "precipitation_type": "G", "precipitation": 0.16, "latest_date": "2023-01-06T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=2385160273, serialized_key_size=-1, serialized_value_size=289, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=60, timestamp=1716298187359, timestamp_type=0, key=None, value=b'{"latitude": -37.587, "longitude": 142.479, "air_temperature_celcius": 12.0, "relative_humidity": 45.1, "windspeed_knots": 11.9, "max_wind_speed": 18.1, "ghi": 107.0, "precipitation_type": "G", "precipitation": 0.16, "latest_date": "2023-01-07T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=2969375403, serialized_key_size=-1, serialized_value_size=290, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=61, timestamp=1716298197376, timestamp_type=0, key=None, value=b'{"latitude": -37.8387, "longitude": 144.6301, "air_temperature_celcius": 11.0, "relative_humidity": 41.4, "windspeed_knots": 7.7, "max_wind_speed": 15.0, "ghi": 101.0, "precipitation_type": "G", "precipitation": 0.03, "latest_date": "2023-01-08T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=3204040091, serialized_key_size=-1, serialized_value_size=291, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=62, timestamp=1716298207391, timestamp_type=0, key=None, value=b'{"latitude": -37.363, "longitude": 148.06, "air_temperature_celcius": 11.0, "relative_humidity": 35.3, "windspeed_knots": 18.2, "max_wind_speed": 25.1, "ghi": 106.0, "precipitation_type": "I", "precipitation": 0.0, "latest_date": "2023-01-09T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=3246206830, serialized_key_size=-1, serialized_value_size=288, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=63, timestamp=1716298217403, timestamp_type=0, key=None, value=b'{"latitude": -37.425, "longitude": 148.107, "air_temperature_celcius": 15.0, "relative_humidity": 41.2, "windspeed_knots": 13.8, "max_wind_speed": 16.9, "ghi": 138.0, "precipitation_type": "G", "precipitation": 0.0, "latest_date": "2023-01-10T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=358296708, serialized_key_size=-1, serialized_value_size=289, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=64, timestamp=1716298227418, timestamp_type=0, key=None, value=b'{"latitude": -37.8088, "longitude": 142.2291, "air_temperature_celcius": 11.0, "relative_humidity": 40.8, "windspeed_knots": 6.4, "max_wind_speed": 8.9, "ghi": 102.0, "precipitation_type": "G", "precipitation": 0.0, "latest_date": "2023-01-11T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=2102533929, serialized_key_size=-1, serialized_value_size=289, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=65, timestamp=1716298237429, timestamp_type=0, key=None, value=b'{"latitude": -37.332, "longitude": 143.375, "air_temperature_celcius": 21.0, "relative_humidity": 51.7, "windspeed_knots": 7.2, "max_wind_speed": 13.0, "ghi": 177.0, "precipitation_type": "I", "precipitation": 0.0, "latest_date": "2023-01-12T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=528738762, serialized_key_size=-1, serialized_value_size=288, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=66, timestamp=1716298247440, timestamp_type=0, key=None, value=b'{"latitude": -37.602, "longitude": 149.295, "air_temperature_celcius": 17.0, "relative_humidity": 50.8, "windspeed_knots": 9.0, "max_wind_speed": 15.9, "ghi": 145.0, "precipitation_type": "G", "precipitation": 0.0, "latest_date": "2023-01-13T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=4259079382, serialized_key_size=-1, serialized_value_size=288, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=67, timestamp=1716298257456, timestamp_type=0, key=None, value=b'{"latitude": -36.6296, "longitude": 142.5191, "air_temperature_celcius": 28.0, "relative_humidity": 49.9, "windspeed_knots": 11.0, "max_wind_speed": 19.0, "ghi": 240.0, "precipitation_type": "I", "precipitation": 0.0, "latest_date": "2023-01-14T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=923004789, serialized_key_size=-1, serialized_value_size=291, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=68, timestamp=1716298267470, timestamp_type=0, key=None, value=b'{"latitude": -36.8835, "longitude": 142.2098, "air_temperature_celcius": 11.0, "relative_humidity": 41.6, "windspeed_knots": 7.9, "max_wind_speed": 15.0, "ghi": 101.0, "precipitation_type": "G", "precipitation": 0.01, "latest_date": "2023-01-15T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=758038857, serialized_key_size=-1, serialized_value_size=291, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=69, timestamp=1716298277483, timestamp_type=0, key=None, value=b'{"latitude": -37.858, "longitude": 143.428, "air_temperature_celcius": 13.0, "relative_humidity": 50.4, "windspeed_knots": 7.9, "max_wind_speed": 14.0, "ghi": 111.0, "precipitation_type": "I", "precipitation": 0.0, "latest_date": "2023-01-16T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=128175119, serialized_key_size=-1, serialized_value_size=288, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=70, timestamp=1716298287496, timestamp_type=0, key=None, value=b'{"latitude": -37.293, "longitude": 141.245, "air_temperature_celcius": 10.0, "relative_humidity": 45.7, "windspeed_knots": 3.7, "max_wind_speed": 8.0, "ghi": 89.0, "precipitation_type": "G", "precipitation": 0.01, "latest_date": "2023-01-17T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=1588986969, serialized_key_size=-1, serialized_value_size=287, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=71, timestamp=1716298297509, timestamp_type=0, key=None, value=b'{"latitude": -36.341, "longitude": 143.636, "air_temperature_celcius": 16.0, "relative_humidity": 47.5, "windspeed_knots": 5.4, "max_wind_speed": 12.0, "ghi": 140.0, "precipitation_type": "I", "precipitation": 0.0, "latest_date": "2023-01-18T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=195632617, serialized_key_size=-1, serialized_value_size=288, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=72, timestamp=1716298307522, timestamp_type=0, key=None, value=b'{"latitude": -37.335, "longitude": 148.064, "air_temperature_celcius": 8.0, "relative_humidity": 41.0, "windspeed_knots": 11.0, "max_wind_speed": 16.9, "ghi": 74.0, "precipitation_type": "G", "precipitation": 0.47, "latest_date": "2023-01-19T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=1526169011, serialized_key_size=-1, serialized_value_size=288, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=73, timestamp=1716298317533, timestamp_type=0, key=None, value=b'{"latitude": -38.141, "longitude": 143.183, "air_temperature_celcius": 23.0, "relative_humidity": 54.1, "windspeed_knots": 5.7, "max_wind_speed": 14.0, "ghi": 190.0, "precipitation_type": "I", "precipitation": 0.0, "latest_date": "2023-01-20T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=777910426, serialized_key_size=-1, serialized_value_size=288, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=74, timestamp=1716298327551, timestamp_type=0, key=None, value=b'{"latitude": -37.0667, "longitude": 143.0582, "air_temperature_celcius": 11.0, "relative_humidity": 39.7, "windspeed_knots": 11.8, "max_wind_speed": 19.0, "ghi": 102.0, "precipitation_type": "G", "precipitation": 0.28, "latest_date": "2023-01-21T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=2704080763, serialized_key_size=-1, serialized_value_size=292, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=75, timestamp=1716298337565, timestamp_type=0, key=None, value=b'{"latitude": -37.062, "longitude": 141.373, "air_temperature_celcius": 22.0, "relative_humidity": 46.8, "windspeed_knots": 8.0, "max_wind_speed": 16.9, "ghi": 194.0, "precipitation_type": "I", "precipitation": 0.0, "latest_date": "2023-01-22T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=1137410641, serialized_key_size=-1, serialized_value_size=288, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=76, timestamp=1716298347581, timestamp_type=0, key=None, value=b'{"latitude": -37.249, "longitude": 143.413, "air_temperature_celcius": 14.0, "relative_humidity": 47.9, "windspeed_knots": 5.3, "max_wind_speed": 9.9, "ghi": 122.0, "precipitation_type": "I", "precipitation": 0.0, "latest_date": "2023-01-23T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=4283889005, serialized_key_size=-1, serialized_value_size=287, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=77, timestamp=1716298357599, timestamp_type=0, key=None, value=b'{"latitude": -36.7685, "longitude": 142.7134, "air_temperature_celcius": 14.0, "relative_humidity": 48.2, "windspeed_knots": 12.5, "max_wind_speed": 19.0, "ghi": 122.0, "precipitation_type": "G", "precipitation": 0.03, "latest_date": "2023-01-24T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=810202817, serialized_key_size=-1, serialized_value_size=292, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=78, timestamp=1716298367618, timestamp_type=0, key=None, value=b'{"latitude": -37.0046, "longitude": 141.8047, "air_temperature_celcius": 10.0, "relative_humidity": 41.4, "windspeed_knots": 6.9, "max_wind_speed": 8.9, "ghi": 92.0, "precipitation_type": "G", "precipitation": 0.0, "latest_date": "2023-01-25T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=1786438097, serialized_key_size=-1, serialized_value_size=288, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=79, timestamp=1716298377629, timestamp_type=0, key=None, value=b'{"latitude": -37.602, "longitude": 149.311, "air_temperature_celcius": 14.0, "relative_humidity": 48.5, "windspeed_knots": 7.3, "max_wind_speed": 14.0, "ghi": 122.0, "precipitation_type": "G", "precipitation": 0.0, "latest_date": "2023-01-26T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=2675008969, serialized_key_size=-1, serialized_value_size=288, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=80, timestamp=1716298387647, timestamp_type=0, key=None, value=b'{"latitude": -36.3774, "longitude": 143.7079, "air_temperature_celcius": 11.0, "relative_humidity": 43.2, "windspeed_knots": 8.1, "max_wind_speed": 14.0, "ghi": 100.0, "precipitation_type": "G", "precipitation": 0.2, "latest_date": "2023-01-27T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=4174172061, serialized_key_size=-1, serialized_value_size=290, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=81, timestamp=1716298397659, timestamp_type=0, key=None, value=b'{"latitude": -36.765, "longitude": 144.176, "air_temperature_celcius": 16.0, "relative_humidity": 54.9, "windspeed_knots": 5.9, "max_wind_speed": 9.9, "ghi": 132.0, "precipitation_type": "I", "precipitation": 0.0, "latest_date": "2023-01-28T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=756040459, serialized_key_size=-1, serialized_value_size=287, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=82, timestamp=1716298407679, timestamp_type=0, key=None, value=b'{"latitude": -37.375, "longitude": 148.063, "air_temperature_celcius": 10.0, "relative_humidity": 43.5, "windspeed_knots": 12.0, "max_wind_speed": 16.9, "ghi": 90.0, "precipitation_type": "G", "precipitation": 0.04, "latest_date": "2023-01-29T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=2919009275, serialized_key_size=-1, serialized_value_size=289, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=83, timestamp=1716298417695, timestamp_type=0, key=None, value=b'{"latitude": -37.95, "longitude": 142.366, "air_temperature_celcius": 16.0, "relative_humidity": 53.6, "windspeed_knots": 8.1, "max_wind_speed": 15.0, "ghi": 133.0, "precipitation_type": "G", "precipitation": 0.0, "latest_date": "2023-01-30T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=4199027795, serialized_key_size=-1, serialized_value_size=287, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=84, timestamp=1716298427708, timestamp_type=0, key=None, value=b'{"latitude": -36.156, "longitude": 143.568, "air_temperature_celcius": 13.0, "relative_humidity": 51.4, "windspeed_knots": 4.6, "max_wind_speed": 8.9, "ghi": 110.0, "precipitation_type": "I", "precipitation": 0.0, "latest_date": "2023-01-31T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=4217729037, serialized_key_size=-1, serialized_value_size=287, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=85, timestamp=1716298437724, timestamp_type=0, key=None, value=b'{"latitude": -37.3583, "longitude": 143.0203, "air_temperature_celcius": 13.0, "relative_humidity": 43.3, "windspeed_knots": 9.4, "max_wind_speed": 14.0, "ghi": 118.0, "precipitation_type": "G", "precipitation": 0.0, "latest_date": "2023-02-01T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=2486723497, serialized_key_size=-1, serialized_value_size=290, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=86, timestamp=1716298447741, timestamp_type=0, key=None, value=b'{"latitude": -36.369, "longitude": 143.7132, "air_temperature_celcius": 13.0, "relative_humidity": 50.1, "windspeed_knots": 8.5, "max_wind_speed": 12.0, "ghi": 111.0, "precipitation_type": "G", "precipitation": 0.08, "latest_date": "2023-02-02T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=571003241, serialized_key_size=-1, serialized_value_size=290, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=87, timestamp=1716298457755, timestamp_type=0, key=None, value=b'{"latitude": -36.369, "longitude": 143.7132, "air_temperature_celcius": 13.0, "relative_humidity": 50.1, "windspeed_knots": 8.5, "max_wind_speed": 12.0, "ghi": 111.0, "precipitation_type": "G", "precipitation": 0.08, "latest_date": "2023-02-03T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=118560232, serialized_key_size=-1, serialized_value_size=290, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=88, timestamp=1716298467772, timestamp_type=0, key=None, value=b'{"latitude": -36.429, "longitude": 141.5759, "air_temperature_celcius": 7.0, "relative_humidity": 37.9, "windspeed_knots": 5.7, "max_wind_speed": 9.9, "ghi": 66.0, "precipitation_type": "G", "precipitation": 0.04, "latest_date": "2023-02-04T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=3050785357, serialized_key_size=-1, serialized_value_size=287, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=89, timestamp=1716298477793, timestamp_type=0, key=None, value=b'{"latitude": -36.282, "longitude": 146.157, "air_temperature_celcius": 17.0, "relative_humidity": 50.4, "windspeed_knots": 11.9, "max_wind_speed": 16.9, "ghi": 145.0, "precipitation_type": "G", "precipitation": 0.0, "latest_date": "2023-02-05T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=3808799881, serialized_key_size=-1, serialized_value_size=289, serialized_header_size=-1)
# ...
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=315, timestamp=1716300758927, timestamp_type=0, key=None, value=b'{"latitude": -37.331, "longitude": 143.122, "air_temperature_celcius": 19.0, "relative_humidity": 44.2, "windspeed_knots": 7.8, "max_wind_speed": 15.9, "ghi": 171.0, "precipitation_type": "I", "precipitation": 0.0, "latest_date": "2024-03-22T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=4163247914, serialized_key_size=-1, serialized_value_size=288, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=316, timestamp=1716300768934, timestamp_type=0, key=None, value=b'{"latitude": -36.4553, "longitude": 142.8786, "air_temperature_celcius": 19.0, "relative_humidity": 55.3, "windspeed_knots": 6.2, "max_wind_speed": 12.0, "ghi": 156.0, "precipitation_type": "I", "precipitation": 0.0, "latest_date": "2024-03-23T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=2538237772, serialized_key_size=-1, serialized_value_size=290, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=317, timestamp=1716300778943, timestamp_type=0, key=None, value=b'{"latitude": -36.4025, "longitude": 142.5598, "air_temperature_celcius": 21.0, "relative_humidity": 57.4, "windspeed_knots": 10.7, "max_wind_speed": 22.9, "ghi": 169.0, "precipitation_type": "G", "precipitation": 0.67, "latest_date": "2024-03-24T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=484996788, serialized_key_size=-1, serialized_value_size=292, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=318, timestamp=1716300788959, timestamp_type=0, key=None, value=b'{"latitude": -36.6511, "longitude": 143.915, "air_temperature_celcius": 13.0, "relative_humidity": 46.2, "windspeed_knots": 5.6, "max_wind_speed": 12.0, "ghi": 115.0, "precipitation_type": "I", "precipitation": 0.0, "latest_date": "2024-03-25T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=686129678, serialized_key_size=-1, serialized_value_size=289, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=319, timestamp=1716300798971, timestamp_type=0, key=None, value=b'{"latitude": -37.453, "longitude": 148.099, "air_temperature_celcius": 10.0, "relative_humidity": 45.7, "windspeed_knots": 3.6, "max_wind_speed": 7.0, "ghi": 89.0, "precipitation_type": "G", "precipitation": 0.01, "latest_date": "2024-03-26T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=2249832717, serialized_key_size=-1, serialized_value_size=287, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=320, timestamp=1716300808979, timestamp_type=0, key=None, value=b'{"latitude": -37.586, "longitude": 141.271, "air_temperature_celcius": 19.0, "relative_humidity": 60.5, "windspeed_knots": 7.0, "max_wind_speed": 11.1, "ghi": 149.0, "precipitation_type": "G", "precipitation": 0.83, "latest_date": "2024-03-27T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=3388450571, serialized_key_size=-1, serialized_value_size=289, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=321, timestamp=1716300818988, timestamp_type=0, key=None, value=b'{"latitude": -36.418, "longitude": 141.596, "air_temperature_celcius": 14.0, "relative_humidity": 50.1, "windspeed_knots": 8.7, "max_wind_speed": 15.0, "ghi": 120.0, "precipitation_type": "G", "precipitation": 0.0, "latest_date": "2024-03-28T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=528819654, serialized_key_size=-1, serialized_value_size=288, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=322, timestamp=1716300829000, timestamp_type=0, key=None, value=b'{"latitude": -37.61, "longitude": 149.279, "air_temperature_celcius": 20.0, "relative_humidity": 57.4, "windspeed_knots": 10.9, "max_wind_speed": 22.0, "ghi": 161.0, "precipitation_type": "I", "precipitation": 0.0, "latest_date": "2024-03-29T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=1413953507, serialized_key_size=-1, serialized_value_size=288, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=323, timestamp=1716300839023, timestamp_type=0, key=None, value=b'{"latitude": -36.2693, "longitude": 143.1768, "air_temperature_celcius": 12.0, "relative_humidity": 46.6, "windspeed_knots": 6.7, "max_wind_speed": 14.0, "ghi": 106.0, "precipitation_type": "G", "precipitation": 0.0, "latest_date": "2024-03-30T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=3262711557, serialized_key_size=-1, serialized_value_size=290, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=324, timestamp=1716300849033, timestamp_type=0, key=None, value=b'{"latitude": -36.952, "longitude": 144.972, "air_temperature_celcius": 21.0, "relative_humidity": 57.3, "windspeed_knots": 5.4, "max_wind_speed": 9.9, "ghi": 169.0, "precipitation_type": "I", "precipitation": 0.0, "latest_date": "2024-03-31T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=3384135579, serialized_key_size=-1, serialized_value_size=287, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=325, timestamp=1716300859045, timestamp_type=0, key=None, value=b'{"latitude": -37.461, "longitude": 148.109, "air_temperature_celcius": 14.0, "relative_humidity": 50.7, "windspeed_knots": 8.6, "max_wind_speed": 13.0, "ghi": 119.0, "precipitation_type": "G", "precipitation": 0.12, "latest_date": "2024-04-01T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=1594138204, serialized_key_size=-1, serialized_value_size=289, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=326, timestamp=1716300869052, timestamp_type=0, key=None, value=b'{"latitude": -37.478, "longitude": 148.117, "air_temperature_celcius": 11.0, "relative_humidity": 43.9, "windspeed_knots": 11.2, "max_wind_speed": 16.9, "ghi": 99.0, "precipitation_type": "G", "precipitation": 0.12, "latest_date": "2024-04-02T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=1402017031, serialized_key_size=-1, serialized_value_size=289, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=327, timestamp=1716300879067, timestamp_type=0, key=None, value=b'{"latitude": -37.332, "longitude": 148.091, "air_temperature_celcius": 8.0, "relative_humidity": 39.3, "windspeed_knots": 7.7, "max_wind_speed": 14.0, "ghi": 75.0, "precipitation_type": "G", "precipitation": 0.0, "latest_date": "2024-04-03T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=4162072844, serialized_key_size=-1, serialized_value_size=286, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=328, timestamp=1716300889076, timestamp_type=0, key=None, value=b'{"latitude": -37.719, "longitude": 142.154, "air_temperature_celcius": 13.0, "relative_humidity": 47.0, "windspeed_knots": 7.9, "max_wind_speed": 15.0, "ghi": 114.0, "precipitation_type": "G", "precipitation": 0.02, "latest_date": "2024-04-04T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=406577596, serialized_key_size=-1, serialized_value_size=289, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=329, timestamp=1716300899082, timestamp_type=0, key=None, value=b'{"latitude": -36.764, "longitude": 144.165, "air_temperature_celcius": 14.0, "relative_humidity": 52.4, "windspeed_knots": 6.7, "max_wind_speed": 11.1, "ghi": 118.0, "precipitation_type": "I", "precipitation": 0.0, "latest_date": "2024-04-05T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=565273694, serialized_key_size=-1, serialized_value_size=288, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=330, timestamp=1716300909093, timestamp_type=0, key=None, value=b'{"latitude": -37.461, "longitude": 148.109, "air_temperature_celcius": 14.0, "relative_humidity": 50.7, "windspeed_knots": 8.6, "max_wind_speed": 13.0, "ghi": 119.0, "precipitation_type": "G", "precipitation": 0.12, "latest_date": "2024-04-06T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=3400809124, serialized_key_size=-1, serialized_value_size=289, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=331, timestamp=1716300919109, timestamp_type=0, key=None, value=b'{"latitude": -36.4125, "longitude": 143.1189, "air_temperature_celcius": 12.0, "relative_humidity": 47.9, "windspeed_knots": 6.7, "max_wind_speed": 11.1, "ghi": 105.0, "precipitation_type": "G", "precipitation": 0.0, "latest_date": "2024-04-07T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=3803231462, serialized_key_size=-1, serialized_value_size=290, serialized_header_size=-1)
# MESSAGE:  ConsumerRecord(topic='Climate', partition=0, offset=332, timestamp=1716300929120, timestamp_type=0, key=None, value=b'{"latitude": -37.242, "longitude": 141.153, "air_temperature_celcius": 12.0, "relative_humidity": 42.8, "windspeed_knots": 12.1, "max_wind_speed": 19.0, "ghi": 109.0, "precipitation_type": "G", "precipitation": 0.04, "latest_date": "2024-04-08T00:00:00", "producer_id": "producer1_climate"}', headers=[], checksum=285955397, serialized_key_size=-1, serialized_value_size=290, serialized_header_size=-1)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 121
#     119 consumer = connect_kafka_consumer()
#     120 fig, ax = init_plots()
# --> 121 consume_messages(consumer, fig, ax)
#
# Cell In[10], line 110, in consume_messages(consumer, fig, ax)
#     107 annotate_max(x,y)
#     108 annotate_min(x,y)
# --> 110 fig.canvas.draw()
#     112 x.pop(0) # removing the item in the first position
#     113 y.pop(0)
#
# File /opt/conda/lib/python3.8/site-packages/matplotlib/backends/backend_webagg_core.py:191, in FigureCanvasWebAggCore.draw(self)
#     189 self._png_is_old = True
#     190 try:
# --> 191     super().draw()
#     192 finally:
#     193     self.manager.refresh_all()
#
# File /opt/conda/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:405, in FigureCanvasAgg.draw(self)
#     401 # Acquire a lock on the shared font cache.
#     402 with RendererAgg.lock, \
#     403      (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     404       else nullcontext()):
# --> 405     self.figure.draw(self.renderer)
#     406     # A GUI class may be need to update a window using this draw, so
#     407     # don't forget to call the superclass.
#     408     super().draw()
#
# File /opt/conda/lib/python3.8/site-packages/matplotlib/artist.py:74, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      72 @wraps(draw)
#      73 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 74     result = draw(artist, renderer, *args, **kwargs)
#      75     if renderer._rasterizing:
#      76         renderer.stop_rasterizing()
#
# File /opt/conda/lib/python3.8/site-packages/matplotlib/artist.py:51, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      48     if artist.get_agg_filter() is not None:
#      49         renderer.start_filter()
# ---> 51     return draw(artist, renderer)
#      52 finally:
#      53     if artist.get_agg_filter() is not None:
#
# File /opt/conda/lib/python3.8/site-packages/matplotlib/figure.py:3082, in Figure.draw(self, renderer)
#    3079         # ValueError can occur when resizing a window.
#    3081 self.patch.draw(renderer)
# -> 3082 mimage._draw_list_compositing_images(
#    3083     renderer, self, artists, self.suppressComposite)
#    3085 for sfig in self.subfigs:
#    3086     sfig.draw(renderer)
#
# File /opt/conda/lib/python3.8/site-packages/matplotlib/image.py:131, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129 if not_composite or not has_images:
#     130     for a in artists:
# --> 131         a.draw(renderer)
#     132 else:
#     133     # Composite any adjacent images together
#     134     image_group = []
#
# File /opt/conda/lib/python3.8/site-packages/matplotlib/artist.py:51, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      48     if artist.get_agg_filter() is not None:
#      49         renderer.start_filter()
# ---> 51     return draw(artist, renderer)
#      52 finally:
#      53     if artist.get_agg_filter() is not None:
#
# File /opt/conda/lib/python3.8/site-packages/matplotlib/axes/_base.py:3100, in _AxesBase.draw(self, renderer)
#    3097         a.draw(renderer)
#    3098     renderer.stop_rasterizing()
# -> 3100 mimage._draw_list_compositing_images(
#    3101     renderer, self, artists, self.figure.suppressComposite)
#    3103 renderer.close_group('axes')
#    3104 self.stale = False
#
# File /opt/conda/lib/python3.8/site-packages/matplotlib/image.py:131, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129 if not_composite or not has_images:
#     130     for a in artists:
# --> 131         a.draw(renderer)
#     132 else:
#     133     # Composite any adjacent images together
#     134     image_group = []
#
# File /opt/conda/lib/python3.8/site-packages/matplotlib/artist.py:51, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      48     if artist.get_agg_filter() is not None:
#      49         renderer.start_filter()
# ---> 51     return draw(artist, renderer)
#      52 finally:
#      53     if artist.get_agg_filter() is not None:
#
# File /opt/conda/lib/python3.8/site-packages/matplotlib/axis.py:1308, in Axis.draw(self, renderer, *args, **kwargs)
#    1305 tlb1, tlb2 = self._get_ticklabel_bboxes(ticks_to_draw, renderer)
#    1307 for tick in ticks_to_draw:
# -> 1308     tick.draw(renderer)
#    1310 # Scale up the axis label box to also find the neighbors, not just the
#    1311 # tick labels that actually overlap.  We need a *copy* of the axis
#    1312 # label box because we don't want to scale the actual bbox.
#    1314 self._update_label_position(renderer)
#
# File /opt/conda/lib/python3.8/site-packages/matplotlib/artist.py:51, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      48     if artist.get_agg_filter() is not None:
#      49         renderer.start_filter()
# ---> 51     return draw(artist, renderer)
#      52 finally:
#      53     if artist.get_agg_filter() is not None:
#
# File /opt/conda/lib/python3.8/site-packages/matplotlib/axis.py:306, in Tick.draw(self, renderer)
#     303 renderer.open_group(self.__name__, gid=self.get_gid())
#     304 for artist in [self.gridline, self.tick1line, self.tick2line,
#     305                self.label1, self.label2]:
# --> 306     artist.draw(renderer)
#     307 renderer.close_group(self.__name__)
#     308 self.stale = False
#
# File /opt/conda/lib/python3.8/site-packages/matplotlib/artist.py:51, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      48     if artist.get_agg_filter() is not None:
#      49         renderer.start_filter()
# ---> 51     return draw(artist, renderer)
#      52 finally:
#      53     if artist.get_agg_filter() is not None:
#
# File /opt/conda/lib/python3.8/site-packages/matplotlib/text.py:694, in Text.draw(self, renderer)
#     692 posx = float(self.convert_xunits(self._x))
#     693 posy = float(self.convert_yunits(self._y))
# --> 694 posx, posy = trans.transform((posx, posy))
#     695 if not np.isfinite(posx) or not np.isfinite(posy):
#     696     _log.warning("posx and posy should be finite values")
#
# KeyboardInterrupt:

# %% [markdown]
# ### Static Data Visualisation

# %% [markdown]
# #### Part A

# %%
client = MongoClient(f'mongodb://{hostip}:27017/')
db = client.fit3182_assignment_db
climate_collection = db.climate_collection

# Aggregation pipeline
pipeline = [
    {
        '$unwind': '$fire_events'
    },
    {
        '$group': {
            '_id': '$fire_events.created_hour',
            'fire_events_count': {'$sum': 1}
        }
    },
    {
        '$sort': {'_id': 1}  # Sort by created_hour in ascending order
    }
]

# Execute the aggregation pipeline
hourly_fire_events = list(climate_collection.aggregate(pipeline))
print(hourly_fire_events)

# Replace None with '0'
for event in hourly_fire_events:
    if event['_id'] is None:
        event['_id'] = '0'
print(hourly_fire_events)

# Extract hours and fire event counts
hours = [record['_id'] for record in hourly_fire_events]
counts = [record['fire_events_count'] for record in hourly_fire_events]

if counts is not None:
    # Perform the operation that requires a string or bytes object
    counts = [record['fire_events_count'] for record in hourly_fire_events]
else:
    # Handle the case where 'value' is None
    counts = 0

# Create a bar plot
plt.figure(figsize=(10, 5))
plt.bar(hours, counts, color='skyblue')

# Add title and labels
plt.title('Fire Events Count by Hour')
plt.xlabel('Hour of the Day (24 hours)')
plt.ylabel('Number of Fire Events')

# Set x-axis to show labels from 0 to 24
#plt.xticks(range(25), range(25))

# Show the plot
plt.show()
# Out:
# [{'_id': None, 'fire_events_count': 43}, {'_id': '11', 'fire_events_count': 8}, {'_id': '13', 'fire_events_count': 4}, {'_id': '17', 'fire_events_count': 1}, {'_id': '19', 'fire_events_count': 1}]
# [{'_id': '0', 'fire_events_count': 43}, {'_id': '11', 'fire_events_count': 8}, {'_id': '13', 'fire_events_count': 4}, {'_id': '17', 'fire_events_count': 1}, {'_id': '19', 'fire_events_count': 1}]
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# #### Part B

# %%
# Connect to MongoDB to obtain data
client = MongoClient(f'mongodb://{hostip}:27017/')
db = client.fit3182_assignment_db
climate_collection = db.climate_collection

# Preparing the data for plotting
natural_fire_events = []
other_fire_events = []

# Looping through all the data
for row in climate_collection.find():
    # pprint(row)
    
    cause = None
    
    # Check if fire_events is not empty
    if row['fire_events']:
        # Extract values from the first fire event
        average_surface_temp = row['fire_events'][0]['average_surface_temp']
        confidence = row['fire_events'][0]['confidence']
        cause = row['fire_events'][0]['cause']

    # Extract remaining values
    air_temperature_celcius = row['air_temperature_celcius']
    relative_humidity = row['relative_humidity']
    latitude = row['latitude']
    longitude = row['longitude']
    
    # Checking fire_events cause
    if cause == 'natural':
        # Adding the latitude and longitude to the list of unoccupied spots
        natural_fire_events.append([(latitude, longitude), average_surface_temp, confidence, air_temperature_celcius, relative_humidity])
    elif cause == 'others':
        # Adding the latitude and longitude to the list of unoccupied spots
        other_fire_events.append([(latitude, longitude), average_surface_temp, confidence, air_temperature_celcius, relative_humidity])

# %%
# Initialize a map at Melbourne
fomap = folium.Map(location=[-37.812015244225677, 144.951471202974], zoom_start=15)

# Plot a blue marker for each natural data on fire_events
for data in natural_fire_events:
    folium.Marker(location=data[0], popup=f"average_surface_temp={data[1]:.2f}, confidence={data[2]:.2f}, air_temperature_celcius={data[3]:.2f}, relative_humidity={data[4]:.2f}", icon=folium.Icon(color='blue')).add_to(fomap)
    
# Plot a red marker for each natural data on fire_events
for data in other_fire_events:
    folium.Marker(location=data[0], popup=f"average_surface_temp={data[1]:.2f}, confidence={data[2]:.2f}, air_temperature_celcius={data[3]:.2f}, relative_humidity={data[4]:.2f}", icon=folium.Icon(color='red')).add_to(fomap)

# %%
fomap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c82cf559af8b1923e781090341b7755d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c82cf559af8b1923e781090341b7755d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c82cf559af8b1923e781090341b7755d = L.map(
#                 &quot;map_c82cf559af8b1923e781090341b7755d&quot;,
#                 {
#                     center: [-37.81201524422568, 144.951471202974],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9d8995e6280bb1e72ace155905e1ff09 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_9d8995e6280bb1e72ace155905e1ff09.addTo(map_c82cf559af8b1923e781090341b7755d);
#
#
#             var marker_49f8575cc74b776208c7cbefb4e31fbc = L.marker(
#                 [-37.621, 143.447],
#                 {}
#             ).addTo(map_c82cf559af8b1923e781090341b7755d);
#
#
#             var icon_5fb7aae373b9f54cef357cbf069af1bd = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_49f8575cc74b776208c7cbefb4e31fbc.setIcon(icon_5fb7aae373b9f54cef357cbf069af1bd);
#
#
#         var popup_7747fa98f693bac264067c64910830a3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b732be56d698dab5b24d8b35a61382b5 = $(`&lt;div id=&quot;html_b732be56d698dab5b24d8b35a61382b5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;average_surface_temp=63.00, confidence=87.00, air_temperature_celcius=23.00, relative_humidity=53.40&lt;/div&gt;`)[0];
#                 popup_7747fa98f693bac264067c64910830a3.setContent(html_b732be56d698dab5b24d8b35a61382b5);
#
#
#
#         marker_49f8575cc74b776208c7cbefb4e31fbc.bindPopup(popup_7747fa98f693bac264067c64910830a3)
#         ;
#
#
#
#
#             var marker_d20a5a30ac729b9eb31e804d4a1a0cc7 = L.marker(
#                 [-36.2127, 141.4938],
#                 {}
#             ).addTo(map_c82cf559af8b1923e781090341b7755d);
#
#
#             var icon_c405c802279150233773fafdc44e279e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d20a5a30ac729b9eb31e804d4a1a0cc7.setIcon(icon_c405c802279150233773fafdc44e279e);
#
#
#         var popup_14dd9cd21205fc90a1df0f2f698a45ba = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_10f0643351aafc4272d457be250ff3d5 = $(`&lt;div id=&quot;html_10f0643351aafc4272d457be250ff3d5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;average_surface_temp=49.00, confidence=76.00, air_temperature_celcius=23.00, relative_humidity=58.80&lt;/div&gt;`)[0];
#                 popup_14dd9cd21205fc90a1df0f2f698a45ba.setContent(html_10f0643351aafc4272d457be250ff3d5);
#
#
#
#         marker_d20a5a30ac729b9eb31e804d4a1a0cc7.bindPopup(popup_14dd9cd21205fc90a1df0f2f698a45ba)
#         ;
#
#
#
#
#             var marker_d98f2557f69ded429846d864613594be = L.marker(
#                 [-36.942, 143.282],
#                 {}
#             ).addTo(map_c82cf559af8b1923e781090341b7755d);
#
#
#             var icon_831767d649fc27b617899e6a9e018c68 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d98f2557f69ded429846d864613594be.setIcon(icon_831767d649fc27b617899e6a9e018c68);
#
#
#         var popup_28ca52eafab4592379de08b89eb37df3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_33609a3024a07ad16bacb5ec98e484bc = $(`&lt;div id=&quot;html_33609a3024a07ad16bacb5ec98e484bc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;average_surface_temp=48.00, confidence=75.00, air_temperature_celcius=25.00, relative_humidity=58.30&lt;/div&gt;`)[0];
#                 popup_28ca52eafab4592379de08b89eb37df3.setContent(html_33609a3024a07ad16bacb5ec98e484bc);
#
#
#
#         marker_d98f2557f69ded429846d864613594be.bindPopup(popup_28ca52eafab4592379de08b89eb37df3)
#         ;
#
#
#
#
#             var marker_bd020b3a67edcb22f88cbbe576c2d632 = L.marker(
#                 [-37.903, 145.25],
#                 {}
#             ).addTo(map_c82cf559af8b1923e781090341b7
