# %% [markdown]
# <div style= "text-align: right">
#     <p style= "text-align: right; font-weight: bold; font-size: x-large;">FIT3182 Big Data Management and Processing</p>
#     <p style= "text-align: right; font-weight: bold; font-size: large;">Assignment 2</p>
#     <p style= "text-align: right">Foo Kai Yan</p>
#     <p style= "text-align: right">kfoo0012@student.monash.edu<br><br><i>33085625<br><br><i>22<sup>th</sup> May 2024</i></p>
# <div>
# <hr style="border-color: black;">

# %% [markdown]
# ## Student Statement
# The assignment was completed with the assistance of some code obtained from seminar/tutorial/lab/applied class.

# %% [markdown]
# ### Installing PyMongo

# %%
# !pip install pymongo
# !pip install pygeohash
# Out:
# Requirement already satisfied: pymongo in /opt/conda/lib/python3.8/site-packages (4.3.3)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /opt/conda/lib/python3.8/site-packages (from pymongo) (2.3.0)
# Requirement already satisfied: pygeohash in /opt/conda/lib/python3.8/site-packages (1.2.0)

# %% [markdown]
# ### Import required Libraries

# %%
import os
import json
import time
import datetime
import pygeohash as pgh
from pprint import pprint
from pymongo import MongoClient
from pyspark.sql import SparkSession
from pyspark import SparkContext, SparkConf # spark
from pyspark.streaming import StreamingContext # spark streaming
from pyspark.sql.functions import col, split, element_at, when

# %% [markdown]
# ### Check working directory

# %%
os.getcwd()
# Out:
# '/home/student/kfoo0012'

# %% [markdown]
# ### Set os environment

# %%
os.environ['PYSPARK_SUBMIT_ARGS'] = '--packages org.apache.spark:spark-streaming-kafka-0-10_2.12:3.3.0,org.apache.spark:spark-sql-kafka-0-10_2.12:3.3.0 pyspark-shell'

# %% [markdown]
# ### Set host ip

# %%
# hostip obtained using `ipconfig` command in command prompt
hostip = "192.168.68.58"

# %% [markdown]
# ### Streaming Application Processing Data

# %%
# Check proximity based on geohash, precision 5
def geohash_proximity_5(record, climate):
    record_geohash = pgh.encode(record["longitude"], record["latitude"], precision = 5)
    climate_geohash = pgh.encode(climate[0]["longitude"], climate[0]["latitude"], precision = 5)
    return record_geohash == climate_geohash

# Check proximity based on geohash, precision 3
def geohash_proximity(record, climate):
    record_geohash = pgh.encode(record["longitude"], record["latitude"], precision = 3)
    climate_geohash = pgh.encode(climate[0]["longitude"], climate[0]["latitude"], precision = 3)
    return record_geohash == climate_geohash

def process_producer_data(batch_df, batch_id):
    all_data = batch_df.collect()  # Returns all elements as an array
    # Send stream data to be transformed & analysed
    producer_data = [row.asDict() for row in all_data]
    
    # Initialize empty lists for aqua_hotspots_record, terra_hotspots_record, and an empty dictionary for climate_record
    climate_record = []
    aqua_hotspots_record = []
    terra_hotspots_record = []
    
    # Producer 1: Climate topic_name = "Climate", ["producer_id"] = "producer1_climate"
    # Producer 2: AQUA topic_name = "Hotspot_AQUA", ["producer_id"] = "producer2_hotspot_aqua"
    # Producer 3: TERRA topic_name = "Hotspot_TERRA", ["producer_id"] = "producer3_hotspot_terra"
    
    # For each item from the data batch from the Kafka stream 
    for eachdata in range(len(producer_data)): 
        # Check if 'value' key exists and is a bytearray
        if 'value' in producer_data[eachdata] and isinstance(producer_data[eachdata]['value'], bytearray):
            # Convert byte array to string and then to JSON
            newdata = producer_data[eachdata]['value'].decode('utf-8')
            produced_data = json.loads(newdata)
            producer_data[eachdata] = produced_data
            
    for producer in producer_data:
        producer_id = producer["producer_id"]

        # Sort data depending on the producer_id information
        if producer_id == "producer1_climate":
            climate_record.append(producer)
            # print("climate record", climate_record)
        elif producer_id == "producer2_hotspot_aqua":
            aqua_hotspots_record.append(producer)
            # print("aqua_hotspots_record", aqua_hotspots_record)
        elif producer_id == "producer3_hotspot_terra":
            terra_hotspots_record.append(producer)
            # print("terra_hotspots_record", terra_hotspots_record)
                
    # If there are no climate_record, skip processing this batch
    # Check if the climate_record is empty, have 1 or more than 1 climate_record
    if len(climate_record) == 1:
        climate_record = climate_record
    elif len(climate_record) > 1:
        # If more than 1 then select the first climate_record only
        climate_record = climate_record[0]
    else:
        print("No climate record present in this batch. Skipping...")
        return  # Exit the function

    # Analyse hotspots data, find if any are close by & merge
    new_hotspots_record = process_hotspots(aqua_hotspots_record, terra_hotspots_record, climate_record)
    # Merge hotspots with climate depending if close & label if natural or other
    new_climate_record = process_climate(climate_record, new_hotspots_record)
    print("BACK TO MAIN FUNCTION")
    return addtodatabase(new_climate_record)

def process_hotspots(aqua_hotspots_record, terra_hotspots_record, climate_record):
    # Initialize empty array for hotspots records from both terra and aqua
    hotspots = []
    print("IN PROCESS HOTSPOTS")
    
    # Process aqua_hotspots_record
    for each_record in aqua_hotspots_record:
        print("IN AQUA")
        if geohash_proximity(each_record, climate_record):
            hotspots.append(each_record)
            
    # Process terra_hotspots_record
    for each_record in terra_hotspots_record:
        print("IN TERRA")
        if geohash_proximity(each_record, climate_record):
            hotspots.append(each_record)
            
    return hotspots

def process_climate(climate_record, hotspots_record):
    # Initialize empty array for fire events records
    print("IN PROCESS CLIMATE")
    fire_events = []
    for each_record in hotspots_record:
        fire_event = process_fire_event(climate_record, each_record)
        if fire_event is not None:
            fire_events.append(fire_event)
    print("FIRE_EVENTS: ", fire_events)
    # Add new key to climate_record and add the fire_events as the value to the key
    # climate_record format: [{}] ; fire_events format: [{}]
    new_key = "fire_events"
    new_value = fire_events
    
    # Since the top-level structure is a list, access the first dictionary
    if climate_record:  # Check if the list is not empty
        climate_record[0][new_key] = new_value
    else:
        # If the list is empty, create a new dictionary with the new key
        climate_record.append({new_key: new_value})
    print("CLIMATE RECORD FROM PROCESS CLIMATE: ", climate_record)
    return climate_record

def process_fire_event(climate_record, hotspots_record):
    print("IN PROCESS FIRE EVENT")
    # Initialize an empty dictionary to store fire event data
    fire_happening = {}

    # Check if the hotspot is geographically close to the climate data with a precision of 5
    if geohash_proximity_5(hotspots_record, climate_record) is True:
        print("hotspots_record: ", hotspots_record)
        
        # Get the created_time for Data Visualisation 
        fire_happening["created_time"] = hotspots_record.get("created_time")
        fire_happening["created_hour"] = hotspots_record.get("created_time").split(':')[0]
        
        # Calculate the average surface temperature from both hotspot and climate data
        average_temp = (hotspots_record.get("surface_temperature_celcius") + hotspots_record.get("surface_temperature_celcius")) / 2
        fire_happening["average_surface_temp"] = average_temp

        # Calculate the average confidence level from both hotspot and climate data
        average_confidence = (hotspots_record.get("confidence") + hotspots_record.get("confidence")) / 2
        fire_happening["confidence"] = average_confidence

        # Get the air_temperature_celcius and GHI_w/m2 value
        if climate_record:  # Check if the list is not empty
            air_temp = climate_record[0].get("air_temperature_celcius")
            solar_irradiance = climate_record[0].get("GHI_w/m2")
        else:
            air_temp = None
            solar_irradiance = None
        # Determine the cause of the fire based on climate conditions            
        if air_temp > 20 and solar_irradiance > 180:
            fire_happening["cause"] = "natural"
        else:
            fire_happening["cause"] = "others"
        
        print("FIRE HAPPENING: ", fire_happening)
        # Return the dictionary containing fire event data
        return fire_happening
    # If the hotspot is not close to the climate data, return None
    return None

def addtodatabase(dictionary_in_array):
    print("ADD TO DATABASE")
    # Only save data with contents
    if len(dictionary_in_array) >= 1:

        client = MongoClient(f'mongodb://{hostip}:27017/')

        db = client.fit3182_assignment_db
        climate_collection = db.climate_collection

        # Insert climate data into database
        inserting = climate_collection.insert_one(dictionary_in_array[0])
        print("ADD SUCCESSFUL: ", inserting)

        client.close()

# %%
# names of three Kafka topics separated by commas (Obtained from Producer1, 2 and 3)
topic = "Climate, Hotspot_AQUA, Hotspot_TERRA"

spark = (
    SparkSession.builder
    .master('local[*]') # local[*] means Spark will run locally using all available cores on the machine
    .appName('Streaming Climate Data')
    .getOrCreate() # Creates a SparkSession if it does not exist or returns the existing one
)

# This is basically connecting to kafka server
topic_stream_df = (
    spark.readStream.format('kafka') # 'kafka' because u are receiving from kafka
    .option('kafka.bootstrap.servers', f'{hostip}:9092')
    .option('subscribe', topic) # Subscribes to the Kafka topics listed in the topic variable
    .load() # Loads the data stream from Kafka and returns it as a DataFrame
)

# Creates a new DataFrame data_sdf by selecting only the ‘value’ column from the topic_stream_df DataFrame
# This ‘value’ column contains the actual message data obtained from Kafka
data_sdf = topic_stream_df.select('value')

db_writer = (
    data_sdf
    .writeStream # Indicates that the data in data_sdf will be written to an output sink
    .outputMode('append') # Only new rows will be written to the output sink as they arrive
    # collect data for 10 seconds
    .trigger(processingTime='10 seconds')
    # each batch of 10 seconds will run func
    .foreachBatch(process_producer_data)) 
    # For each batch collected, the process_producer_data function will be called to process the data
    # process_producer_data function is essentially the main function for the stream data processing

# %%
'''
This code section manage the lifecycle of a streaming query in a controlled manner
It allows for a graceful shutdown when the user decides to interrupt the process
'''
try:
    query = db_writer.start() # Starts the streaming query
    query.awaitTermination() # Waits for the streaming query to finish
except KeyboardInterrupt:
    print('Interrupted by CTRL-C. Stopping query.') # Gracefully handle a user’s request to interrupt the program
finally:
    query.stop() # Stops the streaming query
# Out:
# No climate record present in this batch. Skipping...
# IN PROCESS HOTSPOTS
# IN AQUA
# IN AQUA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN PROCESS CLIMATE
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# FIRE_EVENTS:  []
# CLIMATE RECORD FROM PROCESS CLIMATE:  [{'latitude': -37.0884, 'longitude': 141.0357, 'air_temperature_celcius': 12.0, 'relative_humidity': 40.4, 'windspeed_knots': 5.9, 'max_wind_speed': 8.9, 'GHI_w/m2': 111.0, 'precipitation_flag': 'G', 'precipitation': 0.0, 'latest_date': '2027-12-27T00:00:00', 'producer_id': 'producer1_climate', 'fire_events': []}]
# BACK TO MAIN FUNCTION
# ADD TO DATABASE
# ADD SUCCESSFUL:  <pymongo.results.InsertOneResult object at 0x7fda9d5323d0>
# IN PROCESS HOTSPOTS
# IN AQUA
# IN AQUA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN PROCESS CLIMATE
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# FIRE_EVENTS:  []
# CLIMATE RECORD FROM PROCESS CLIMATE:  [{'latitude': -37.608, 'longitude': 149.292, 'air_temperature_celcius': 15.0, 'relative_humidity': 44.6, 'windspeed_knots': 9.7, 'max_wind_speed': 12.0, 'GHI_w/m2': 134.0, 'precipitation_flag': 'G', 'precipitation': 0.02, 'latest_date': '2027-12-28T00:00:00', 'producer_id': 'producer1_climate', 'fire_events': []}]
# BACK TO MAIN FUNCTION
# ADD TO DATABASE
# ADD SUCCESSFUL:  <pymongo.results.InsertOneResult object at 0x7fda9ccc4580>
# IN PROCESS HOTSPOTS
# IN AQUA
# IN AQUA
# IN AQUA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN PROCESS CLIMATE
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# FIRE_EVENTS:  []
# CLIMATE RECORD FROM PROCESS CLIMATE:  [{'latitude': -37.596, 'longitude': 149.319, 'air_temperature_celcius': 19.0, 'relative_humidity': 56.1, 'windspeed_knots': 6.9, 'max_wind_speed': 12.0, 'GHI_w/m2': 155.0, 'precipitation_flag': 'A', 'precipitation': 0.0, 'latest_date': '2027-12-29T00:00:00', 'producer_id': 'producer1_climate', 'fire_events': []}]
# BACK TO MAIN FUNCTION
# ADD TO DATABASE
# ADD SUCCESSFUL:  <pymongo.results.InsertOneResult object at 0x7fda9ccc4340>
# IN PROCESS HOTSPOTS
# IN AQUA
# IN AQUA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN PROCESS CLIMATE
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# FIRE_EVENTS:  []
# CLIMATE RECORD FROM PROCESS CLIMATE:  [{'latitude': -37.903, 'longitude': 145.25, 'air_temperature_celcius': 24.0, 'relative_humidity': 62.3, 'windspeed_knots': 7.0, 'max_wind_speed': 13.0, 'GHI_w/m2': 185.0, 'precipitation_flag': 'I', 'precipitation': 0.0, 'latest_date': '2027-12-30T00:00:00', 'producer_id': 'producer1_climate', 'fire_events': []}]
# BACK TO MAIN FUNCTION
# ADD TO DATABASE
# ADD SUCCESSFUL:  <pymongo.results.InsertOneResult object at 0x7fda9ccc4280>
# IN PROCESS HOTSPOTS
# IN AQUA
# IN AQUA
# IN AQUA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN PROCESS CLIMATE
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# FIRE_EVENTS:  []
# CLIMATE RECORD FROM PROCESS CLIMATE:  [{'latitude': -36.6732, 'longitude': 142.5162, 'air_temperature_celcius': 19.0, 'relative_humidity': 53.9, 'windspeed_knots': 8.3, 'max_wind_speed': 14.0, 'GHI_w/m2': 158.0, 'precipitation_flag': 'I', 'precipitation': 0.0, 'latest_date': '2027-12-31T00:00:00', 'producer_id': 'producer1_climate', 'fire_events': []}]
# BACK TO MAIN FUNCTION
# ADD TO DATABASE
# ADD SUCCESSFUL:  <pymongo.results.InsertOneResult object at 0x7fda9ccc4880>
# IN PROCESS HOTSPOTS
# IN AQUA
# IN AQUA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN PROCESS CLIMATE
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# FIRE_EVENTS:  []
# CLIMATE RECORD FROM PROCESS CLIMATE:  [{'latitude': -37.1875, 'longitude': 146.8024, 'air_temperature_celcius': 28.0, 'relative_humidity': 58.3, 'windspeed_knots': 9.3, 'max_wind_speed': 15.9, 'GHI_w/m2': 223.0, 'precipitation_flag': 'I', 'precipitation': 0.0, 'latest_date': '2028-01-01T00:00:00', 'producer_id': 'producer1_climate', 'fire_events': []}]
# BACK TO MAIN FUNCTION
# ADD TO DATABASE
# ADD SUCCESSFUL:  <pymongo.results.InsertOneResult object at 0x7fda9ccc4b80>
# IN PROCESS HOTSPOTS
# IN AQUA
# IN AQUA
# IN AQUA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN PROCESS CLIMATE
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# hotspots_record:  {'latitude': -37.5865, 'longitude': 143.0246, 'confidence': 70.0, 'surface_temperature_celcius': 45.0, 'created_time': '11:53:15', 'producer_id': 'producer3_hotspot_terra'}
# FIRE HAPPENING:  {'created_time': '11:53:15', 'created_hour': '11', 'average_surface_temp': 45.0, 'confidence': 70.0, 'cause': 'others'}
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# FIRE_EVENTS:  [{'created_time': '11:53:15', 'created_hour': '11', 'average_surface_temp': 45.0, 'confidence': 70.0, 'cause': 'others'}]
# CLIMATE RECORD FROM PROCESS CLIMATE:  [{'latitude': -37.585, 'longitude': 149.336, 'air_temperature_celcius': 17.0, 'relative_humidity': 52.5, 'windspeed_knots': 6.7, 'max_wind_speed': 12.0, 'GHI_w/m2': 143.0, 'precipitation_flag': 'G', 'precipitation': 0.0, 'latest_date': '2028-01-02T00:00:00', 'producer_id': 'producer1_climate', 'fire_events': [{'created_time': '11:53:15', 'created_hour': '11', 'average_surface_temp': 45.0, 'confidence': 70.0, 'cause': 'others'}]}]
# BACK TO MAIN FUNCTION
# ADD TO DATABASE
# ADD SUCCESSFUL:  <pymongo.results.InsertOneResult object at 0x7fda9cca2970>
# IN PROCESS HOTSPOTS
# IN AQUA
# IN AQUA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN PROCESS CLIMATE
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# FIRE_EVENTS:  []
# CLIMATE RECORD FROM PROCESS CLIMATE:  [{'latitude': -37.1926, 'longitude': 143.8095, 'air_temperature_celcius': 8.0, 'relative_humidity': 36.3, 'windspeed_knots': 6.3, 'max_wind_speed': 13.0, 'GHI_w/m2': 76.0, 'precipitation_flag': 'G', 'precipitation': 0.01, 'latest_date': '2028-01-03T00:00:00', 'producer_id': 'producer1_climate', 'fire_events': []}]
# BACK TO MAIN FUNCTION
# ADD TO DATABASE
# ADD SUCCESSFUL:  <pymongo.results.InsertOneResult object at 0x7fda9d52df10>
# IN PROCESS HOTSPOTS
# IN AQUA
# IN AQUA
# IN AQUA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN PROCESS CLIMATE
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# FIRE_EVENTS:  []
# CLIMATE RECORD FROM PROCESS CLIMATE:  [{'latitude': -37.332, 'longitude': 143.375, 'air_temperature_celcius': 21.0, 'relative_humidity': 51.7, 'windspeed_knots': 7.2, 'max_wind_speed': 13.0, 'GHI_w/m2': 177.0, 'precipitation_flag': 'I', 'precipitation': 0.0, 'latest_date': '2028-01-04T00:00:00', 'producer_id': 'producer1_climate', 'fire_events': []}]
# BACK TO MAIN FUNCTION
# ADD TO DATABASE
# ADD SUCCESSFUL:  <pymongo.results.InsertOneResult object at 0x7fda9dd44a90>
# IN PROCESS HOTSPOTS
# IN AQUA
# IN AQUA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN PROCESS CLIMATE
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# hotspots_record:  {'latitude': -37.363, 'longitude': 148.06, 'confidence': 100.0, 'surface_temperature_celcius': 48.0, 'created_time': '11:53:15', 'producer_id': 'producer3_hotspot_terra'}
# FIRE HAPPENING:  {'created_time': '11:53:15', 'created_hour': '11', 'average_surface_temp': 48.0, 'confidence': 100.0, 'cause': 'others'}
# IN PROCESS FIRE EVENT
# FIRE_EVENTS:  [{'created_time': '11:53:15', 'created_hour': '11', 'average_surface_temp': 48.0, 'confidence': 100.0, 'cause': 'others'}]
# CLIMATE RECORD FROM PROCESS CLIMATE:  [{'latitude': -37.375, 'longitude': 148.054, 'air_temperature_celcius': 12.0, 'relative_humidity': 47.0, 'windspeed_knots': 4.8, 'max_wind_speed': 8.9, 'GHI_w/m2': 105.0, 'precipitation_flag': 'I', 'precipitation': 0.0, 'latest_date': '2028-01-05T00:00:00', 'producer_id': 'producer1_climate', 'fire_events': [{'created_time': '11:53:15', 'created_hour': '11', 'average_surface_temp': 48.0, 'confidence': 100.0, 'cause': 'others'}]}]
# BACK TO MAIN FUNCTION
# ADD TO DATABASE
# ADD SUCCESSFUL:  <pymongo.results.InsertOneResult object at 0x7fda9dd41c10>
# IN PROCESS HOTSPOTS
# IN AQUA
# IN AQUA
# IN AQUA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN PROCESS CLIMATE
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# FIRE_EVENTS:  []
# CLIMATE RECORD FROM PROCESS CLIMATE:  [{'latitude': -37.475, 'longitude': 148.134, 'air_temperature_celcius': 8.0, 'relative_humidity': 43.1, 'windspeed_knots': 3.4, 'max_wind_speed': 7.0, 'GHI_w/m2': 73.0, 'precipitation_flag': 'I', 'precipitation': 0.0, 'latest_date': '2028-01-06T00:00:00', 'producer_id': 'producer1_climate', 'fire_events': []}]
# BACK TO MAIN FUNCTION
# ADD TO DATABASE
# ADD SUCCESSFUL:  <pymongo.results.InsertOneResult object at 0x7fda9dd41130>
# IN PROCESS HOTSPOTS
# IN AQUA
# IN AQUA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN PROCESS CLIMATE
# FIRE_EVENTS:  []
# CLIMATE RECORD FROM PROCESS CLIMATE:  [{'latitude': -35.892, 'longitude': 145.62, 'air_temperature_celcius': 10.0, 'relative_humidity': 42.6, 'windspeed_knots': 8.9, 'max_wind_speed': 15.0, 'GHI_w/m2': 91.0, 'precipitation_flag': 'G', 'precipitation': 0.04, 'latest_date': '2028-01-07T00:00:00', 'producer_id': 'producer1_climate', 'fire_events': []}]
# BACK TO MAIN FUNCTION
# ADD TO DATABASE
# ADD SUCCESSFUL:  <pymongo.results.InsertOneResult object at 0x7fda9dd44e80>
# IN PROCESS HOTSPOTS
# IN AQUA
# IN AQUA
# IN AQUA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN PROCESS CLIMATE
# IN PROCESS FIRE EVENT
# FIRE_EVENTS:  []
# CLIMATE RECORD FROM PROCESS CLIMATE:  [{'latitude': -38.527, 'longitude': 143.493, 'air_temperature_celcius': 19.0, 'relative_humidity': 51.5, 'windspeed_knots': 10.2, 'max_wind_speed': 20.0, 'GHI_w/m2': 161.0, 'precipitation_flag': 'I', 'precipitation': 0.0, 'latest_date': '2028-01-08T00:00:00', 'producer_id': 'producer1_climate', 'fire_events': []}]
# BACK TO MAIN FUNCTION
# ADD TO DATABASE
# ADD SUCCESSFUL:  <pymongo.results.InsertOneResult object at 0x7fda9dd44d90>
# IN PROCESS HOTSPOTS
# IN AQUA
# IN AQUA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN PROCESS CLIMATE
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# FIRE_EVENTS:  []
# CLIMATE RECORD FROM PROCESS CLIMATE:  [{'latitude': -36.0714, 'longitude': 145.7665, 'air_temperature_celcius': 18.0, 'relative_humidity': 54.6, 'windspeed_knots': 12.0, 'max_wind_speed': 25.1, 'GHI_w/m2': 148.0, 'precipitation_flag': 'G', 'precipitation': 0.12, 'latest_date': '2028-01-09T00:00:00', 'producer_id': 'producer1_climate', 'fire_events': []}]
# BACK TO MAIN FUNCTION
# ADD TO DATABASE
# ADD SUCCESSFUL:  <pymongo.results.InsertOneResult object at 0x7fda9dd44400>
# IN PROCESS HOTSPOTS
# IN AQUA
# IN AQUA
# IN AQUA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN PROCESS CLIMATE
# FIRE_EVENTS:  []
# CLIMATE RECORD FROM PROCESS CLIMATE:  [{'latitude': -34.289, 'longitude': 141.712, 'air_temperature_celcius': 32.0, 'relative_humidity': 54.1, 'windspeed_knots': 12.8, 'max_wind_speed': 19.0, 'GHI_w/m2': 265.0, 'precipitation_flag': 'I', 'precipitation': 0.0, 'latest_date': '2028-01-10T00:00:00', 'producer_id': 'producer1_climate', 'fire_events': []}]
# BACK TO MAIN FUNCTION
# ADD TO DATABASE
# ADD SUCCESSFUL:  <pymongo.results.InsertOneResult object at 0x7fda9cca27f0>
# IN PROCESS HOTSPOTS
# IN AQUA
# IN AQUA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN PROCESS CLIMATE
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# hotspots_record:  {'latitude': -36.8867, 'longitude': 142.1873, 'confidence': 90.0, 'surface_temperature_celcius': 66.0, 'created_time': '11:53:15', 'producer_id': 'producer3_hotspot_terra'}
# FIRE HAPPENING:  {'created_time': '11:53:15', 'created_hour': '11', 'average_surface_temp': 66.0, 'confidence': 90.0, 'cause': 'others'}
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# hotspots_record:  {'latitude': -36.8741, 'longitude': 143.91, 'confidence': 71.0, 'surface_temperature_celcius': 45.0, 'created_time': '11:53:15', 'producer_id': 'producer3_hotspot_terra'}
# FIRE HAPPENING:  {'created_time': '11:53:15', 'created_hour': '11', 'average_surface_temp': 45.0, 'confidence': 71.0, 'cause': 'others'}
# FIRE_EVENTS:  [{'created_time': '11:53:15', 'created_hour': '11', 'average_surface_temp': 66.0, 'confidence': 90.0, 'cause': 'others'}, {'created_time': '11:53:15', 'created_hour': '11', 'average_surface_temp': 45.0, 'confidence': 71.0, 'cause': 'others'}]
# CLIMATE RECORD FROM PROCESS CLIMATE:  [{'latitude': -36.8867, 'longitude': 142.1873, 'air_temperature_celcius': 14.0, 'relative_humidity': 39.3, 'windspeed_knots': 17.7, 'max_wind_speed': 30.9, 'GHI_w/m2': 131.0, 'precipitation_flag': 'G', 'precipitation': 0.01, 'latest_date': '2028-01-11T00:00:00', 'producer_id': 'producer1_climate', 'fire_events': [{'created_time': '11:53:15', 'created_hour': '11', 'average_surface_temp': 66.0, 'confidence': 90.0, 'cause': 'others'}, {'created_time': '11:53:15', 'created_hour': '11', 'average_surface_temp': 45.0, 'confidence': 71.0, 'cause': 'others'}]}]
# BACK TO MAIN FUNCTION
# ADD TO DATABASE
# ADD SUCCESSFUL:  <pymongo.results.InsertOneResult object at 0x7fda9cca27f0>
# IN PROCESS HOTSPOTS
# IN AQUA
# IN AQUA
# IN AQUA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN PROCESS CLIMATE
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# FIRE_EVENTS:  []
# CLIMATE RECORD FROM PROCESS CLIMATE:  [{'latitude': -36.6516, 'longitude': 141.4943, 'air_temperature_celcius': 11.0, 'relative_humidity': 45.3, 'windspeed_knots': 8.5, 'max_wind_speed': 15.0, 'GHI_w/m2': 98.0, 'precipitation_flag': 'G', 'precipitation': 0.0, 'latest_date': '2028-01-12T00:00:00', 'producer_id': 'producer1_climate', 'fire_events': []}]
# BACK TO MAIN FUNCTION
# ADD TO DATABASE
# ADD SUCCESSFUL:  <pymongo.results.InsertOneResult object at 0x7fda9dd44100>
# IN PROCESS HOTSPOTS
# IN AQUA
# IN AQUA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN PROCESS CLIMATE
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# FIRE_EVENTS:  []
# CLIMATE RECORD FROM PROCESS CLIMATE:  [{'latitude': -37.3583, 'longitude': 143.0203, 'air_temperature_celcius': 13.0, 'relative_humidity': 43.3, 'windspeed_knots': 9.4, 'max_wind_speed': 14.0, 'GHI_w/m2': 118.0, 'precipitation_flag': 'G', 'precipitation': 0.0, 'latest_date': '2028-01-13T00:00:00', 'producer_id': 'producer1_climate', 'fire_events': []}]
# BACK TO MAIN FUNCTION
# ADD TO DATABASE
# ADD SUCCESSFUL:  <pymongo.results.InsertOneResult object at 0x7fda9dd44430>
# IN PROCESS HOTSPOTS
# IN AQUA
# IN AQUA
# IN AQUA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN PROCESS CLIMATE
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# hotspots_record:  {'latitude': -37.7009, 'longitude': 146.2046, 'confidence': 80.0, 'surface_temperature_celcius': 53.0, 'created_time': '11:53:15', 'producer_id': 'producer3_hotspot_terra'}
# FIRE HAPPENING:  {'created_time': '11:53:15', 'created_hour': '11', 'average_surface_temp': 53.0, 'confidence': 80.0, 'cause': 'others'}
# IN PROCESS FIRE EVENT
# FIRE_EVENTS:  [{'created_time': '11:53:15', 'created_hour': '11', 'average_surface_temp': 53.0, 'confidence': 80.0, 'cause': 'others'}]
# CLIMATE RECORD FROM PROCESS CLIMATE:  [{'latitude': -37.692, 'longitude': 143.593, 'air_temperature_celcius': 14.0, 'relative_humidity': 45.8, 'windspeed_knots': 6.5, 'max_wind_speed': 9.9, 'GHI_w/m2': 124.0, 'precipitation_flag': 'G', 'precipitation': 0.0, 'latest_date': '2028-01-14T00:00:00', 'producer_id': 'producer1_climate', 'fire_events': [{'created_time': '11:53:15', 'created_hour': '11', 'average_surface_temp': 53.0, 'confidence': 80.0, 'cause': 'others'}]}]
# BACK TO MAIN FUNCTION
# ADD TO DATABASE
# ADD SUCCESSFUL:  <pymongo.results.InsertOneResult object at 0x7fda9dd44310>
# IN PROCESS HOTSPOTS
# IN AQUA
# IN AQUA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN PROCESS CLIMATE
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# FIRE_EVENTS:  []
# CLIMATE RECORD FROM PROCESS CLIMATE:  [{'latitude': -36.1462, 'longitude': 145.2096, 'air_temperature_celcius': 10.0, 'relative_humidity': 43.6, 'windspeed_knots': 9.7, 'max_wind_speed': 14.0, 'GHI_w/m2': 90.0, 'precipitation_flag': 'G', 'precipitation': 0.2, 'latest_date': '2028-01-15T00:00:00', 'producer_id': 'producer1_climate', 'fire_events': []}]
# BACK TO MAIN FUNCTION
# ADD TO DATABASE
# ADD SUCCESSFUL:  <pymongo.results.InsertOneResult object at 0x7fda9dd44310>
# IN PROCESS HOTSPOTS
# IN AQUA
# IN AQUA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN PROCESS CLIMATE
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# FIRE_EVENTS:  []
# CLIMATE RECORD FROM PROCESS CLIMATE:  [{'latitude': -37.478, 'longitude': 148.117, 'air_temperature_celcius': 11.0, 'relative_humidity': 43.9, 'windspeed_knots': 11.2, 'max_wind_speed': 16.9, 'GHI_w/m2': 99.0, 'precipitation_flag': 'G', 'precipitation': 0.12, 'latest_date': '2028-01-16T00:00:00', 'producer_id': 'producer1_climate', 'fire_events': []}]
# BACK TO MAIN FUNCTION
# ADD TO DATABASE
# ADD SUCCESSFUL:  <pymongo.results.InsertOneResult object at 0x7fda9dd44a90>
# IN PROCESS HOTSPOTS
# IN AQUA
# IN AQUA
# IN AQUA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN PROCESS CLIMATE
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# FIRE_EVENTS:  []
# CLIMATE RECORD FROM PROCESS CLIMATE:  [{'latitude': -37.623, 'longitude': 149.284, 'air_temperature_celcius': 21.0, 'relative_humidity': 64.5, 'windspeed_knots': 10.6, 'max_wind_speed': 15.9, 'GHI_w/m2': 158.0, 'precipitation_flag': 'G', 'precipitation': 1.26, 'latest_date': '2028-01-17T00:00:00', 'producer_id': 'producer1_climate', 'fire_events': []}]
# BACK TO MAIN FUNCTION
# ADD TO DATABASE
# ADD SUCCESSFUL:  <pymongo.results.InsertOneResult object at 0x7fda9dd443a0>
# IN PROCESS HOTSPOTS
# IN AQUA
# IN AQUA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN PROCESS CLIMATE
# IN PROCESS FIRE EVENT
# FIRE_EVENTS:  []
# CLIMATE RECORD FROM PROCESS CLIMATE:  [{'latitude': -38.498, 'longitude': 146.95, 'air_temperature_celcius': 5.0, 'relative_humidity': 38.6, 'windspeed_knots': 1.8, 'max_wind_speed': 5.1, 'GHI_w/m2': 47.0, 'precipitation_flag': 'I', 'precipitation': 0.0, 'latest_date': '2028-01-18T00:00:00', 'producer_id': 'producer1_climate', 'fire_events': []}]
# BACK TO MAIN FUNCTION
# ADD TO DATABASE
# ADD SUCCESSFUL:  <pymongo.results.InsertOneResult object at 0x7fda9dd44d90>
# IN PROCESS HOTSPOTS
# IN AQUA
# IN AQUA
# IN AQUA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN PROCESS CLIMATE
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# FIRE_EVENTS:  []
# CLIMATE RECORD FROM PROCESS CLIMATE:  [{'latitude': -37.8147, 'longitude': 143.1062, 'air_temperature_celcius': 17.0, 'relative_humidity': 46.4, 'windspeed_knots': 9.5, 'max_wind_speed': 20.0, 'GHI_w/m2': 150.0, 'precipitation_flag': 'I', 'precipitation': 0.0, 'latest_date': '2028-01-19T00:00:00', 'producer_id': 'producer1_climate', 'fire_events': []}]
# BACK TO MAIN FUNCTION
# ADD TO DATABASE
# ADD SUCCESSFUL:  <pymongo.results.InsertOneResult object at 0x7fda9dd44100>
# IN PROCESS HOTSPOTS
# IN AQUA
# IN AQUA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN PROCESS CLIMATE
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# FIRE_EVENTS:  []
# CLIMATE RECORD FROM PROCESS CLIMATE:  [{'latitude': -37.605, 'longitude': 149.326, 'air_temperature_celcius': 23.0, 'relative_humidity': 49.6, 'windspeed_knots': 10.0, 'max_wind_speed': 19.0, 'GHI_w/m2': 198.0, 'precipitation_flag': 'I', 'precipitation': 0.0, 'latest_date': '2028-01-20T00:00:00', 'producer_id': 'producer1_climate', 'fire_events': []}]
# BACK TO MAIN FUNCTION
# ADD TO DATABASE
# ADD SUCCESSFUL:  <pymongo.results.InsertOneResult object at 0x7fda9dd44d90>
# IN PROCESS HOTSPOTS
# IN AQUA
# IN AQUA
# IN AQUA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN PROCESS CLIMATE
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# FIRE_EVENTS:  []
# CLIMATE RECORD FROM PROCESS CLIMATE:  [{'latitude': -37.456, 'longitude': 148.11, 'air_temperature_celcius': 10.0, 'relative_humidity': 47.9, 'windspeed_knots': 4.1, 'max_wind_speed': 7.0, 'GHI_w/m2': 87.0, 'precipitation_flag': 'I', 'precipitation': 0.0, 'latest_date': '2028-01-21T00:00:00', 'producer_id': 'producer1_climate', 'fire_events': []}]
# BACK TO MAIN FUNCTION
# ADD TO DATABASE
# ADD SUCCESSFUL:  <pymongo.results.InsertOneResult object at 0x7fda9ccc4370>
# IN PROCESS HOTSPOTS
# IN AQUA
# IN AQUA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN PROCESS CLIMATE
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# FIRE_EVENTS:  []
# CLIMATE RECORD FROM PROCESS CLIMATE:  [{'latitude': -36.4553, 'longitude': 142.8786, 'air_temperature_celcius': 19.0, 'relative_humidity': 55.3, 'windspeed_knots': 6.2, 'max_wind_speed': 12.0, 'GHI_w/m2': 156.0, 'precipitation_flag': 'I', 'precipitation': 0.0, 'latest_date': '2028-01-22T00:00:00', 'producer_id': 'producer1_climate', 'fire_events': []}]
# BACK TO MAIN FUNCTION
# ADD TO DATABASE
# ADD SUCCESSFUL:  <pymongo.results.InsertOneResult object at 0x7fda9ccc4af0>
# IN PROCESS HOTSPOTS
# IN AQUA
# IN AQUA
# IN AQUA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN PROCESS CLIMATE
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# FIRE_EVENTS:  []
# CLIMATE RECORD FROM PROCESS CLIMATE:  [{'latitude': -37.406, 'longitude': 148.123, 'air_temperature_celcius': 12.0, 'relative_humidity': 44.7, 'windspeed_knots': 11.4, 'max_wind_speed': 18.1, 'GHI_w/m2': 107.0, 'precipitation_flag': 'G', 'precipitation': 0.0, 'latest_date': '2028-01-23T00:00:00', 'producer_id': 'producer1_climate', 'fire_events': []}]
# BACK TO MAIN FUNCTION
# ADD TO DATABASE
# ADD SUCCESSFUL:  <pymongo.results.InsertOneResult object at 0x7fda9ccc4940>
# IN PROCESS HOTSPOTS
# IN AQUA
# IN AQUA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN PROCESS CLIMATE
# IN PROCESS FIRE EVENT
# hotspots_record:  {'latitude': -37.6659, 'longitude': 143.186, 'confidence': 61.0, 'surface_temperature_celcius': 41.0, 'created_time': '11:53:15', 'producer_id': 'producer3_hotspot_terra'}
# FIRE HAPPENING:  {'created_time': '11:53:15', 'created_hour': '11', 'average_surface_temp': 41.0, 'confidence': 61.0, 'cause': 'others'}
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# FIRE_EVENTS:  [{'created_time': '11:53:15', 'created_hour': '11', 'average_surface_temp': 41.0, 'confidence': 61.0, 'cause': 'others'}]
# CLIMATE RECORD FROM PROCESS CLIMATE:  [{'latitude': -37.6745, 'longitude': 142.9848, 'air_temperature_celcius': 15.0, 'relative_humidity': 44.5, 'windspeed_knots': 10.2, 'max_wind_speed': 14.0, 'GHI_w/m2': 134.0, 'precipitation_flag': 'G', 'precipitation': 0.0, 'latest_date': '2028-01-24T00:00:00', 'producer_id': 'producer1_climate', 'fire_events': [{'created_time': '11:53:15', 'created_hour': '11', 'average_surface_temp': 41.0, 'confidence': 61.0, 'cause': 'others'}]}]
# BACK TO MAIN FUNCTION
# ADD TO DATABASE
# ADD SUCCESSFUL:  <pymongo.results.InsertOneResult object at 0x7fda9ccc4580>
# IN PROCESS HOTSPOTS
# IN AQUA
# IN AQUA
# IN AQUA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN PROCESS CLIMATE
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# FIRE_EVENTS:  []
# CLIMATE RECORD FROM PROCESS CLIMATE:  [{'latitude': -36.404, 'longitude': 142.5467, 'air_temperature_celcius': 25.0, 'relative_humidity': 60.9, 'windspeed_knots': 6.3, 'max_wind_speed': 8.9, 'GHI_w/m2': 195.0, 'precipitation_flag': 'I', 'precipitation': 0.0, 'latest_date': '2028-01-25T00:00:00', 'producer_id': 'producer1_climate', 'fire_events': []}]
# BACK TO MAIN FUNCTION
# ADD TO DATABASE
# ADD SUCCESSFUL:  <pymongo.results.InsertOneResult object at 0x7fda9ccc4760>
# IN PROCESS HOTSPOTS
# IN AQUA
# IN AQUA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN PROCESS CLIMATE
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# FIRE_EVENTS:  []
# CLIMATE RECORD FROM PROCESS CLIMATE:  [{'latitude': -37.623, 'longitude': 149.323, 'air_temperature_celcius': 19.0, 'relative_humidity': 56.8, 'windspeed_knots': 7.9, 'max_wind_speed': 11.1, 'GHI_w/m2': 154.0, 'precipitation_flag': 'I', 'precipitation': 0.0, 'latest_date': '2028-01-26T00:00:00', 'producer_id': 'producer1_climate', 'fire_events': []}]
# BACK TO MAIN FUNCTION
# ADD TO DATABASE
# ADD SUCCESSFUL:  <pymongo.results.InsertOneResult object at 0x7fda9ccc4670>
# IN PROCESS HOTSPOTS
# IN AQUA
# IN AQUA
# IN AQUA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN PROCESS CLIMATE
# FIRE_EVENTS:  []
# CLIMATE RECORD FROM PROCESS CLIMATE:  [{'latitude': -38.038, 'longitude': 142.986, 'air_temperature_celcius': 15.0, 'relative_humidity': 50.7, 'windspeed_knots': 9.2, 'max_wind_speed': 13.0, 'GHI_w/m2': 128.0, 'precipitation_flag': 'G', 'precipitation': 0.02, 'latest_date': '2028-01-27T00:00:00', 'producer_id': 'producer1_climate', 'fire_events': []}]
# BACK TO MAIN FUNCTION
# ADD TO DATABASE
# ADD SUCCESSFUL:  <pymongo.results.InsertOneResult object at 0x7fda9ccc47f0>
# IN PROCESS HOTSPOTS
# IN AQUA
# IN AQUA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN PROCESS CLIMATE
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# hotspots_record:  {'latitude': -37.2341, 'longitude': 149.1736, 'confidence': 80.0, 'surface_temperature_celcius': 53.0, 'created_time': '11:53:15', 'producer_id': 'producer3_hotspot_terra'}
# FIRE HAPPENING:  {'created_time': '11:53:15', 'created_hour': '11', 'average_surface_temp': 53.0, 'confidence': 80.0, 'cause': 'others'}
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# FIRE_EVENTS:  [{'created_time': '11:53:15', 'created_hour': '11', 'average_surface_temp': 53.0, 'confidence': 80.0, 'cause': 'others'}]
# CLIMATE RECORD FROM PROCESS CLIMATE:  [{'latitude': -37.245, 'longitude': 143.426, 'air_temperature_celcius': 10.0, 'relative_humidity': 47.0, 'windspeed_knots': 5.2, 'max_wind_speed': 8.9, 'GHI_w/m2': 88.0, 'precipitation_flag': 'I', 'precipitation': 0.0, 'latest_date': '2028-01-28T00:00:00', 'producer_id': 'producer1_climate', 'fire_events': [{'created_time': '11:53:15', 'created_hour': '11', 'average_surface_temp': 53.0, 'confidence': 80.0, 'cause': 'others'}]}]
# BACK TO MAIN FUNCTION
# ADD TO DATABASE
# ADD SUCCESSFUL:  <pymongo.results.InsertOneResult object at 0x7fda9ccc4ac0>
# IN PROCESS HOTSPOTS
# IN AQUA
# IN AQUA
# IN AQUA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN PROCESS CLIMATE
# IN PROCESS FIRE EVENT
# FIRE_EVENTS:  []
# CLIMATE RECORD FROM PROCESS CLIMATE:  [{'latitude': -38.141, 'longitude': 143.183, 'air_temperature_celcius': 23.0, 'relative_humidity': 54.1, 'windspeed_knots': 5.7, 'max_wind_speed': 14.0, 'GHI_w/m2': 190.0, 'precipitation_flag': 'I', 'precipitation': 0.0, 'latest_date': '2028-01-29T00:00:00', 'producer_id': 'producer1_climate', 'fire_events': []}]
# BACK TO MAIN FUNCTION
# ADD TO DATABASE
# ADD SUCCESSFUL:  <pymongo.results.InsertOneResult object at 0x7fda9ccc4730>
# IN PROCESS HOTSPOTS
# IN AQUA
# IN AQUA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN PROCESS CLIMATE
# IN PROCESS FIRE EVENT
# hotspots_record:  {'latitude': -37.45, 'longitude': 148.097, 'confidence': 70.0, 'surface_temperature_celcius': 37.0, 'created_time': '19:05:15', 'producer_id': 'producer2_hotspot_aqua'}
# FIRE HAPPENING:  {'created_time': '19:05:15', 'created_hour': '19', 'average_surface_temp': 37.0, 'confidence': 70.0, 'cause': 'others'}
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# hotspots_record:  {'latitude': -37.467, 'longitude': 143.351, 'confidence': 72.0, 'surface_temperature_celcius': 47.0, 'created_time': '11:53:15', 'producer_id': 'producer3_hotspot_terra'}
# FIRE HAPPENING:  {'created_time': '11:53:15', 'created_hour': '11', 'average_surface_temp': 47.0, 'confidence': 72.0, 'cause': 'others'}
# FIRE_EVENTS:  [{'created_time': '19:05:15', 'created_hour': '19', 'average_surface_temp': 37.0, 'confidence': 70.0, 'cause': 'others'}, {'created_time': '11:53:15', 'created_hour': '11', 'average_surface_temp': 47.0, 'confidence': 72.0, 'cause': 'others'}]
# CLIMATE RECORD FROM PROCESS CLIMATE:  [{'latitude': -37.4437, 'longitude': 143.4924, 'air_temperature_celcius': 13.0, 'relative_humidity': 50.7, 'windspeed_knots': 6.1, 'max_wind_speed': 13.0, 'GHI_w/m2': 111.0, 'precipitation_flag': 'I', 'precipitation': 0.0, 'latest_date': '2028-01-30T00:00:00', 'producer_id': 'producer1_climate', 'fire_events': [{'created_time': '19:05:15', 'created_hour': '19', 'average_surface_temp': 37.0, 'confidence': 70.0, 'cause': 'others'}, {'created_time': '11:53:15', 'created_hour': '11', 'average_surface_temp': 47.0, 'confidence': 72.0, 'cause': 'others'}]}]
# BACK TO MAIN FUNCTION
# ADD TO DATABASE
# ADD SUCCESSFUL:  <pymongo.results.InsertOneResult object at 0x7fda9ccc4070>
# IN PROCESS HOTSPOTS
# IN AQUA
# IN AQUA
# IN AQUA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN PROCESS CLIMATE
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# FIRE_EVENTS:  []
# CLIMATE RECORD FROM PROCESS CLIMATE:  [{'latitude': -36.0279, 'longitude': 146.0244, 'air_temperature_celcius': 24.0, 'relative_humidity': 60.1, 'windspeed_knots': 8.0, 'max_wind_speed': 13.0, 'GHI_w/m2': 188.0, 'precipitation_flag': 'G', 'precipitation': 0.12, 'latest_date': '2028-01-31T00:00:00', 'producer_id': 'producer1_climate', 'fire_events': []}]
# BACK TO MAIN FUNCTION
# ADD TO DATABASE
# ADD SUCCESSFUL:  <pymongo.results.InsertOneResult object at 0x7fda9ccc4490>
# IN PROCESS HOTSPOTS
# IN AQUA
# IN AQUA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN PROCESS CLIMATE
# IN PROCESS FIRE EVENT
# FIRE_EVENTS:  []
# CLIMATE RECORD FROM PROCESS CLIMATE:  [{'latitude': -38.495, 'longitude': 146.944, 'air_temperature_celcius': 8.0, 'relative_humidity': 44.6, 'windspeed_knots': 3.9, 'max_wind_speed': 8.0, 'GHI_w/m2': 72.0, 'precipitation_flag': 'G', 'precipitation': 0.39, 'latest_date': '2028-02-01T00:00:00', 'producer_id': 'producer1_climate', 'fire_events': []}]
# BACK TO MAIN FUNCTION
# ADD TO DATABASE
# ADD SUCCESSFUL:  <pymongo.results.InsertOneResult object at 0x7fda9ccc4d00>
# IN PROCESS HOTSPOTS
# IN AQUA
# IN AQUA
# IN AQUA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN PROCESS CLIMATE
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# FIRE_EVENTS:  []
# CLIMATE RECORD FROM PROCESS CLIMATE:  [{'latitude': -36.2669, 'longitude': 143.1906, 'air_temperature_celcius': 12.0, 'relative_humidity': 42.7, 'windspeed_knots': 10.0, 'max_wind_speed': 15.9, 'GHI_w/m2': 109.0, 'precipitation_flag': 'G', 'precipitation': 0.01, 'latest_date': '2028-02-02T00:00:00', 'producer_id': 'producer1_climate', 'fire_events': []}]
# BACK TO MAIN FUNCTION
# ADD TO DATABASE
# ADD SUCCESSFUL:  <pymongo.results.InsertOneResult object at 0x7fda9ccc4790>
# ERROR:root:KeyboardInterrupt while sending command.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.8/site-packages/py4j/java_gateway.py", line 1038, in send_command
#     response = connection.send_command(command)
#   File "/opt/conda/lib/python3.8/site-packages/py4j/clientserver.py", line 511, in send_command
#     answer = smart_decode(self.stream.readline()[:-1])
#   File "/opt/conda/lib/python3.8/socket.py", line 669, in readinto
#     return self._sock.recv_into(b)
# KeyboardInterrupt
# IN PROCESS HOTSPOTS
# IN AQUA
# IN AQUA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN TERRA
# IN PROCESS CLIMATE
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# IN PROCESS FIRE EVENT
# FIRE_EVENTS:  []
# CLIMATE RECORD FROM PROCESS CLIMATE:  [{'latitude': -36.8948, 'longitude': 142.3282, 'air_temperature_celcius': 9.0, 'relative_humidity': 41.2, 'windspeed_knots': 6.7, 'max_wind_speed': 13.0, 'GHI_w/m2': 83.0, 'precipitation_flag': 'G', 'precipitation': 0.01, 'latest_date': '2028-02-03T00:00:00', 'producer_id': 'producer1_climate', 'fire_events': []}]
# BACK TO MAIN FUNCTION
# ADD TO DATABASE
# ADD SUCCESSFUL:  <pymongo.results.InsertOneResult object at 0x7fda9ccc47f0>
# Interrupted by CTRL-C. Stopping query.

# %% [markdown]
# ### Double Check data is added to MongoDB

# %%
client = MongoClient(f'mongodb://{hostip}:27017/')
db = client.fit3182_assignment_db
climate_collection = db.climate_collection
cursor = db.climate_collection.find({})

for document in cursor:
    pprint(document)
# Out:
# {'_id': ObjectId('664ca4c85680a216c5999e2b'),
#  'air_temperature_celcius': 13.0,
#  'fire_events': [],
#  'ghi': 113.0,
#  'latest_date': '2023-03-24T00:00:00',
#  'latitude': -37.459,
#  'longitude': 148.092,
#  'max_wind_speed': 15.9,
#  'precipitation': 0.0,
#  'precipitation_type': 'G',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 48.5,
#  'windspeed_knots': 7.1}
# {'_id': ObjectId('664ca6b50be2acee2738400b'),
#  'air_temperature_celcius': 13.0,
#  'fire_events': [],
#  'ghi': 110.0,
#  'latest_date': '2023-01-17T00:00:00',
#  'latitude': -36.156,
#  'longitude': 143.568,
#  'max_wind_speed': 8.9,
#  'precipitation': 0.0,
#  'precipitation_type': 'I',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 51.4,
#  'windspeed_knots': 4.6}
# {'_id': ObjectId('664ca8f5a87ea706395d5814'),
#  'air_temperature_celcius': 11.0,
#  'fire_events': [],
#  'ghi': 99.0,
#  'latest_date': '2024-01-08T00:00:00',
#  'latitude': -37.478,
#  'longitude': 148.117,
#  'max_wind_speed': 16.9,
#  'precipitation': 0.12,
#  'precipitation_type': 'G',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 43.9,
#  'windspeed_knots': 11.2}
# {'_id': ObjectId('664ca8ffa87ea706395d5816'),
#  'air_temperature_celcius': 13.0,
#  'fire_events': [],
#  'ghi': 118.0,
#  'latest_date': '2024-01-09T00:00:00',
#  'latitude': -37.3583,
#  'longitude': 143.0203,
#  'max_wind_speed': 14.0,
#  'precipitation': 0.0,
#  'precipitation_type': 'G',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 43.3,
#  'windspeed_knots': 9.4}
# {'_id': ObjectId('664ca908a87ea706395d5818'),
#  'air_temperature_celcius': 25.0,
#  'fire_events': [],
#  'ghi': 199.0,
#  'latest_date': '2024-01-10T00:00:00',
#  'latitude': -37.583,
#  'longitude': 149.316,
#  'max_wind_speed': 22.0,
#  'precipitation': 0.04,
#  'precipitation_type': 'G',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 58.3,
#  'windspeed_knots': 12.2}
# {'_id': ObjectId('664ca913a87ea706395d581a'),
#  'air_temperature_celcius': 17.0,
#  'fire_events': [],
#  'ghi': 145.0,
#  'latest_date': '2024-01-11T00:00:00',
#  'latitude': -37.1815,
#  'longitude': 146.7777,
#  'max_wind_speed': 16.9,
#  'precipitation': 0.0,
#  'precipitation_type': 'I',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 50.4,
#  'windspeed_knots': 10.8}
# {'_id': ObjectId('664ca91ca87ea706395d581c'),
#  'air_temperature_celcius': 19.0,
#  'fire_events': [],
#  'ghi': 159.0,
#  'latest_date': '2024-01-12T00:00:00',
#  'latitude': -38.0427,
#  'longitude': 141.0271,
#  'max_wind_speed': 15.0,
#  'precipitation': 0.0,
#  'precipitation_type': 'I',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 52.9,
#  'windspeed_knots': 8.1}
# {'_id': ObjectId('664ca926a87ea706395d581e'),
#  'air_temperature_celcius': 18.0,
#  'fire_events': [],
#  'ghi': 150.0,
#  'latest_date': '2024-01-13T00:00:00',
#  'latitude': -35.779,
#  'longitude': 143.1057,
#  'max_wind_speed': 13.0,
#  'precipitation': 0.0,
#  'precipitation_type': 'I',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 53.7,
#  'windspeed_knots': 9.0}
# {'_id': ObjectId('664ca930a87ea706395d5820'),
#  'air_temperature_celcius': 15.0,
#  'fire_events': [],
#  'ghi': 130.0,
#  'latest_date': '2024-01-14T00:00:00',
#  'latitude': -34.282,
#  'longitude': 142.121,
#  'max_wind_speed': 16.9,
#  'precipitation': 0.01,
#  'precipitation_type': 'G',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 49.1,
#  'windspeed_knots': 9.6}
# {'_id': ObjectId('664ca93aa87ea706395d5822'),
#  'air_temperature_celcius': 26.0,
#  'fire_events': [],
#  'ghi': 219.0,
#  'latest_date': '2024-01-15T00:00:00',
#  'latitude': -37.062,
#  'longitude': 141.373,
#  'max_wind_speed': 16.9,
#  'precipitation': 0.0,
#  'precipitation_type': 'I',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 52.2,
#  'windspeed_knots': 13.7}
# {'_id': ObjectId('664ca944a87ea706395d5824'),
#  'air_temperature_celcius': 20.0,
#  'fire_events': [],
#  'ghi': 161.0,
#  'latest_date': '2024-01-16T00:00:00',
#  'latitude': -36.277,
#  'longitude': 146.165,
#  'max_wind_speed': 13.0,
#  'precipitation': 0.0,
#  'precipitation_type': 'I',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 57.0,
#  'windspeed_knots': 8.7}
# {'_id': ObjectId('664ca94ea87ea706395d5826'),
#  'air_temperature_celcius': 10.0,
#  'fire_events': [],
#  'ghi': 91.0,
#  'latest_date': '2024-01-17T00:00:00',
#  'latitude': -35.954,
#  'longitude': 141.076,
#  'max_wind_speed': 15.0,
#  'precipitation': 0.13,
#  'precipitation_type': 'B',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 42.1,
#  'windspeed_knots': 9.4}
# {'_id': ObjectId('664ca958a87ea706395d5828'),
#  'air_temperature_celcius': 11.0,
#  'fire_events': [],
#  'ghi': 102.0,
#  'latest_date': '2024-01-18T00:00:00',
#  'latitude': -37.296,
#  'longitude': 144.386,
#  'max_wind_speed': 20.0,
#  'precipitation': 0.24,
#  'precipitation_type': 'G',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 40.8,
#  'windspeed_knots': 12.2}
# {'_id': ObjectId('664ca962a87ea706395d582a'),
#  'air_temperature_celcius': 21.0,
#  'fire_events': [],
#  'ghi': 177.0,
#  'latest_date': '2024-01-19T00:00:00',
#  'latitude': -37.332,
#  'longitude': 143.375,
#  'max_wind_speed': 13.0,
#  'precipitation': 0.0,
#  'precipitation_type': 'I',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 51.7,
#  'windspeed_knots': 7.2}
# {'_id': ObjectId('664caad5d5b619c543510416'),
#  'air_temperature_celcius': 28.0,
#  'fire_events': [],
#  'ghi': 223.0,
#  'latest_date': '2024-02-25T00:00:00',
#  'latitude': -37.864,
#  'longitude': 144.174,
#  'max_wind_speed': 18.1,
#  'precipitation': 0.04,
#  'precipitation_type': 'G',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 58.4,
#  'windspeed_knots': 11.9}
# {'_id': ObjectId('664cab9362b568195ee2146c'),
#  'air_temperature_celcius': 16.0,
#  'fire_events': [],
#  'ghi': 136.0,
#  'latest_date': '2024-03-15T00:00:00',
#  'latitude': -37.633,
#  'longitude': 149.264,
#  'max_wind_speed': 21.0,
#  'precipitation': 0.03,
#  'precipitation_type': 'G',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 50.9,
#  'windspeed_knots': 12.9}
# {'_id': ObjectId('664cab9c62b568195ee2146e'),
#  'air_temperature_celcius': 18.0,
#  'fire_events': [],
#  'ghi': 140.0,
#  'latest_date': '2024-03-16T00:00:00',
#  'latitude': -36.701,
#  'longitude': 142.538,
#  'max_wind_speed': 11.1,
#  'precipitation': 0.28,
#  'precipitation_type': 'G',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 61.5,
#  'windspeed_knots': 5.5}
# {'_id': ObjectId('664caba662b568195ee21470'),
#  'air_temperature_celcius': 20.0,
#  'fire_events': [],
#  'ghi': 160.0,
#  'latest_date': '2024-03-17T00:00:00',
#  'latitude': -36.294,
#  'longitude': 146.149,
#  'max_wind_speed': 18.1,
#  'precipitation': 0.0,
#  'precipitation_type': 'I',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 57.7,
#  'windspeed_knots': 9.9}
# {'_id': ObjectId('664cabb062b568195ee21472'),
#  'air_temperature_celcius': 10.0,
#  'fire_events': [],
#  'ghi': 93.0,
#  'latest_date': '2024-03-18T00:00:00',
#  'latitude': -36.984,
#  'longitude': 148.25,
#  'max_wind_speed': 16.9,
#  'precipitation': 0.08,
#  'precipitation_type': 'G',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 39.9,
#  'windspeed_knots': 12.6}
# {'_id': ObjectId('664cabba62b568195ee21474'),
#  'air_temperature_celcius': 14.0,
#  'fire_events': [],
#  'ghi': 120.0,
#  'latest_date': '2024-03-19T00:00:00',
#  'latitude': -37.399,
#  'longitude': 148.081,
#  'max_wind_speed': 22.0,
#  'precipitation': 0.03,
#  'precipitation_type': 'G',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 49.9,
#  'windspeed_knots': 13.7}
# {'_id': ObjectId('664cabc462b568195ee21476'),
#  'air_temperature_celcius': 14.0,
#  'fire_events': [],
#  'ghi': 117.0,
#  'latest_date': '2024-03-20T00:00:00',
#  'latitude': -37.588,
#  'longitude': 141.259,
#  'max_wind_speed': 18.1,
#  'precipitation': 0.98,
#  'precipitation_type': 'G',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 52.8,
#  'windspeed_knots': 9.3}
# {'_id': ObjectId('664cabce62b568195ee21478'),
#  'air_temperature_celcius': 18.0,
#  'fire_events': [],
#  'ghi': 149.0,
#  'latest_date': '2024-03-21T00:00:00',
#  'latitude': -37.605,
#  'longitude': 149.302,
#  'max_wind_speed': 9.9,
#  'precipitation': 0.0,
#  'precipitation_type': 'I',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 54.4,
#  'windspeed_knots': 5.7}
# {'_id': ObjectId('664cabd862b568195ee2147a'),
#  'air_temperature_celcius': 19.0,
#  'fire_events': [],
#  'ghi': 171.0,
#  'latest_date': '2024-03-22T00:00:00',
#  'latitude': -37.331,
#  'longitude': 143.122,
#  'max_wind_speed': 15.9,
#  'precipitation': 0.0,
#  'precipitation_type': 'I',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 44.2,
#  'windspeed_knots': 7.8}
# {'_id': ObjectId('664cabe262b568195ee2147c'),
#  'air_temperature_celcius': 19.0,
#  'fire_events': [],
#  'ghi': 156.0,
#  'latest_date': '2024-03-23T00:00:00',
#  'latitude': -36.4553,
#  'longitude': 142.8786,
#  'max_wind_speed': 12.0,
#  'precipitation': 0.0,
#  'precipitation_type': 'I',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 55.3,
#  'windspeed_knots': 6.2}
# {'_id': ObjectId('664cabec62b568195ee2147e'),
#  'air_temperature_celcius': 21.0,
#  'fire_events': [],
#  'ghi': 169.0,
#  'latest_date': '2024-03-24T00:00:00',
#  'latitude': -36.4025,
#  'longitude': 142.5598,
#  'max_wind_speed': 22.9,
#  'precipitation': 0.67,
#  'precipitation_type': 'G',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 57.4,
#  'windspeed_knots': 10.7}
# {'_id': ObjectId('664cabf662b568195ee21480'),
#  'air_temperature_celcius': 13.0,
#  'fire_events': [],
#  'ghi': 115.0,
#  'latest_date': '2024-03-25T00:00:00',
#  'latitude': -36.6511,
#  'longitude': 143.915,
#  'max_wind_speed': 12.0,
#  'precipitation': 0.0,
#  'precipitation_type': 'I',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 46.2,
#  'windspeed_knots': 5.6}
# {'_id': ObjectId('664cacfbba0f0b905284d515'),
#  'air_temperature_celcius': 11.0,
#  'fire_events': [],
#  'ghi': 98.0,
#  'latest_date': '2024-04-20T00:00:00',
#  'latitude': -36.398,
#  'longitude': 145.286,
#  'max_wind_speed': 18.1,
#  'precipitation': 0.2,
#  'precipitation_type': 'G',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 45.1,
#  'windspeed_knots': 11.5}
# {'_id': ObjectId('664cad04ba0f0b905284d517'),
#  'air_temperature_celcius': 7.0,
#  'fire_events': [],
#  'ghi': 65.0,
#  'latest_date': '2024-04-21T00:00:00',
#  'latitude': -37.336,
#  'longitude': 148.073,
#  'max_wind_speed': 15.0,
#  'precipitation': 0.12,
#  'precipitation_type': 'G',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 40.5,
#  'windspeed_knots': 8.1}
# {'_id': ObjectId('664cad0eba0f0b905284d519'),
#  'air_temperature_celcius': 17.0,
#  'fire_events': [],
#  'ghi': 150.0,
#  'latest_date': '2024-04-22T00:00:00',
#  'latitude': -36.778,
#  'longitude': 145.1635,
#  'max_wind_speed': 20.0,
#  'precipitation': 0.02,
#  'precipitation_type': 'G',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 46.3,
#  'windspeed_knots': 11.7}
# {'_id': ObjectId('664cad18ba0f0b905284d51b'),
#  'air_temperature_celcius': 15.0,
#  'fire_events': [],
#  'ghi': 128.0,
#  'latest_date': '2024-04-23T00:00:00',
#  'latitude': -36.779,
#  'longitude': 146.108,
#  'max_wind_speed': 15.9,
#  'precipitation': 0.16,
#  'precipitation_type': 'G',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 51.0,
#  'windspeed_knots': 9.6}
# {'_id': ObjectId('664cad22ba0f0b905284d51d'),
#  'air_temperature_celcius': 14.0,
#  'fire_events': [],
#  'ghi': 124.0,
#  'latest_date': '2024-04-24T00:00:00',
#  'latitude': -37.692,
#  'longitude': 143.593,
#  'max_wind_speed': 9.9,
#  'precipitation': 0.0,
#  'precipitation_type': 'G',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 45.8,
#  'windspeed_knots': 6.5}
# {'_id': ObjectId('664cad2cba0f0b905284d51f'),
#  'air_temperature_celcius': 16.0,
#  'fire_events': [],
#  'ghi': 139.0,
#  'latest_date': '2024-04-25T00:00:00',
#  'latitude': -37.6,
#  'longitude': 149.325,
#  'max_wind_speed': 12.0,
#  'precipitation': 0.0,
#  'precipitation_type': 'G',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 48.1,
#  'windspeed_knots': 9.3}
# {'_id': ObjectId('664cad36ba0f0b905284d521'),
#  'air_temperature_celcius': 10.0,
#  'fire_events': [],
#  'ghi': 90.0,
#  'latest_date': '2024-04-26T00:00:00',
#  'latitude': -37.438,
#  'longitude': 148.09,
#  'max_wind_speed': 15.9,
#  'precipitation': 0.08,
#  'precipitation_type': 'G',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 44.7,
#  'windspeed_knots': 8.0}
# {'_id': ObjectId('664cad40ba0f0b905284d523'),
#  'air_temperature_celcius': 17.0,
#  'fire_events': [],
#  'ghi': 143.0,
#  'latest_date': '2024-04-27T00:00:00',
#  'latitude': -37.5915,
#  'longitude': 143.0015,
#  'max_wind_speed': 15.0,
#  'precipitation': 0.0,
#  'precipitation_type': 'I',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 52.0,
#  'windspeed_knots': 8.8}
# {'_id': ObjectId('664cad4aba0f0b905284d525'),
#  'air_temperature_celcius': 19.0,
#  'fire_events': [],
#  'ghi': 157.0,
#  'latest_date': '2024-04-28T00:00:00',
#  'latitude': -36.284,
#  'longitude': 146.145,
#  'max_wind_speed': 18.1,
#  'precipitation': 0.31,
#  'precipitation_type': 'G',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 54.1,
#  'windspeed_knots': 11.2}
# {'_id': ObjectId('664cad54ba0f0b905284d527'),
#  'air_temperature_celcius': 32.0,
#  'fire_events': [],
#  'ghi': 265.0,
#  'latest_date': '2024-04-29T00:00:00',
#  'latitude': -34.289,
#  'longitude': 141.712,
#  'max_wind_speed': 19.0,
#  'precipitation': 0.0,
#  'precipitation_type': 'I',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 54.1,
#  'windspeed_knots': 12.8}
# {'_id': ObjectId('664cad5eba0f0b905284d529'),
#  'air_temperature_celcius': 9.0,
#  'fire_events': [],
#  'ghi': 83.0,
#  'latest_date': '2024-04-30T00:00:00',
#  'latitude': -37.471,
#  'longitude': 148.091,
#  'max_wind_speed': 15.0,
#  'precipitation': 0.01,
#  'precipitation_type': 'G',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 40.8,
#  'windspeed_knots': 6.7}
# {'_id': ObjectId('664cad68ba0f0b905284d52b'),
#  'air_temperature_celcius': 11.0,
#  'fire_events': [],
#  'ghi': 99.0,
#  'latest_date': '2024-05-01T00:00:00',
#  'latitude': -37.365,
#  'longitude': 148.052,
#  'max_wind_speed': 12.0,
#  'precipitation': 0.02,
#  'precipitation_type': 'G',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 43.8,
#  'windspeed_knots': 6.5}
# {'_id': ObjectId('664cad72ba0f0b905284d52d'),
#  'air_temperature_celcius': 15.0,
#  'fire_events': [],
#  'ghi': 128.0,
#  'latest_date': '2024-05-02T00:00:00',
#  'latitude': -38.038,
#  'longitude': 142.986,
#  'max_wind_speed': 13.0,
#  'precipitation': 0.02,
#  'precipitation_type': 'G',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 50.7,
#  'windspeed_knots': 9.2}
# {'_id': ObjectId('664cad7cba0f0b905284d52f'),
#  'air_temperature_celcius': 20.0,
#  'fire_events': [],
#  'ghi': 158.0,
#  'latest_date': '2024-05-03T00:00:00',
#  'latitude': -37.954,
#  'longitude': 143.918,
#  'max_wind_speed': 15.9,
#  'precipitation': 0.01,
#  'precipitation_type': 'G',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 59.7,
#  'windspeed_knots': 8.6}
# {'_id': ObjectId('664cad86ba0f0b905284d531'),
#  'air_temperature_celcius': 15.0,
#  'fire_events': [],
#  'ghi': 131.0,
#  'latest_date': '2024-05-04T00:00:00',
#  'latitude': -36.543,
#  'longitude': 141.138,
#  'max_wind_speed': 13.0,
#  'precipitation': 0.0,
#  'precipitation_type': 'I',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 47.7,
#  'windspeed_knots': 5.9}
# {'_id': ObjectId('664cae65e60093103de59826'),
#  'air_temperature_celcius': 14.0,
#  'fire_events': [],
#  'ghi': 122.0,
#  'latest_date': '2024-05-26T00:00:00',
#  'latitude': -37.249,
#  'longitude': 143.413,
#  'max_wind_speed': 9.9,
#  'precipitation': 0.0,
#  'precipitation_type': 'I',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 47.9,
#  'windspeed_knots': 5.3}
# {'_id': ObjectId('664cae6ce60093103de59828'),
#  'air_temperature_celcius': 20.0,
#  'fire_events': [],
#  'ghi': 159.0,
#  'latest_date': '2024-05-27T00:00:00',
#  'latitude': -37.758,
#  'longitude': 144.693,
#  'max_wind_speed': 15.9,
#  'precipitation': 0.0,
#  'precipitation_type': 'I',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 58.8,
#  'windspeed_knots': 11.5}
# {'_id': ObjectId('664cae76e60093103de5982a'),
#  'air_temperature_celcius': 15.0,
#  'fire_events': [],
#  'ghi': 131.0,
#  'latest_date': '2024-05-28T00:00:00',
#  'latitude': -36.9085,
#  'longitude': 141.2821,
#  'max_wind_speed': 22.9,
#  'precipitation': 0.0,
#  'precipitation_type': 'I',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 47.3,
#  'windspeed_knots': 8.6}
# {'_id': ObjectId('664cae80e60093103de5982c'),
#  'air_temperature_celcius': 18.0,
#  'fire_events': [],
#  'ghi': 147.0,
#  'latest_date': '2024-05-29T00:00:00',
#  'latitude': -36.0201,
#  'longitude': 143.7775,
#  'max_wind_speed': 12.0,
#  'precipitation': 0.0,
#  'precipitation_type': 'I',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 55.6,
#  'windspeed_knots': 8.2}
# {'_id': ObjectId('664cae8ae60093103de5982e'),
#  'air_temperature_celcius': 7.0,
#  'fire_events': [],
#  'ghi': 66.0,
#  'latest_date': '2024-05-30T00:00:00',
#  'latitude': -36.3328,
#  'longitude': 146.0355,
#  'max_wind_speed': 16.9,
#  'precipitation': 0.08,
#  'precipitation_type': 'G',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 37.2,
#  'windspeed_knots': 6.2}
# {'_id': ObjectId('664cae94e60093103de59830'),
#  'air_temperature_celcius': 12.0,
#  'fire_events': [],
#  'ghi': 109.0,
#  'latest_date': '2024-05-31T00:00:00',
#  'latitude': -37.242,
#  'longitude': 141.153,
#  'max_wind_speed': 19.0,
#  'precipitation': 0.04,
#  'precipitation_type': 'G',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 42.8,
#  'windspeed_knots': 12.1}
# {'_id': ObjectId('664cae9ee60093103de59832'),
#  'air_temperature_celcius': 14.0,
#  'fire_events': [],
#  'ghi': 117.0,
#  'latest_date': '2024-06-01T00:00:00',
#  'latitude': -37.588,
#  'longitude': 141.259,
#  'max_wind_speed': 18.1,
#  'precipitation': 0.98,
#  'precipitation_type': 'G',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 52.8,
#  'windspeed_knots': 9.3}
# {'_id': ObjectId('664caea8e60093103de59834'),
#  'air_temperature_celcius': 18.0,
#  'fire_events': [],
#  'ghi': 155.0,
#  'latest_date': '2024-06-02T00:00:00',
#  'latitude': -37.611,
#  'longitude': 149.277,
#  'max_wind_speed': 13.0,
#  'precipitation': 0.0,
#  'precipitation_type': 'I',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 49.4,
#  'windspeed_knots': 9.3}
# {'_id': ObjectId('664caeb2e60093103de59836'),
#  'air_temperature_celcius': 10.0,
#  'fire_events': [],
#  'ghi': 90.0,
#  'latest_date': '2024-06-03T00:00:00',
#  'latitude': -36.3823,
#  'longitude': 141.3146,
#  'max_wind_speed': 13.0,
#  'precipitation': 0.08,
#  'precipitation_type': 'G',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 43.7,
#  'windspeed_knots': 9.5}
# {'_id': ObjectId('664caebce60093103de59838'),
#  'air_temperature_celcius': 25.0,
#  'fire_events': [],
#  'ghi': 199.0,
#  'latest_date': '2024-06-04T00:00:00',
#  'latitude': -36.942,
#  'longitude': 143.282,
#  'max_wind_speed': 13.0,
#  'precipitation': 0.0,
#  'precipitation_type': 'I',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 58.3,
#  'windspeed_knots': 7.1}
# {'_id': ObjectId('664caec6e60093103de5983a'),
#  'air_temperature_celcius': 11.0,
#  'fire_events': [],
#  'ghi': 98.0,
#  'latest_date': '2024-06-05T00:00:00',
#  'latitude': -37.453,
#  'longitude': 148.111,
#  'max_wind_speed': 16.9,
#  'precipitation': 0.08,
#  'precipitation_type': 'G',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 45.3,
#  'windspeed_knots': 10.6}
# {'_id': ObjectId('664caed0e60093103de5983c'),
#  'air_temperature_celcius': 18.0,
#  'fire_events': [],
#  'ghi': 150.0,
#  'latest_date': '2024-06-06T00:00:00',
#  'latitude': -37.382,
#  'longitude': 149.341,
#  'max_wind_speed': 15.0,
#  'precipitation': 0.0,
#  'precipitation_type': 'I',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 53.6,
#  'windspeed_knots': 7.2}
# {'_id': ObjectId('664caedae60093103de5983e'),
#  'air_temperature_celcius': 17.0,
#  'fire_events': [],
#  'ghi': 142.0,
#  'latest_date': '2024-06-07T00:00:00',
#  'latitude': -37.9243,
#  'longitude': 144.1064,
#  'max_wind_speed': 22.9,
#  'precipitation': 0.0,
#  'precipitation_type': 'I',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 53.0,
#  'windspeed_knots': 14.6}
# {'_id': ObjectId('664caee4e60093103de59840'),
#  'air_temperature_celcius': 8.0,
#  'fire_events': [],
#  'ghi': 75.0,
#  'latest_date': '2024-06-08T00:00:00',
#  'latitude': -36.5548,
#  'longitude': 142.5237,
#  'max_wind_speed': 18.1,
#  'precipitation': 0.31,
#  'precipitation_type': 'G',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 38.6,
#  'windspeed_knots': 12.8}
# {'_id': ObjectId('664caeeee60093103de59842'),
#  'air_temperature_celcius': 8.0,
#  'fire_events': [],
#  'ghi': 72.0,
#  'latest_date': '2024-06-09T00:00:00',
#  'latitude': -38.495,
#  'longitude': 146.944,
#  'max_wind_speed': 8.0,
#  'precipitation': 0.39,
#  'precipitation_type': 'G',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 44.6,
#  'windspeed_knots': 3.9}
# {'_id': ObjectId('664caef8e60093103de59844'),
#  'air_temperature_celcius': 9.0,
#  'fire_events': [],
#  'ghi': 81.0,
#  'latest_date': '2024-06-10T00:00:00',
#  'latitude': -38.127,
#  'longitude': 143.82,
#  'max_wind_speed': 8.0,
#  'precipitation': 0.0,
#  'precipitation_type': 'I',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 44.0,
#  'windspeed_knots': 2.8}
# {'_id': ObjectId('664caf02e60093103de59846'),
#  'air_temperature_celcius': 24.0,
#  'fire_events': [],
#  'ghi': 194.0,
#  'latest_date': '2024-06-11T00:00:00',
#  'latitude': -36.3096,
#  'longitude': 142.7722,
#  'max_wind_speed': 9.9,
#  'precipitation': 0.0,
#  'precipitation_type': 'I',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 56.8,
#  'windspeed_knots': 5.7}
# {'_id': ObjectId('664caf0ce60093103de59848'),
#  'air_temperature_celcius': 9.0,
#  'fire_events': [],
#  'ghi': 82.0,
#  'latest_date': '2024-06-12T00:00:00',
#  'latitude': -37.444,
#  'longitude': 148.101,
#  'max_wind_speed': 12.0,
#  'precipitation': 0.0,
#  'precipitation_type': 'I',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 42.0,
#  'windspeed_knots': 4.6}
# {'_id': ObjectId('664caf16e60093103de5984a'),
#  'air_temperature_celcius': 15.0,
#  'fire_events': [],
#  'ghi': 130.0,
#  'latest_date': '2024-06-13T00:00:00',
#  'latitude': -34.282,
#  'longitude': 142.121,
#  'max_wind_speed': 16.9,
#  'precipitation': 0.01,
#  'precipitation_type': 'G',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 49.1,
#  'windspeed_knots': 9.6}
# {'_id': ObjectId('664cb043fef7e795e29aec05'),
#  'air_temperature_celcius': 10.0,
#  'fire_events': [],
#  'ghi': 90.0,
#  'latest_date': '2024-01-03T00:00:00',
#  'latitude': -37.448,
#  'longitude': 148.114,
#  'max_wind_speed': 11.1,
#  'precipitation': 0.12,
#  'precipitation_type': 'G',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 44.4,
#  'windspeed_knots': 5.6}
# {'_id': ObjectId('664cb04cfef7e795e29aec07'),
#  'air_temperature_celcius': 18.0,
#  'fire_events': [],
#  'ghi': 150.0,
#  'latest_date': '2024-01-04T00:00:00',
#  'latitude': -37.598,
#  'longitude': 149.29,
#  'max_wind_speed': 13.0,
#  'precipitation': 0.0,
#  'precipitation_type': 'I',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 53.5,
#  'windspeed_knots': 8.8}
# {'_id': ObjectId('664cb056fef7e795e29aec09'),
#  'air_temperature_celcius': 11.0,
#  'fire_events': [],
#  'ghi': 101.0,
#  'latest_date': '2024-01-05T00:00:00',
#  'latitude': -36.8835,
#  'longitude': 142.2098,
#  'max_wind_speed': 15.0,
#  'precipitation': 0.01,
#  'precipitation_type': 'G',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 41.6,
#  'windspeed_knots': 7.9}
# {'_id': ObjectId('664cb060fef7e795e29aec0b'),
#  'air_temperature_celcius': 8.0,
#  'fire_events': [],
#  'ghi': 72.0,
#  'latest_date': '2024-01-06T00:00:00',
#  'latitude': -37.229,
#  'longitude': 141.182,
#  'max_wind_speed': 7.0,
#  'precipitation': 0.01,
#  'precipitation_type': 'G',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 44.5,
#  'windspeed_knots': 4.7}
# {'_id': ObjectId('664cb06afef7e795e29aec0d'),
#  'air_temperature_celcius': 16.0,
#  'fire_events': [],
#  'ghi': 139.0,
#  'latest_date': '2024-01-07T00:00:00',
#  'latitude': -37.38,
#  'longitude': 149.334,
#  'max_wind_speed': 18.1,
#  'precipitation': 0.01,
#  'precipitation_type': 'G',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 48.2,
#  'windspeed_knots': 9.9}
# {'_id': ObjectId('664cb074fef7e795e29aec0f'),
#  'air_temperature_celcius': 18.0,
#  'fire_events': [],
#  'ghi': 150.0,
#  'latest_date': '2024-01-08T00:00:00',
#  'latitude': -35.779,
#  'longitude': 143.1057,
#  'max_wind_speed': 13.0,
#  'precipitation': 0.0,
#  'precipitation_type': 'I',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 53.7,
#  'windspeed_knots': 9.0}
# {'_id': ObjectId('664cb07efef7e795e29aec11'),
#  'air_temperature_celcius': 14.0,
#  'fire_events': [],
#  'ghi': 119.0,
#  'latest_date': '2024-01-09T00:00:00',
#  'latitude': -37.856,
#  'longitude': 143.416,
#  'max_wind_speed': 12.0,
#  'precipitation': 0.0,
#  'precipitation_type': 'G',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 51.0,
#  'windspeed_knots': 9.1}
# {'_id': ObjectId('664cb088fef7e795e29aec13'),
#  'air_temperature_celcius': 8.0,
#  'fire_events': [],
#  'ghi': 74.0,
#  'latest_date': '2024-01-10T00:00:00',
#  'latitude': -37.335,
#  'longitude': 148.064,
#  'max_wind_speed': 16.9,
#  'precipitation': 0.47,
#  'precipitation_type': 'G',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 41.0,
#  'windspeed_knots': 11.0}
# {'_id': ObjectId('664cb092fef7e795e29aec15'),
#  'air_temperature_celcius': 12.0,
#  'fire_events': [],
#  'ghi': 105.0,
#  'latest_date': '2024-01-11T00:00:00',
#  'latitude': -37.415,
#  'longitude': 148.105,
#  'max_wind_speed': 15.0,
#  'precipitation': 0.08,
#  'precipitation_type': 'G',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 47.0,
#  'windspeed_knots': 7.7}
# {'_id': ObjectId('664cb09cfef7e795e29aec17'),
#  'air_temperature_celcius': 13.0,
#  'fire_events': [],
#  'ghi': 118.0,
#  'latest_date': '2024-01-12T00:00:00',
#  'latitude': -36.279,
#  'longitude': 141.6716,
#  'max_wind_speed': 15.0,
#  'precipitation': 0.0,
#  'precipitation_type': 'I',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 42.5,
#  'windspeed_knots': 8.0}
# {'_id': ObjectId('664cb0a6fef7e795e29aec19'),
#  'air_temperature_celcius': 12.0,
#  'fire_events': [],
#  'ghi': 109.0,
#  'latest_date': '2024-01-13T00:00:00',
#  'latitude': -36.538,
#  'longitude': 141.129,
#  'max_wind_speed': 15.0,
#  'precipitation': 0.0,
#  'precipitation_type': 'I',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 43.4,
#  'windspeed_knots': 9.3}
# {'_id': ObjectId('664cb3be8866fa211368f1d9'),
#  'air_temperature_celcius': 13.0,
#  'fire_events': [],
#  'ghi': 113.0,
#  'latest_date': '2024-04-01T00:00:00',
#  'latitude': -35.325,
#  'longitude': 143.497,
#  'max_wind_speed': 11.1,
#  'precipitation': 0.08,
#  'precipitation_type': 'G',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 48.5,
#  'windspeed_knots': 5.3}
# {'_id': ObjectId('664cb4ad41a416220bf31a01'),
#  'air_temperature_celcius': 10.0,
#  'fire_events': [],
#  'ghi': 90.0,
#  'latest_date': '2024-01-11T00:00:00',
#  'latitude': -37.448,
#  'longitude': 148.114,
#  'max_wind_speed': 11.1,
#  'precipitation': 0.12,
#  'precipitation_type': 'G',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 44.4,
#  'windspeed_knots': 5.6}
# {'_id': ObjectId('664cb4b641a416220bf31a03'),
#  'air_temperature_celcius': 12.0,
#  'fire_events': [],
#  'ghi': 108.0,
#  'latest_date': '2024-01-12T00:00:00',
#  'latitude': -35.321,
#  'longitude': 143.502,
#  'max_wind_speed': 7.0,
#  'precipitation': 0.0,
#  'precipitation_type': 'G',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 44.0,
#  'windspeed_knots': 4.7}
# {'_id': ObjectId('664cb4c041a416220bf31a05'),
#  'air_temperature_celcius': 16.0,
#  'fire_events': [],
#  'ghi': 139.0,
#  'latest_date': '2024-01-13T00:00:00',
#  'latitude': -37.609,
#  'longitude': 149.32,
#  'max_wind_speed': 14.0,
#  'precipitation': 0.01,
#  'precipitation_type': 'G',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 48.3,
#  'windspeed_knots': 9.4}
# {'_id': ObjectId('664cb4ca41a416220bf31a07'),
#  'air_temperature_celcius': 11.0,
#  'fire_events': [],
#  'ghi': 102.0,
#  'latest_date': '2024-01-14T00:00:00',
#  'latitude': -37.0667,
#  'longitude': 143.0582,
#  'max_wind_speed': 19.0,
#  'precipitation': 0.28,
#  'precipitation_type': 'G',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 39.7,
#  'windspeed_knots': 11.8}
# {'_id': ObjectId('664cb4d441a416220bf31a09'),
#  'air_temperature_celcius': 8.0,
#  'fire_events': [],
#  'ghi': 75.0,
#  'latest_date': '2024-01-15T00:00:00',
#  'latitude': -37.332,
#  'longitude': 148.091,
#  'max_wind_speed': 14.0,
#  'precipitation': 0.0,
#  'precipitation_type': 'G',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 39.3,
#  'windspeed_knots': 7.7}
# {'_id': ObjectId('664cb4de41a416220bf31a0b'),
#  'air_temperature_celcius': 25.0,
#  'fire_events': [],
#  'ghi': 195.0,
#  'latest_date': '2024-01-16T00:00:00',
#  'latitude': -36.404,
#  'longitude': 142.5467,
#  'max_wind_speed': 8.9,
#  'precipitation': 0.0,
#  'precipitation_type': 'I',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 60.9,
#  'windspeed_knots': 6.3}
# {'_id': ObjectId('664cb4e841a416220bf31a0d'),
#  'air_temperature_celcius': 15.0,
#  'fire_events': [],
#  'ghi': 134.0,
#  'latest_date': '2024-01-17T00:00:00',
#  'latitude': -37.6008,
#  'longitude': 143.0558,
#  'max_wind_speed': 19.0,
#  'precipitation': 0.0,
#  'precipitation_type': 'I',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 44.8,
#  'windspeed_knots': 8.3}
# {'_id': ObjectId('664cb4f241a416220bf31a0f'),
#  'air_temperature_celcius': 14.0,
#  'fire_events': [],
#  'ghi': 126.0,
#  'latest_date': '2024-01-18T00:00:00',
#  'latitude': -36.9817,
#  'longitude': 143.5051,
#  'max_wind_speed': 23.9,
#  'precipitation': 0.16,
#  'precipitation_type': 'G',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 44.0,
#  'windspeed_knots': 14.4}
# {'_id': ObjectId('664cb4fc41a416220bf31a11'),
#  'air_temperature_celcius': 18.0,
#  'fire_events': [],
#  'ghi': 150.0,
#  'latest_date': '2024-01-19T00:00:00',
#  'latitude': -36.575,
#  'longitude': 146.6668,
#  'max_wind_speed': 15.9,
#  'precipitation': 0.0,
#  'precipitation_type': 'G',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 53.6,
#  'windspeed_knots': 7.9}
# {'GHI_w/m2': 118.0,
#  '_id': ObjectId('664cb63d2d0aa3a5aca82920'),
#  'air_temperature_celcius': 13.0,
#  'fire_events': [],
#  'latest_date': '2024-01-18T00:00:00',
#  'latitude': -36.279,
#  'longitude': 141.6716,
#  'max_wind_speed': 15.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 42.5,
#  'windspeed_knots': 8.0}
# {'GHI_w/m2': 84.0,
#  '_id': ObjectId('664cb6462d0aa3a5aca82922'),
#  'air_temperature_celcius': 9.0,
#  'fire_events': [],
#  'latest_date': '2024-01-19T00:00:00',
#  'latitude': -37.6593,
#  'longitude': 143.3445,
#  'max_wind_speed': 15.0,
#  'precipitation': 0.08,
#  'precipitation_flag': 'G',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 40.1,
#  'windspeed_knots': 12.1}
# {'GHI_w/m2': 199.0,
#  '_id': ObjectId('664cb6502d0aa3a5aca82924'),
#  'air_temperature_celcius': 25.0,
#  'fire_events': [],
#  'latest_date': '2024-01-20T00:00:00',
#  'latitude': -37.583,
#  'longitude': 149.316,
#  'max_wind_speed': 22.0,
#  'precipitation': 0.04,
#  'precipitation_flag': 'G',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 58.3,
#  'windspeed_knots': 12.2}
# {'GHI_w/m2': 88.0,
#  '_id': ObjectId('664cb65b2d0aa3a5aca82926'),
#  'air_temperature_celcius': 10.0,
#  'fire_events': [],
#  'latest_date': '2024-01-21T00:00:00',
#  'latitude': -37.245,
#  'longitude': 143.426,
#  'max_wind_speed': 8.9,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 47.0,
#  'windspeed_knots': 5.2}
# {'GHI_w/m2': 173.0,
#  '_id': ObjectId('664cb6642d0aa3a5aca82928'),
#  'air_temperature_celcius': 21.0,
#  'fire_events': [],
#  'latest_date': '2024-01-22T00:00:00',
#  'latitude': -37.946,
#  'longitude': 144.342,
#  'max_wind_speed': 16.9,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 54.9,
#  'windspeed_knots': 7.4}
# {'GHI_w/m2': 159.0,
#  '_id': ObjectId('664cb97136342612331458a6'),
#  'air_temperature_celcius': 20.0,
#  'fire_events': [],
#  'latest_date': '2024-02-06T00:00:00',
#  'latitude': -37.758,
#  'longitude': 144.693,
#  'max_wind_speed': 15.9,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 58.8,
#  'windspeed_knots': 11.5}
# {'GHI_w/m2': 157.0,
#  '_id': ObjectId('664cb97b36342612331458a8'),
#  'air_temperature_celcius': 19.0,
#  'fire_events': [],
#  'latest_date': '2024-02-07T00:00:00',
#  'latitude': -37.886,
#  'longitude': 147.207,
#  'max_wind_speed': 12.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 54.3,
#  'windspeed_knots': 5.9}
# {'GHI_w/m2': 159.0,
#  '_id': ObjectId('664cb98536342612331458aa'),
#  'air_temperature_celcius': 17.0,
#  'fire_events': [],
#  'latest_date': '2024-02-08T00:00:00',
#  'latitude': -35.2881,
#  'longitude': 142.5679,
#  'max_wind_speed': 22.9,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 38.7,
#  'windspeed_knots': 16.8}
# {'GHI_w/m2': 114.0,
#  '_id': ObjectId('664cb98e36342612331458ac'),
#  'air_temperature_celcius': 13.0,
#  'fire_events': [],
#  'latest_date': '2024-02-09T00:00:00',
#  'latitude': -37.719,
#  'longitude': 142.154,
#  'max_wind_speed': 15.0,
#  'precipitation': 0.02,
#  'precipitation_flag': 'G',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 47.0,
#  'windspeed_knots': 7.9}
# {'GHI_w/m2': 111.0,
#  '_id': ObjectId('664cb99836342612331458ae'),
#  'air_temperature_celcius': 12.0,
#  'fire_events': [{'average_surface_temp': 59.0,
#                   'cause': 'others',
#                   'confidence': 77.0}],
#  'latest_date': '2024-02-10T00:00:00',
#  'latitude': -37.437,
#  'longitude': 148.104,
#  'max_wind_speed': 21.0,
#  'precipitation': 0.12,
#  'precipitation_flag': 'G',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 40.7,
#  'windspeed_knots': 16.7}
# {'GHI_w/m2': 149.0,
#  '_id': ObjectId('664cb9a236342612331458b0'),
#  'air_temperature_celcius': 18.0,
#  'fire_events': [],
#  'latest_date': '2024-02-11T00:00:00',
#  'latitude': -37.6767,
#  'longitude': 142.9892,
#  'max_wind_speed': 14.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 53.8,
#  'windspeed_knots': 6.7}
# {'GHI_w/m2': 135.0,
#  '_id': ObjectId('664cb9ac36342612331458b2'),
#  'air_temperature_celcius': 17.0,
#  'fire_events': [],
#  'latest_date': '2024-02-12T00:00:00',
#  'latitude': -36.6851,
#  'longitude': 141.6125,
#  'max_wind_speed': 15.0,
#  'precipitation': 0.75,
#  'precipitation_flag': 'G',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 59.0,
#  'windspeed_knots': 9.4}
# {'GHI_w/m2': 120.0,
#  '_id': ObjectId('664cb9b636342612331458b4'),
#  'air_temperature_celcius': 14.0,
#  'fire_events': [],
#  'latest_date': '2024-02-13T00:00:00',
#  'latitude': -35.962,
#  'longitude': 143.791,
#  'max_wind_speed': 15.9,
#  'precipitation': 0.0,
#  'precipitation_flag': 'G',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 49.9,
#  'windspeed_knots': 6.8}
# {'GHI_w/m2': 182.0,
#  '_id': ObjectId('664cb9c036342612331458b6'),
#  'air_temperature_celcius': 23.0,
#  'fire_events': [],
#  'latest_date': '2024-02-14T00:00:00',
#  'latitude': -37.58,
#  'longitude': 149.331,
#  'max_wind_speed': 12.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 59.0,
#  'windspeed_knots': 6.0}
# {'GHI_w/m2': 134.0,
#  '_id': ObjectId('664cb9ca36342612331458b8'),
#  'air_temperature_celcius': 14.0,
#  'fire_events': [],
#  'latest_date': '2024-02-15T00:00:00',
#  'latitude': -37.618,
#  'longitude': 143.0013,
#  'max_wind_speed': 22.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 36.0,
#  'windspeed_knots': 15.9}
# {'GHI_w/m2': 72.0,
#  '_id': ObjectId('664cb9d436342612331458ba'),
#  'air_temperature_celcius': 8.0,
#  'fire_events': [],
#  'latest_date': '2024-02-16T00:00:00',
#  'latitude': -38.495,
#  'longitude': 146.944,
#  'max_wind_speed': 8.0,
#  'precipitation': 0.39,
#  'precipitation_flag': 'G',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 44.6,
#  'windspeed_knots': 3.9}
# {'GHI_w/m2': 118.0,
#  '_id': ObjectId('664cb9de36342612331458bc'),
#  'air_temperature_celcius': 13.0,
#  'fire_events': [],
#  'latest_date': '2024-02-17T00:00:00',
#  'latitude': -36.279,
#  'longitude': 141.6716,
#  'max_wind_speed': 15.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 42.5,
#  'windspeed_knots': 8.0}
# {'GHI_w/m2': 154.0,
#  '_id': ObjectId('664cb9e836342612331458be'),
#  'air_temperature_celcius': 19.0,
#  'fire_events': [],
#  'latest_date': '2024-02-18T00:00:00',
#  'latitude': -36.285,
#  'longitude': 146.151,
#  'max_wind_speed': 8.9,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 56.3,
#  'windspeed_knots': 5.8}
# {'GHI_w/m2': 169.0,
#  '_id': ObjectId('664cb9f236342612331458c0'),
#  'air_temperature_celcius': 21.0,
#  'fire_events': [],
#  'latest_date': '2024-02-19T00:00:00',
#  'latitude': -36.952,
#  'longitude': 144.972,
#  'max_wind_speed': 9.9,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 57.3,
#  'windspeed_knots': 5.4}
# {'GHI_w/m2': 122.0,
#  '_id': ObjectId('664cb9fc36342612331458c2'),
#  'air_temperature_celcius': 15.0,
#  'fire_events': [],
#  'latest_date': '2024-02-20T00:00:00',
#  'latitude': -36.152,
#  'longitude': 143.578,
#  'max_wind_speed': 9.9,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 56.1,
#  'windspeed_knots': 5.1}
# {'GHI_w/m2': 170.0,
#  '_id': ObjectId('664cba0636342612331458c4'),
#  'air_temperature_celcius': 22.0,
#  'fire_events': [],
#  'latest_date': '2024-02-21T00:00:00',
#  'latitude': -37.976,
#  'longitude': 145.649,
#  'max_wind_speed': 11.1,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 62.0,
#  'windspeed_knots': 7.9}
# {'GHI_w/m2': 192.0,
#  '_id': ObjectId('664cba1036342612331458c6'),
#  'air_temperature_celcius': 23.0,
#  'fire_events': [{'average_surface_temp': 63.0,
#                   'cause': 'natural',
#                   'confidence': 87.0}],
#  'latest_date': '2024-02-22T00:00:00',
#  'latitude': -37.621,
#  'longitude': 143.447,
#  'max_wind_speed': 11.1,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 53.4,
#  'windspeed_knots': 6.1}
# {'GHI_w/m2': 111.0,
#  '_id': ObjectId('664cba1a36342612331458c8'),
#  'air_temperature_celcius': 12.0,
#  'fire_events': [],
#  'latest_date': '2024-02-23T00:00:00',
#  'latitude': -37.437,
#  'longitude': 148.104,
#  'max_wind_speed': 21.0,
#  'precipitation': 0.12,
#  'precipitation_flag': 'G',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 40.7,
#  'windspeed_knots': 16.7}
# {'GHI_w/m2': 102.0,
#  '_id': ObjectId('664cba2436342612331458ca'),
#  'air_temperature_celcius': 11.0,
#  'fire_events': [],
#  'latest_date': '2024-02-24T00:00:00',
#  'latitude': -37.0667,
#  'longitude': 143.0582,
#  'max_wind_speed': 19.0,
#  'precipitation': 0.28,
#  'precipitation_flag': 'G',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 39.7,
#  'windspeed_knots': 11.8}
# {'GHI_w/m2': 153.0,
#  '_id': ObjectId('664cba2e36342612331458cc'),
#  'air_temperature_celcius': 20.0,
#  'fire_events': [],
#  'latest_date': '2024-02-25T00:00:00',
#  'latitude': -34.965,
#  'longitude': 142.031,
#  'max_wind_speed': 15.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 62.6,
#  'windspeed_knots': 10.1}
# {'GHI_w/m2': 91.0,
#  '_id': ObjectId('664cba3836342612331458ce'),
#  'air_temperature_celcius': 10.0,
#  'fire_events': [],
#  'latest_date': '2024-02-26T00:00:00',
#  'latitude': -35.892,
#  'longitude': 145.62,
#  'max_wind_speed': 15.0,
#  'precipitation': 0.04,
#  'precipitation_flag': 'G',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 42.6,
#  'windspeed_knots': 8.9}
# {'GHI_w/m2': 91.0,
#  '_id': ObjectId('664cba4236342612331458d0'),
#  'air_temperature_celcius': 10.0,
#  'fire_events': [],
#  'latest_date': '2024-02-27T00:00:00',
#  'latitude': -35.892,
#  'longitude': 145.62,
#  'max_wind_speed': 15.0,
#  'precipitation': 0.04,
#  'precipitation_flag': 'G',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 42.6,
#  'windspeed_knots': 8.9}
# {'GHI_w/m2': 153.0,
#  '_id': ObjectId('664cba4c36342612331458d2'),
#  'air_temperature_celcius': 19.0,
#  'fire_events': [],
#  'latest_date': '2024-02-28T00:00:00',
#  'latitude': -37.59,
#  'longitude': 149.31,
#  'max_wind_speed': 15.0,
#  'precipitation': 0.98,
#  'precipitation_flag': 'G',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 57.2,
#  'windspeed_knots': 8.9}
# {'GHI_w/m2': 143.0,
#  '_id': ObjectId('664cba5636342612331458d4'),
#  'air_temperature_celcius': 17.0,
#  'fire_events': [],
#  'latest_date': '2024-02-29T00:00:00',
#  'latitude': -37.585,
#  'longitude': 149.336,
#  'max_wind_speed': 12.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'G',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 52.5,
#  'windspeed_knots': 6.7}
# {'GHI_w/m2': 150.0,
#  '_id': ObjectId('664cba6036342612331458d6'),
#  'air_temperature_celcius': 18.0,
#  'fire_events': [],
#  'latest_date': '2024-03-01T00:00:00',
#  'latitude': -36.575,
#  'longitude': 146.6668,
#  'max_wind_speed': 15.9,
#  'precipitation': 0.0,
#  'precipitation_flag': 'G',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 53.6,
#  'windspeed_knots': 7.9}
# {'GHI_w/m2': 183.0,
#  '_id': ObjectId('664cba6a36342612331458d8'),
#  'air_temperature_celcius': 23.0,
#  'fire_events': [{'average_surface_temp': 49.0,
#                   'cause': 'natural',
#                   'confidence': 76.0}],
#  'latest_date': '2024-03-02T00:00:00',
#  'latitude': -36.2127,
#  'longitude': 141.4938,
#  'max_wind_speed': 15.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 58.8,
#  'windspeed_knots': 8.8}
# {'GHI_w/m2': 173.0,
#  '_id': ObjectId('664cba7436342612331458da'),
#  'air_temperature_celcius': 21.0,
#  'fire_events': [],
#  'latest_date': '2024-03-03T00:00:00',
#  'latitude': -37.946,
#  'longitude': 144.342,
#  'max_wind_speed': 16.9,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 54.9,
#  'windspeed_knots': 7.4}
# {'GHI_w/m2': 82.0,
#  '_id': ObjectId('664cba7e36342612331458dc'),
#  'air_temperature_celcius': 9.0,
#  'fire_events': [],
#  'latest_date': '2024-03-04T00:00:00',
#  'latitude': -37.384,
#  'longitude': 148.056,
#  'max_wind_speed': 8.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 43.2,
#  'windspeed_knots': 4.9}
# {'GHI_w/m2': 188.0,
#  '_id': ObjectId('664cba8936342612331458de'),
#  'air_temperature_celcius': 24.0,
#  'fire_events': [],
#  'latest_date': '2024-03-05T00:00:00',
#  'latitude': -36.0279,
#  'longitude': 146.0244,
#  'max_wind_speed': 13.0,
#  'precipitation': 0.12,
#  'precipitation_flag': 'G',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 60.1,
#  'windspeed_knots': 8.0}
# {'GHI_w/m2': 49.0,
#  '_id': ObjectId('664d928c87f00ff1a1c1bc41'),
#  'air_temperature_celcius': 5.0,
#  'fire_events': [],
#  'latest_date': '2025-02-25T00:00:00',
#  'latitude': -35.963,
#  'longitude': 141.078,
#  'max_wind_speed': 14.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 33.1,
#  'windspeed_knots': 5.8}
# {'GHI_w/m2': 159.0,
#  '_id': ObjectId('664d929687f00ff1a1c1bc43'),
#  'air_temperature_celcius': 19.0,
#  'fire_events': [],
#  'latest_date': '2025-02-26T00:00:00',
#  'latitude': -38.0427,
#  'longitude': 141.0271,
#  'max_wind_speed': 15.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 52.9,
#  'windspeed_knots': 8.1}
# {'GHI_w/m2': 90.0,
#  '_id': ObjectId('664d92a087f00ff1a1c1bc45'),
#  'air_temperature_celcius': 10.0,
#  'fire_events': [],
#  'latest_date': '2025-02-27T00:00:00',
#  'latitude': -37.438,
#  'longitude': 148.09,
#  'max_wind_speed': 15.9,
#  'precipitation': 0.08,
#  'precipitation_flag': 'G',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 44.7,
#  'windspeed_knots': 8.0}
# {'GHI_w/m2': 145.0,
#  '_id': ObjectId('664d92aa87f00ff1a1c1bc47'),
#  'air_temperature_celcius': 17.0,
#  'fire_events': [],
#  'latest_date': '2025-02-28T00:00:00',
#  'latitude': -36.282,
#  'longitude': 146.157,
#  'max_wind_speed': 16.9,
#  'precipitation': 0.0,
#  'precipitation_flag': 'G',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 50.4,
#  'windspeed_knots': 11.9}
# {'GHI_w/m2': 49.0,
#  '_id': ObjectId('664d92b487f00ff1a1c1bc49'),
#  'air_temperature_celcius': 5.0,
#  'fire_events': [],
#  'latest_date': '2025-03-01T00:00:00',
#  'latitude': -35.963,
#  'longitude': 141.078,
#  'max_wind_speed': 14.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 33.1,
#  'windspeed_knots': 5.8}
# {'GHI_w/m2': 152.0,
#  '_id': ObjectId('664d92be87f00ff1a1c1bc4b'),
#  'air_temperature_celcius': 17.0,
#  'fire_events': [{'average_surface_temp': 55.0,
#                   'cause': 'others',
#                   'confidence': 82.0},
#                  {'average_surface_temp': 51.0,
#                   'cause': 'others',
#                   'confidence': 78.0}],
#  'latest_date': '2025-03-02T00:00:00',
#  'latitude': -36.3782,
#  'longitude': 143.7313,
#  'max_wind_speed': 27.0,
#  'precipitation': 0.24,
#  'precipitation_flag': 'G',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 44.9,
#  'windspeed_knots': 16.1}
# {'GHI_w/m2': 102.0,
#  '_id': ObjectId('664d92c887f00ff1a1c1bc4d'),
#  'air_temperature_celcius': 11.0,
#  'fire_events': [],
#  'latest_date': '2025-03-03T00:00:00',
#  'latitude': -37.8088,
#  'longitude': 142.2291,
#  'max_wind_speed': 8.9,
#  'precipitation': 0.0,
#  'precipitation_flag': 'G',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 40.8,
#  'windspeed_knots': 6.4}
# {'GHI_w/m2': 139.0,
#  '_id': ObjectId('664d92d287f00ff1a1c1bc4f'),
#  'air_temperature_celcius': 16.0,
#  'fire_events': [],
#  'latest_date': '2025-03-04T00:00:00',
#  'latitude': -37.634,
#  'longitude': 149.237,
#  'max_wind_speed': 15.9,
#  'precipitation': 0.0,
#  'precipitation_flag': 'G',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 48.4,
#  'windspeed_knots': 8.1}
# {'GHI_w/m2': 99.0,
#  '_id': ObjectId('664d9c5087f00ff1a1c1bc52'),
#  'air_temperature_celcius': 11.0,
#  'fire_events': [],
#  'latest_date': '2025-11-02T00:00:00',
#  'latitude': -37.478,
#  'longitude': 148.117,
#  'max_wind_speed': 16.9,
#  'precipitation': 0.12,
#  'precipitation_flag': 'G',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 43.9,
#  'windspeed_knots': 11.2}
# {'GHI_w/m2': 163.0,
#  '_id': ObjectId('664d9c5a87f00ff1a1c1bc54'),
#  'air_temperature_celcius': 21.0,
#  'fire_events': [],
#  'latest_date': '2025-11-03T00:00:00',
#  'latitude': -37.189,
#  'longitude': 146.791,
#  'max_wind_speed': 11.1,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 61.1,
#  'windspeed_knots': 6.6}
# {'GHI_w/m2': 107.0,
#  '_id': ObjectId('664d9c6487f00ff1a1c1bc56'),
#  'air_temperature_celcius': 12.0,
#  'fire_events': [{'average_surface_temp': 49.0,
#                   'cause': 'others',
#                   'confidence': 82.0}],
#  'latest_date': '2025-11-04T00:00:00',
#  'latitude': -37.379,
#  'longitude': 148.132,
#  'max_wind_speed': 11.1,
#  'precipitation': 0.0,
#  'precipitation_flag': 'G',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 44.9,
#  'windspeed_knots': 7.9}
# {'GHI_w/m2': 48.0,
#  '_id': ObjectId('664d9c6e87f00ff1a1c1bc58'),
#  'air_temperature_celcius': 5.0,
#  'fire_events': [],
#  'latest_date': '2025-11-05T00:00:00',
#  'latitude': -35.961,
#  'longitude': 141.089,
#  'max_wind_speed': 11.1,
#  'precipitation': 0.0,
#  'precipitation_flag': 'A',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 34.9,
#  'windspeed_knots': 4.3}
# {'GHI_w/m2': 47.0,
#  '_id': ObjectId('664d9c7887f00ff1a1c1bc5a'),
#  'air_temperature_celcius': 5.0,
#  'fire_events': [],
#  'latest_date': '2025-11-06T00:00:00',
#  'latitude': -38.498,
#  'longitude': 146.95,
#  'max_wind_speed': 5.1,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 38.6,
#  'windspeed_knots': 1.8}
# {'GHI_w/m2': 82.0,
#  '_id': ObjectId('664d9c8287f00ff1a1c1bc5c'),
#  'air_temperature_celcius': 9.0,
#  'fire_events': [],
#  'latest_date': '2025-11-07T00:00:00',
#  'latitude': -36.8741,
#  'longitude': 143.91,
#  'max_wind_speed': 14.0,
#  'precipitation': 0.12,
#  'precipitation_flag': 'G',
#  'producer_id': 'producer1_climate',
# ...
#  'precipitation': 0.0,
#  'precipitation_flag': 'G',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 40.4,
#  'windspeed_knots': 5.9}
# {'GHI_w/m2': 134.0,
#  '_id': ObjectId('664dbb0e06058a4bb12f4f5a'),
#  'air_temperature_celcius': 15.0,
#  'fire_events': [],
#  'latest_date': '2027-12-28T00:00:00',
#  'latitude': -37.608,
#  'longitude': 149.292,
#  'max_wind_speed': 12.0,
#  'precipitation': 0.02,
#  'precipitation_flag': 'G',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 44.6,
#  'windspeed_knots': 9.7}
# {'GHI_w/m2': 155.0,
#  '_id': ObjectId('664dbb1806058a4bb12f4f5c'),
#  'air_temperature_celcius': 19.0,
#  'fire_events': [],
#  'latest_date': '2027-12-29T00:00:00',
#  'latitude': -37.596,
#  'longitude': 149.319,
#  'max_wind_speed': 12.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'A',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 56.1,
#  'windspeed_knots': 6.9}
# {'GHI_w/m2': 185.0,
#  '_id': ObjectId('664dbb2206058a4bb12f4f5e'),
#  'air_temperature_celcius': 24.0,
#  'fire_events': [],
#  'latest_date': '2027-12-30T00:00:00',
#  'latitude': -37.903,
#  'longitude': 145.25,
#  'max_wind_speed': 13.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 62.3,
#  'windspeed_knots': 7.0}
# {'GHI_w/m2': 158.0,
#  '_id': ObjectId('664dbb2c06058a4bb12f4f60'),
#  'air_temperature_celcius': 19.0,
#  'fire_events': [],
#  'latest_date': '2027-12-31T00:00:00',
#  'latitude': -36.6732,
#  'longitude': 142.5162,
#  'max_wind_speed': 14.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 53.9,
#  'windspeed_knots': 8.3}
# {'GHI_w/m2': 223.0,
#  '_id': ObjectId('664dbb3606058a4bb12f4f62'),
#  'air_temperature_celcius': 28.0,
#  'fire_events': [],
#  'latest_date': '2028-01-01T00:00:00',
#  'latitude': -37.1875,
#  'longitude': 146.8024,
#  'max_wind_speed': 15.9,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 58.3,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 143.0,
#  '_id': ObjectId('664dbb4006058a4bb12f4f64'),
#  'air_temperature_celcius': 17.0,
#  'fire_events': [{'average_surface_temp': 45.0,
#                   'cause': 'others',
#                   'confidence': 70.0,
#                   'created_hour': '11',
#                   'created_time': '11:53:15'}],
#  'latest_date': '2028-01-02T00:00:00',
#  'latitude': -37.585,
#  'longitude': 149.336,
#  'max_wind_speed': 12.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'G',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 52.5,
#  'windspeed_knots': 6.7}
# {'GHI_w/m2': 76.0,
#  '_id': ObjectId('664dbb4a06058a4bb12f4f66'),
#  'air_temperature_celcius': 8.0,
#  'fire_events': [],
#  'latest_date': '2028-01-03T00:00:00',
#  'latitude': -37.1926,
#  'longitude': 143.8095,
#  'max_wind_speed': 13.0,
#  'precipitation': 0.01,
#  'precipitation_flag': 'G',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 36.3,
#  'windspeed_knots': 6.3}
# {'GHI_w/m2': 177.0,
#  '_id': ObjectId('664dbb5406058a4bb12f4f68'),
#  'air_temperature_celcius': 21.0,
#  'fire_events': [],
#  'latest_date': '2028-01-04T00:00:00',
#  'latitude': -37.332,
#  'longitude': 143.375,
#  'max_wind_speed': 13.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 51.7,
#  'windspeed_knots': 7.2}
# {'GHI_w/m2': 105.0,
#  '_id': ObjectId('664dbb5e06058a4bb12f4f6a'),
#  'air_temperature_celcius': 12.0,
#  'fire_events': [{'average_surface_temp': 48.0,
#                   'cause': 'others',
#                   'confidence': 100.0,
#                   'created_hour': '11',
#                   'created_time': '11:53:15'}],
#  'latest_date': '2028-01-05T00:00:00',
#  'latitude': -37.375,
#  'longitude': 148.054,
#  'max_wind_speed': 8.9,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 47.0,
#  'windspeed_knots': 4.8}
# {'GHI_w/m2': 73.0,
#  '_id': ObjectId('664dbb6806058a4bb12f4f6c'),
#  'air_temperature_celcius': 8.0,
#  'fire_events': [],
#  'latest_date': '2028-01-06T00:00:00',
#  'latitude': -37.475,
#  'longitude': 148.134,
#  'max_wind_speed': 7.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 43.1,
#  'windspeed_knots': 3.4}
# {'GHI_w/m2': 91.0,
#  '_id': ObjectId('664dbb7206058a4bb12f4f6e'),
#  'air_temperature_celcius': 10.0,
#  'fire_events': [],
#  'latest_date': '2028-01-07T00:00:00',
#  'latitude': -35.892,
#  'longitude': 145.62,
#  'max_wind_speed': 15.0,
#  'precipitation': 0.04,
#  'precipitation_flag': 'G',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 42.6,
#  'windspeed_knots': 8.9}
# {'GHI_w/m2': 161.0,
#  '_id': ObjectId('664dbb7c06058a4bb12f4f70'),
#  'air_temperature_celcius': 19.0,
#  'fire_events': [],
#  'latest_date': '2028-01-08T00:00:00',
#  'latitude': -38.527,
#  'longitude': 143.493,
#  'max_wind_speed': 20.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 51.5,
#  'windspeed_knots': 10.2}
# {'GHI_w/m2': 148.0,
#  '_id': ObjectId('664dbb8606058a4bb12f4f72'),
#  'air_temperature_celcius': 18.0,
#  'fire_events': [],
#  'latest_date': '2028-01-09T00:00:00',
#  'latitude': -36.0714,
#  'longitude': 145.7665,
#  'max_wind_speed': 25.1,
#  'precipitation': 0.12,
#  'precipitation_flag': 'G',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 54.6,
#  'windspeed_knots': 12.0}
# {'GHI_w/m2': 265.0,
#  '_id': ObjectId('664dbb9006058a4bb12f4f74'),
#  'air_temperature_celcius': 32.0,
#  'fire_events': [],
#  'latest_date': '2028-01-10T00:00:00',
#  'latitude': -34.289,
#  'longitude': 141.712,
#  'max_wind_speed': 19.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 54.1,
#  'windspeed_knots': 12.8}
# {'GHI_w/m2': 131.0,
#  '_id': ObjectId('664dbb9a06058a4bb12f4f76'),
#  'air_temperature_celcius': 14.0,
#  'fire_events': [{'average_surface_temp': 66.0,
#                   'cause': 'others',
#                   'confidence': 90.0,
#                   'created_hour': '11',
#                   'created_time': '11:53:15'},
#                  {'average_surface_temp': 45.0,
#                   'cause': 'others',
#                   'confidence': 71.0,
#                   'created_hour': '11',
#                   'created_time': '11:53:15'}],
#  'latest_date': '2028-01-11T00:00:00',
#  'latitude': -36.8867,
#  'longitude': 142.1873,
#  'max_wind_speed': 30.9,
#  'precipitation': 0.01,
#  'precipitation_flag': 'G',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 39.3,
#  'windspeed_knots': 17.7}
# {'GHI_w/m2': 98.0,
#  '_id': ObjectId('664dbba406058a4bb12f4f78'),
#  'air_temperature_celcius': 11.0,
#  'fire_events': [],
#  'latest_date': '2028-01-12T00:00:00',
#  'latitude': -36.6516,
#  'longitude': 141.4943,
#  'max_wind_speed': 15.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'G',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 45.3,
#  'windspeed_knots': 8.5}
# {'GHI_w/m2': 118.0,
#  '_id': ObjectId('664dbbae06058a4bb12f4f7a'),
#  'air_temperature_celcius': 13.0,
#  'fire_events': [],
#  'latest_date': '2028-01-13T00:00:00',
#  'latitude': -37.3583,
#  'longitude': 143.0203,
#  'max_wind_speed': 14.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'G',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 43.3,
#  'windspeed_knots': 9.4}
# {'GHI_w/m2': 124.0,
#  '_id': ObjectId('664dbbb806058a4bb12f4f7c'),
#  'air_temperature_celcius': 14.0,
#  'fire_events': [{'average_surface_temp': 53.0,
#                   'cause': 'others',
#                   'confidence': 80.0,
#                   'created_hour': '11',
#                   'created_time': '11:53:15'}],
#  'latest_date': '2028-01-14T00:00:00',
#  'latitude': -37.692,
#  'longitude': 143.593,
#  'max_wind_speed': 9.9,
#  'precipitation': 0.0,
#  'precipitation_flag': 'G',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 45.8,
#  'windspeed_knots': 6.5}
# {'GHI_w/m2': 90.0,
#  '_id': ObjectId('664dbbc206058a4bb12f4f7e'),
#  'air_temperature_celcius': 10.0,
#  'fire_events': [],
#  'latest_date': '2028-01-15T00:00:00',
#  'latitude': -36.1462,
#  'longitude': 145.2096,
#  'max_wind_speed': 14.0,
#  'precipitation': 0.2,
#  'precipitation_flag': 'G',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 43.6,
#  'windspeed_knots': 9.7}
# {'GHI_w/m2': 99.0,
#  '_id': ObjectId('664dbbcc06058a4bb12f4f80'),
#  'air_temperature_celcius': 11.0,
#  'fire_events': [],
#  'latest_date': '2028-01-16T00:00:00',
#  'latitude': -37.478,
#  'longitude': 148.117,
#  'max_wind_speed': 16.9,
#  'precipitation': 0.12,
#  'precipitation_flag': 'G',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 43.9,
#  'windspeed_knots': 11.2}
# {'GHI_w/m2': 158.0,
#  '_id': ObjectId('664dbbd606058a4bb12f4f82'),
#  'air_temperature_celcius': 21.0,
#  'fire_events': [],
#  'latest_date': '2028-01-17T00:00:00',
#  'latitude': -37.623,
#  'longitude': 149.284,
#  'max_wind_speed': 15.9,
#  'precipitation': 1.26,
#  'precipitation_flag': 'G',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 64.5,
#  'windspeed_knots': 10.6}
# {'GHI_w/m2': 47.0,
#  '_id': ObjectId('664dbbe006058a4bb12f4f84'),
#  'air_temperature_celcius': 5.0,
#  'fire_events': [],
#  'latest_date': '2028-01-18T00:00:00',
#  'latitude': -38.498,
#  'longitude': 146.95,
#  'max_wind_speed': 5.1,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 38.6,
#  'windspeed_knots': 1.8}
# {'GHI_w/m2': 150.0,
#  '_id': ObjectId('664dbbea06058a4bb12f4f86'),
#  'air_temperature_celcius': 17.0,
#  'fire_events': [],
#  'latest_date': '2028-01-19T00:00:00',
#  'latitude': -37.8147,
#  'longitude': 143.1062,
#  'max_wind_speed': 20.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 46.4,
#  'windspeed_knots': 9.5}
# {'GHI_w/m2': 198.0,
#  '_id': ObjectId('664dbbf406058a4bb12f4f88'),
#  'air_temperature_celcius': 23.0,
#  'fire_events': [],
#  'latest_date': '2028-01-20T00:00:00',
#  'latitude': -37.605,
#  'longitude': 149.326,
#  'max_wind_speed': 19.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 49.6,
#  'windspeed_knots': 10.0}
# {'GHI_w/m2': 87.0,
#  '_id': ObjectId('664dbbfe06058a4bb12f4f8a'),
#  'air_temperature_celcius': 10.0,
#  'fire_events': [],
#  'latest_date': '2028-01-21T00:00:00',
#  'latitude': -37.456,
#  'longitude': 148.11,
#  'max_wind_speed': 7.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 47.9,
#  'windspeed_knots': 4.1}
# {'GHI_w/m2': 156.0,
#  '_id': ObjectId('664dbc0806058a4bb12f4f8c'),
#  'air_temperature_celcius': 19.0,
#  'fire_events': [],
#  'latest_date': '2028-01-22T00:00:00',
#  'latitude': -36.4553,
#  'longitude': 142.8786,
#  'max_wind_speed': 12.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 55.3,
#  'windspeed_knots': 6.2}
# {'GHI_w/m2': 107.0,
#  '_id': ObjectId('664dbc1206058a4bb12f4f8e'),
#  'air_temperature_celcius': 12.0,
#  'fire_events': [],
#  'latest_date': '2028-01-23T00:00:00',
#  'latitude': -37.406,
#  'longitude': 148.123,
#  'max_wind_speed': 18.1,
#  'precipitation': 0.0,
#  'precipitation_flag': 'G',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 44.7,
#  'windspeed_knots': 11.4}
# {'GHI_w/m2': 134.0,
#  '_id': ObjectId('664dbc1c06058a4bb12f4f90'),
#  'air_temperature_celcius': 15.0,
#  'fire_events': [{'average_surface_temp': 41.0,
#                   'cause': 'others',
#                   'confidence': 61.0,
#                   'created_hour': '11',
#                   'created_time': '11:53:15'}],
#  'latest_date': '2028-01-24T00:00:00',
#  'latitude': -37.6745,
#  'longitude': 142.9848,
#  'max_wind_speed': 14.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'G',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 44.5,
#  'windspeed_knots': 10.2}
# {'GHI_w/m2': 195.0,
#  '_id': ObjectId('664dbc2606058a4bb12f4f92'),
#  'air_temperature_celcius': 25.0,
#  'fire_events': [],
#  'latest_date': '2028-01-25T00:00:00',
#  'latitude': -36.404,
#  'longitude': 142.5467,
#  'max_wind_speed': 8.9,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 60.9,
#  'windspeed_knots': 6.3}
# {'GHI_w/m2': 154.0,
#  '_id': ObjectId('664dbc3006058a4bb12f4f94'),
#  'air_temperature_celcius': 19.0,
#  'fire_events': [],
#  'latest_date': '2028-01-26T00:00:00',
#  'latitude': -37.623,
#  'longitude': 149.323,
#  'max_wind_speed': 11.1,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 56.8,
#  'windspeed_knots': 7.9}
# {'GHI_w/m2': 128.0,
#  '_id': ObjectId('664dbc3a06058a4bb12f4f96'),
#  'air_temperature_celcius': 15.0,
#  'fire_events': [],
#  'latest_date': '2028-01-27T00:00:00',
#  'latitude': -38.038,
#  'longitude': 142.986,
#  'max_wind_speed': 13.0,
#  'precipitation': 0.02,
#  'precipitation_flag': 'G',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 50.7,
#  'windspeed_knots': 9.2}
# {'GHI_w/m2': 88.0,
#  '_id': ObjectId('664dbc4406058a4bb12f4f98'),
#  'air_temperature_celcius': 10.0,
#  'fire_events': [{'average_surface_temp': 53.0,
#                   'cause': 'others',
#                   'confidence': 80.0,
#                   'created_hour': '11',
#                   'created_time': '11:53:15'}],
#  'latest_date': '2028-01-28T00:00:00',
#  'latitude': -37.245,
#  'longitude': 143.426,
#  'max_wind_speed': 8.9,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 47.0,
#  'windspeed_knots': 5.2}
# {'GHI_w/m2': 190.0,
#  '_id': ObjectId('664dbc4e06058a4bb12f4f9a'),
#  'air_temperature_celcius': 23.0,
#  'fire_events': [],
#  'latest_date': '2028-01-29T00:00:00',
#  'latitude': -38.141,
#  'longitude': 143.183,
#  'max_wind_speed': 14.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 54.1,
#  'windspeed_knots': 5.7}
# {'GHI_w/m2': 111.0,
#  '_id': ObjectId('664dbc5806058a4bb12f4f9c'),
#  'air_temperature_celcius': 13.0,
#  'fire_events': [{'average_surface_temp': 37.0,
#                   'cause': 'others',
#                   'confidence': 70.0,
#                   'created_hour': '19',
#                   'created_time': '19:05:15'},
#                  {'average_surface_temp': 47.0,
#                   'cause': 'others',
#                   'confidence': 72.0,
#                   'created_hour': '11',
#                   'created_time': '11:53:15'}],
#  'latest_date': '2028-01-30T00:00:00',
#  'latitude': -37.4437,
#  'longitude': 143.4924,
#  'max_wind_speed': 13.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 50.7,
#  'windspeed_knots': 6.1}
# {'GHI_w/m2': 188.0,
#  '_id': ObjectId('664dbc6206058a4bb12f4f9e'),
#  'air_temperature_celcius': 24.0,
#  'fire_events': [],
#  'latest_date': '2028-01-31T00:00:00',
#  'latitude': -36.0279,
#  'longitude': 146.0244,
#  'max_wind_speed': 13.0,
#  'precipitation': 0.12,
#  'precipitation_flag': 'G',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 60.1,
#  'windspeed_knots': 8.0}
# {'GHI_w/m2': 72.0,
#  '_id': ObjectId('664dbc6c06058a4bb12f4fa0'),
#  'air_temperature_celcius': 8.0,
#  'fire_events': [],
#  'latest_date': '2028-02-01T00:00:00',
#  'latitude': -38.495,
#  'longitude': 146.944,
#  'max_wind_speed': 8.0,
#  'precipitation': 0.39,
#  'precipitation_flag': 'G',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 44.6,
#  'windspeed_knots': 3.9}
# {'GHI_w/m2': 109.0,
#  '_id': ObjectId('664dbc7606058a4bb12f4fa2'),
#  'air_temperature_celcius': 12.0,
#  'fire_events': [],
#  'latest_date': '2028-02-02T00:00:00',
#  'latitude': -36.2669,
#  'longitude': 143.1906,
#  'max_wind_speed': 15.9,
#  'precipitation': 0.01,
#  'precipitation_flag': 'G',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 42.7,
#  'windspeed_knots': 10.0}
# {'GHI_w/m2': 83.0,
#  '_id': ObjectId('664dbc8006058a4bb12f4fa4'),
#  'air_temperature_celcius': 9.0,
#  'fire_events': [],
#  'latest_date': '2028-02-03T00:00:00',
#  'latitude': -36.8948,
#  'longitude': 142.3282,
#  'max_wind_speed': 13.0,
#  'precipitation': 0.01,
#  'precipitation_flag': 'G',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 41.2,
#  'windspeed_knots': 6.7}

# %% [markdown]
# If there are fire events:
# ```
# {'GHI_w/m2': 152.0,
#  '_id': ObjectId('664db85c06058a4bb12f4f43'),
#  'air_temperature_celcius': 18.0,
#  'fire_events': [{'average_surface_temp': 48.0,
#                   'cause': 'others',
#                   'confidence': 74.0,
#                   'created_hour': '17',
#                   'created_time': '17:15:55'}],
#  'latest_date': '2027-10-20T00:00:00',
#  'latitude': -36.2032,
#  'longitude': 145.3025,
#  'max_wind_speed': 14.0,
#  'precipitation': 0.0,
#  'precipitation_flag': 'I',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 52.0,
#  'windspeed_knots': 7.1}
# ```
#
# If there are no fire events:
# ```
# {'GHI_w/m2': 102.0,
#  '_id': ObjectId('664d92c887f00ff1a1c1bc4d'),
#  'air_temperature_celcius': 11.0,
#  'fire_events': [],
#  'latest_date': '2025-03-03T00:00:00',
#  'latitude': -37.8088,
#  'longitude': 142.2291,
#  'max_wind_speed': 8.9,
#  'precipitation': 0.0,
#  'precipitation_flag': 'G',
#  'producer_id': 'producer1_climate',
#  'relative_humidity': 40.8,
#  'windspeed_knots': 6.4}
# ```
